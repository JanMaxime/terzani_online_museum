# %% [markdown]
# # Image annotation script

# %% [markdown]
# This notebook will serve as a prototype to create a script to annotate all the images of Terzani collection

# %% [markdown]
# ## Installing the client library
#
# If the Google cloud vision library is not installed already, install it.
#
# If you have python environment use
#
# ```shell
# pip install --upgrade google-cloud-vision
# ```
#
# If you have conda environment use
#
# ```shell
# conda install -c conda-forge google-cloud-vision
# ```

# %% [markdown]
# ## Installing other libraries
#
# Install `dotenv` to get the environment variables
#
# If you have python environment use
#
# ```shell
# pip install python-dotenv
# ```
#
# If you have conda environment use
#
# ```shell
# conda install -c conda-forge python-dotenvn
# ```
#
# pip install python-dotenv

# %% [markdown]
# ## Import the libraries

# %%
## Import the standard libraries
import os, io, pickle, random, json
## Import Vison API related libraries
from google.cloud import vision
from google.cloud.vision import types
## Import dotenv library to get environment variables
from dotenv import load_dotenv
# Import urllib to read images
import urllib.request as ur
# Import pymango to inset data into mangodb
import pymongo
from tqdm import tqdm
# 
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
import nltk
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ravin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Setup the service account credentials to use the API

# %%
load_dotenv()

GOOGLE_APPLICATION_CREDENTIALS = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = GOOGLE_APPLICATION_CREDENTIALS

MANGO_CLIENT_URI = os.getenv('MONGO_URI')
os.environ['MANGO_CLIENT_URI'] = MANGO_CLIENT_URI

# %% [markdown]
# ## Creation of Client to access the API

# %%
client = vision.ImageAnnotatorClient()

# %% [markdown]
# ## Image selection
#
# As this is a prototyping script we shall select 10 images randomly each from the color and monochrome photos (using the already created pickle files).

# %% [markdown]
# Generic class to store an image and its IIIF representation

# %%
class Terzani_Photo(object):
    def __init__(self, iiif, country):
        self.iiif = iiif
        self.photo = country
        
    def get_photo_link(self):
        return self.iiif["images"][0]["resource"]["@id"]

# %%
nu_of_images_per_type = 10

'''
# loading the color photos
color_photos = pickle.load(open("terzani_recto_iiif_color.pickle", "rb" ))
# randomly selecting 10 images
color_photos = random.sample(color_photos, nu_of_images_per_type)

# loading the monochrome photos
bw_photos = pickle.load(open("terzani_recto_iiif_color.pickle", "rb" ))
# randomly selecting 10 images
bw_photos = random.sample(bw_photos, nu_of_images_per_type)

all_photos = color_photos + bw_photos

'''

all_photos = pickle.load(open("terzani_recto_iiif.pickle", "rb"))
all_photos = random.sample(all_photos, nu_of_images_per_type)

# %% [markdown]
# ## Function to clean text

# %%
def clean_text(text: str, lower: bool=True, rmv_punc: bool = True, stem: bool = True, norm: bool = True):
    """
    This function accepts a string and performs preprocessing steps on it. 
    
    :param text (str): The string or text on which the preprocessing has to be performed.
    :param lower (bool): Default=True, indicates if the text has to be made into lower case.
    :param rmv_punc (bool): Default=True, indicates if the punctuation should be removed in the text.
    :param stem (bool): Default=True, indicates if the stemming should be performed on the words in the text.
    :param norm (bool): Default=True, indicates if the words in the has to be normalised.
    :return cleaned_text (list): The modified text is returned as list after performing the indicated operations.
    """
    
    # split into words
    tokens = word_tokenize(text)
    if lower:
        # convert to lower case
        tokens = [w.lower() for w in tokens]
    if rmv_punc:
        # remove punctuation from each word
        table = str.maketrans('', '', string.punctuation)
        tokens = [w.translate(table) for w in tokens if w.translate(table) != '']
    if stem:
        # stemming of words
        porter = PorterStemmer()
        tokens = [porter.stem(word) for word in tokens]
    cleaned_text = sorted(list(set(tokens)),key=str.lower)
    return cleaned_text

# %% [markdown]
# ## Calling the Vision API
#
# The structure of tagged images will be
# ```json
# {'tag1': [label_1],
#  'tag2': [label_2, label_4],
#  'tag3': [label_3],
#  'tag4': [label_3]
# }
# ```
#
# The structure of annotated_images will be
# ```json
# {'label_1':
#     {
#     'iiif': IIIF ANNOTATION,
#     'obj_boxes':
#     {
#     frozenset({'tag1'}): [[x1, y1, w1, h1]],
#     frozenset({'tag2'}): [[x4, y4, w4, h4], [x2, y2, w2, h2], [x3, y3, w3, h3]],
#     frozenset({'tag3', 'tag4'}): [[x5, y5, w5, h5], [x6, y6, w6, h6], [x7, y7, w7, h7]]
#     },
#     'landmark_info':
#     {
#     'landmark1_name':{"latitude":la1, "longitude":lt1},
#     'landmark2_name':{"latitude":la2, "longitude":lt2}
#     },
#     'country': None
#     },
# 'label_2':
#     {
#     'iiif': IIIF ANNOTATION,
#     'obj_boxes':
#     {
#     frozenset({'tag4'}): [[x1, y1, w1, h1]],
#     frozenset({'tag5'}): [[x4, y4, w4, h4],],
#     frozenset({'tag6'}): [[x5, y5, w5, h5], [x6, y6, w6, h6]]
#     },
#     'landmark_info':
#     {
#     'landmark3_name':{"latitude":la3, "longitude":lt3},
#     'landmark4_name':{"latitude":la4, "longitude":lt4}
#     },
#     'country': None
#     }
# }
# ```

# %%
tagged_images = dict() # The keys would be the tags, entities and objects found in the annotation and the values would be the image labels.
annotated_images = dict() # The keys would be the image labels and the values will be the IIIF annotation, name of the country, lat,lon if there is geotag and object localization.
failed_images = dict() # We store information about images that are failed to be annotated by google api.

for img in tqdm(all_photos):

    # if the image is already not present in the either annotated and failed dictionaries
    if img.iiif["label"] not in annotated_images and img.iiif["label"] not in failed_images:

        # get the image label
        img_lbl = img.iiif["label"]
        img_country = img.country
                
        # reading the image
        image_data = ur.urlopen(img.get_photo_link()).read()
        image = types.Image(content=image_data)
        
        # call the goole vision api to get the annotations of various types
        response = client.annotate_image({
            'image': image,
            'features': [{'type': vision.enums.Feature.Type.LANDMARK_DETECTION}, 
                         {'type': vision.enums.Feature.Type.LOGO_DETECTION},
                         {'type': vision.enums.Feature.Type.LABEL_DETECTION},
                         {'type': vision.enums.Feature.Type.TEXT_DETECTION},
                         {'type': vision.enums.Feature.Type.OBJECT_LOCALIZATION},
                         {'type': vision.enums.Feature.Type.WEB_DETECTION}],})
        
        # check if there is any error returned by the api
        if response.error.code != 0:
            failed_images[img_lbl] = {}
            failed_images[img_lbl]["error"] = [response.error.code, response.error.message]
        else:
            # if the API call is successful
            annotated_images[img_lbl] = {}
        
            # store the iiif description
            annotated_images[img_lbl]["iiif"] = img.iiif

            # get the list of labels
            labels = list()
            for lbl in response.label_annotations:
                labels.extend(clean_text(lbl.description))
            labels = list(set(labels))
            
            # Add the label and image label to the dictionary to perform search
            for label in labels:
                if label not in tagged_images:
                    tagged_images[label] = []
                if img_lbl not in tagged_images[label]:
                    tagged_images[label].append(img_lbl)
            
            # get the list of web entities
            webent = list()
            for weben in response.web_detection.web_entities:
                webent.extend(clean_text(weben.description))
            webent = list(set(webent))
            
            # Add the web entity and image label to the dictionary to perform search
            for web_entity in labels:
                if web_entity not in tagged_images:
                    tagged_images[web_entity] = []
                if img_lbl not in tagged_images[web_entity]:
                    tagged_images[web_entity].append(img_lbl)
            

            obj_boxes = {} # this dictionary will store the information of annotations along with bounding boxes.
            # The key will the the name to identify the annotation and the value be a list of lists containing the top left x coordinate
            # top left y coordinate, width and height of for the bounding box.
            # It would be a list of list to store coordinates for different boxes for same tag

            # storing the landmarks
            landmark_info = dict() # this dictionary will store the information of landmarks which are name, latitude, longitude.
            for lndmk in response.landmark_annotations:
                
                # if there are any landamrks identified, we store them in a seperate field,to access easily.
                landmark_name = lndmk.description.lower()
                landmark_info[landmark_name] = {"latitude":lndmk.locations[0].lat_lng.latitude, "longitude":lndmk.locations[0].lat_lng.longitude}
                
                
                lndmks = clean_text(lndmk.description)
                # we add the landmarks and image label to the dictionary to perform search
                for land_mark in lndmks:
                    if land_mark not in tagged_images:
                        tagged_images[land_mark] = []
                    if img_lbl not in tagged_images[land_mark]:
                        tagged_images[land_mark].append(img_lbl)
                
                # storing the landmarks with bounding boxes 
                lndmk_desc = '_'.join(lndmks)
                '_'.join(lndmks)
                if lndmk_desc not in obj_boxes:
                    obj_boxes[lndmk_desc] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lndmk.bounding_poly.vertices[0].x, lndmk.bounding_poly.vertices[0].y
                box_width = lndmk.bounding_poly.vertices[1].x - lndmk.bounding_poly.vertices[0].x
                box_height = lndmk.bounding_poly.vertices[3].y - lndmk.bounding_poly.vertices[0].y
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height] 
                    obj_boxes[lndmk_desc].append(vert)    

            for lgo in response.logo_annotations:
                
                logos = clean_text(lgo.description)
                # we add the logo names and image label to the dictionary to perform search
                for lgo_name in logos:
                    if lgo_name not in tagged_images:
                        tagged_images[lgo_name] = []
                    if img_lbl not in tagged_images[lgo_name]:
                        tagged_images[lgo_name].append(img_lbl)
                        
                lgo_desc = '_'.join(logos)
                if lgo_desc not in obj_boxes:
                    obj_boxes[lgo_desc] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lgo.bounding_poly.vertices[0].x, lgo.bounding_poly.vertices[0].y
                box_width = abs(lgo.bounding_poly.vertices[1].x - lgo.bounding_poly.vertices[0].x)
                box_height = abs(lgo.bounding_poly.vertices[3].y - lgo.bounding_poly.vertices[0].y)
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[lgo_desc].append(vert)

            if len(response.localized_object_annotations) > 0:
                img_width, img_height = img.iiif["width"], img.iiif["height"]
            for lobj in response.localized_object_annotations:
                
                objects = clean_text(lobj.name)  
                # we add the object names and image label to the dictionary to perform search
                for obj_name in objects:
                    if obj_name not in tagged_images:
                        tagged_images[obj_name] = []
                    if img_lbl not in tagged_images[obj_name]:
                        tagged_images[obj_name].append(img_lbl)
                
                lobj_name = '_'.join(objects)
                if lobj_name not in obj_boxes:
                    obj_boxes[lobj_name] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lobj.bounding_poly.normalized_vertices[0].x * img_width, lobj.bounding_poly.normalized_vertices[0].y * img_height
                box_width = (lobj.bounding_poly.normalized_vertices[1].x - lobj.bounding_poly.normalized_vertices[0].x) * img_width
                box_height = (lobj.bounding_poly.normalized_vertices[3].y - lobj.bounding_poly.normalized_vertices[0].y) * img_height
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[lobj_name].append(vert)

            for txt in response.text_annotations:
                modified_text = txt.description.replace(".", "_").lower()
                # we add the text and image label to the dictionary to perform search
                if modified_text not in tagged_images:
                    tagged_images[modified_text] = []
                if img_lbl not in tagged_images[modified_text]:
                        tagged_images[modified_text].append(img_lbl)    
                
                # the text identified on the images in not cleaned to store the original information.
                if modified_text not in obj_boxes:
                    obj_boxes[modified_text] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = txt.bounding_poly.vertices[0].x, txt.bounding_poly.vertices[0].y
                box_width = abs(txt.bounding_poly.vertices[1].x - txt.bounding_poly.vertices[0].x)
                box_height = abs(txt.bounding_poly.vertices[3].y - txt.bounding_poly.vertices[0].y)
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[modified_text].append(vert)

            # store the generated object boxes into the dictionary.
            annotated_images[img_lbl]["obj_boxes"] = obj_boxes
            
            # store the generated land mark information into the dictionary.
            annotated_images[img_lbl]["landmark_info"] = landmark_info
            
            # store the generated land mark information into the dictionary.
            annotated_images[img_lbl]["country"] = img_country
# Out:
# 100%|██████████| 10/10 [01:10<00:00,  7.04s/it]

# %% [markdown]
# ## Saving the dictionaries to JSON file

# %%
tagged_images
# Out:
# {'photograph': ['T61_61_recto',
#   'T12_45_recto',
#   'T31_30_recto',
#   'T20_169_recto',
#   'T14_38_recto',
#   'F20_88_recto',
#   'F25_239_recto'],
#  'snapshot': ['T61_61_recto',
#   'T12_45_recto',
#   'T31_30_recto',
#   'T20_169_recto',
#   'T14_38_recto',
#   'F20_88_recto',
#   'F25_239_recto'],
#  'blackandwhit': ['T61_61_recto',
#   'Cina9_1_recto',
#   'T12_45_recto',
#   'T31_30_recto',
#   'T12_29_recto',
#   'T20_169_recto',
#   'T14_38_recto',
#   'F20_88_recto',
#   'F25_239_recto'],
#  'monochrom': ['T61_61_recto',
#   'Cina9_1_recto',
#   'T12_45_recto',
#   'T12_29_recto',
#   'T20_169_recto',
#   'T14_38_recto',
#   'F20_88_recto',
#   'F25_239_recto'],
#  'photographi': ['T61_61_recto',
#   'Cina9_1_recto',
#   'T12_45_recto',
#   'T31_30_recto',
#   'T12_29_recto',
#   'F25_18_recto',
#   'T20_169_recto',
#   'T14_38_recto',
#   'F20_88_recto',
#   'F25_239_recto'],
#  'adapt': ['T61_61_recto', 'T12_45_recto', 'F25_18_recto'],
#  'stock': ['T61_61_recto',
#   'Cina9_1_recto',
#   'T12_45_recto',
#   'T31_30_recto',
#   'F25_18_recto',
#   'T20_169_recto',
#   'T14_38_recto',
#   'F20_88_recto',
#   'F25_239_recto'],
#  'cloth': ['T61_61_recto',
#   'T31_30_recto',
#   'F25_18_recto',
#   'T20_169_recto',
#   'F20_88_recto',
#   'F25_239_recto'],
#  'person': ['T61_61_recto',
#   'T12_45_recto',
#   'T31_30_recto',
#   'F25_18_recto',
#   'T20_169_recto',
#   'F20_88_recto',
#   'F25_239_recto'],
#  'landmark': ['Cina9_1_recto'],
#  'symmetri': ['Cina9_1_recto'],
#  'facad': ['Cina9_1_recto'],
#  'histori': ['Cina9_1_recto', 'T14_38_recto'],
#  'architectur': ['Cina9_1_recto'],
#  'build': ['Cina9_1_recto'],
#  'black': ['T12_45_recto'],
#  'tree': ['T12_45_recto'],
#  'bench': ['T12_45_recto'],
#  'footwear': ['T12_45_recto'],
#  'coat': ['T12_45_recto'],
#  'room': ['T31_30_recto', 'T12_29_recto', 'F20_88_recto'],
#  'frame': ['T31_30_recto', 'T12_29_recto'],
#  'art': ['T31_30_recto', 'T12_29_recto'],
#  'illustr': ['T31_30_recto'],
#  'visual': ['T31_30_recto', 'T12_29_recto'],
#  'pictur': ['T31_30_recto', 'T12_29_recto'],
#  'collect': ['T12_29_recto'],
#  'style': ['T12_29_recto', 'F25_239_recto'],
#  'apeee cenen\nhiyoyna\n44444* 12494\n5105\n': ['T12_29_recto'],
#  'apeee': ['T12_29_recto'],
#  'cenen': ['T12_29_recto'],
#  'hiyoyna': ['T12_29_recto'],
#  '44444*': ['T12_29_recto'],
#  '12494': ['T12_29_recto'],
#  '5105': ['T12_29_recto'],
#  'tourism': ['F25_18_recto'],
#  'sky': ['F25_18_recto'],
#  'cloud': ['F25_18_recto'],
#  'soil': ['F25_18_recto'],
#  'landscap': ['F25_18_recto'],
#  'anim': ['F25_18_recto'],
#  'bag': ['F25_18_recto'],
#  'luggag': ['F25_18_recto'],
#  'contain': ['F25_18_recto'],
#  'sit': ['T20_169_recto', 'F20_88_recto'],
#  'famili': ['T20_169_recto'],
#  'pant': ['T20_169_recto'],
#  'なぶつい ー\nニニゴ ten\n': ['T20_169_recto'],
#  'なぶ': ['T20_169_recto'],
#  'つい': ['T20_169_recto'],
#  'ー': ['T20_169_recto'],
#  'ニニゴ': ['T20_169_recto'],
#  'ten': ['T20_169_recto'],
#  'vehicl': ['T14_38_recto'],
#  'truck': ['T14_38_recto'],
#  'portrait': ['F20_88_recto'],
#  'glass': ['F20_88_recto'],
#  'bookcas': ['F20_88_recto'],
#  'paz\n': ['F20_88_recto'],
#  'paz': ['F20_88_recto'],
#  '下\n': ['F25_239_recto'],
#  '下': ['F25_239_recto']}

# %%
annotated_images
# Out:
# {'T61_61_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/78402/canvas.json',
#    'label': 'T61_61_recto',
#    '@type': 'sc:Canvas',
#    'width': 3118,
#    'height': 3851,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/77362/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/8a6b9536f38497fe9d32dec40ec23402.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3118,
#       'height': 3851,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/8a6b9536f38497fe9d32dec40ec23402.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/78402/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '482b6671-edd4-4053-9418-b697fc277dfc'},
#     {'label': 'notes', 'value': 'T61_61_recto'},
#     {'label': 'originalFileName', 'value': 'T61_61_recto.jpg'},
#     {'label': 'filename', 'value': '121.jpg'},
#     {'label': 'fileMD5', 'value': '64f0f355c12b36d7a6029db667923921'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/78402/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'cloth': [[886.6250683665276,
#      1783.3267759084702,
#      997.6463320851326,
#      808.6417447328568],
#     [1691.8676117658615,
#      1287.347108989954,
#      532.7966532707214,
#      508.52698934078217]],
#    'person': [[790.0051105618477,
#      1755.3793244063854,
#      1140.1620196700096,
#      874.7073390185833],
#     [1400.3586224913597,
#      1158.8841589987278,
#      824.1119896769524,
#      1081.1588637530804],
#     [821.58363032341,
#      1788.0964501202106,
#      1090.414512038231,
#      834.9220654666424],
#     [1407.1580311655998,
#      1174.8496389091015,
#      829.6931694149971,
#      1022.2581673562527]]},
#   'landmark_info': {},
#   'country': 'Cambodia'},
#  'Cina9_1_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/81348/canvas.json',
#    'label': 'Cina9_1_recto',
#    '@type': 'sc:Canvas',
#    'width': 3767,
#    'height': 2919,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/80308/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/fe7779812ca1f51abe009484a427e464.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3767,
#       'height': 2919,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/fe7779812ca1f51abe009484a427e464.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/81348/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '00e818b8-31e4-4866-9583-62975e0c99de'},
#     {'label': 'notes', 'value': 'Cina9_1_recto'},
#     {'label': 'originalFileName', 'value': 'Cina9_1_recto.jpg'},
#     {'label': 'filename', 'value': '1.jpg'},
#     {'label': 'fileMD5', 'value': '1d937caf706dc453aff8dcfd30417c54'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/81348/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'build': [[50.18607343453914,
#      51.94862406514585,
#      3620.365418541245,
#      2497.450395355001]]},
#   'landmark_info': {},
#   'country': 'China'},
#  'T12_45_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/67176/canvas.json',
#    'label': 'T12_45_recto',
#    '@type': 'sc:Canvas',
#    'width': 3850,
#    'height': 3114,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/66136/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/7c5a36eb4df4bf9c02ac4ed6668cf5bb.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3850,
#       'height': 3114,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/7c5a36eb4df4bf9c02ac4ed6668cf5bb.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/67176/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'c4b7b5da-8984-44fe-807c-0558a7ae72fa'},
#     {'label': 'notes', 'value': 'T12_45_recto'},
#     {'label': 'originalFileName', 'value': 'T12_45_recto.jpg'},
#     {'label': 'filename', 'value': '89.jpg'},
#     {'label': 'fileMD5', 'value': '446aefeb0cdac4b08676670422142b78'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/67176/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'bench': [[2758.416625857353,
#      1528.1429259181023,
#      911.7615222930908,
#      961.4805495142937]],
#    'person': [[804.7656238079071,
#      1026.3093638420105,
#      450.66667944192886,
#      953.5529165267944],
#     [2315.516510605812,
#      1238.3630361557007,
#      1036.1199468374252,
#      1027.6063985824585]],
#    'footwear': [[2323.340329527855,
#      1784.8903774023056,
#      347.87883162498474,
#      406.09604609012604]],
#    'coat': [[816.174977272749,
#      1106.6626891493797,
#      418.5680590569973,
#      751.150626718998]]},
#   'landmark_info': {},
#   'country': None},
#  'T31_30_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/69518/canvas.json',
#    'label': 'T31_30_recto',
#    '@type': 'sc:Canvas',
#    'width': 3642,
#    'height': 4586,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/68478/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/fb2d9b8d428d57d332c385caefde506b.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3642,
#       'height': 4586,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/fb2d9b8d428d57d332c385caefde506b.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/69518/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '78658174-4b34-4802-91e0-53d6e40f6555'},
#     {'label': 'notes', 'value': 'T31_30_recto'},
#     {'label': 'originalFileName', 'value': 'T31_30_recto.jpg'},
#     {'label': 'filename', 'value': '59.jpg'},
#     {'label': 'fileMD5', 'value': '25dbc0b16ac0c2f3d3c02d529b76a4e4'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/69518/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[1784.1323069930077,
#      2403.074610233307,
#      633.0571755766869,
#      1594.264911532402],
#     [2015.5426415205002,
#      1850.1696833968163,
#      398.18311071395874,
#      589.6206092238426],
#     [822.1333598792553,
#      2047.016627252102,
#      399.9399943649769,
#      752.1603302359581],
#     [1731.2264093756676,
#      1951.520153939724,
#      368.70569318532944,
#      854.6998597979546],
#     [689.563618272543,
#      2011.6583855748177,
#      323.316683024168,
#      953.7741706967354]],
#    'cloth': [[1787.5700962543488,
#      2519.2721910476685,
#      628.9234274625778,
#      1466.4779688119888],
#     [2004.3326243162155,
#      1869.054127395153,
#      412.4409327507019,
#      560.5512596964836],
#     [821.0851885378361,
#      2084.250028669834,
#      420.9447749555111,
#      622.4378181099892]],
#    'frame_pictur': [[494.1017509996891,
#      421.4000220745802,
#      2650.8661877810955,
#      3893.061266735196]]},
#   'landmark_info': {},
#   'country': 'Nepal'},
#  'T12_29_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/67144/canvas.json',
#    'label': 'T12_29_recto',
#    '@type': 'sc:Canvas',
#    'width': 3854,
#    'height': 3117,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/66104/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/88c6c0f9bfb4ec5ba01be10025469f66.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3854,
#       'height': 3117,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/88c6c0f9bfb4ec5ba01be10025469f66.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/67144/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '3d238cef-47ae-483f-8021-9e8fe0b5904f'},
#     {'label': 'notes', 'value': 'T12_29_recto'},
#     {'label': 'originalFileName', 'value': 'T12_29_recto.jpg'},
#     {'label': 'filename', 'value': '57.jpg'},
#     {'label': 'fileMD5', 'value': 'd60d4389544da1ff6cea99d153e0e523'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/67144/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'frame_pictur': [[141.49302335828543,
#      159.70662938430905,
#      3583.2529650107026,
#      2719.076224397868]],
#    'apeee cenen\nhiyoyna\n44444* 12494\n5105\n': [[653, 1178, 1970, 1488]],
#    'apeee': [[2494, 1178, 60, 25]],
#    'cenen': [[2566, 1185, 57, 18]],
#    'hiyoyna': [[2521, 1207, 72, 25]],
#    '44444*': [[1328, 1541, 253, 86]],
#    '12494': [[1681, 1579, 154, 50]],
#    '5105': [[686, 2571, 6, 2]]},
#   'landmark_info': {},
#   'country': None},
#  'F25_18_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/65066/canvas.json',
#    'label': 'F25_18_recto',
#    '@type': 'sc:Canvas',
#    'width': 1933,
#    'height': 1458,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/64026/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/80a93fe44a21f0b62a40c7e6fec77d10.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 1933,
#       'height': 1458,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/80a93fe44a21f0b62a40c7e6fec77d10.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/65066/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'fed80d19-e367-4dc1-99bc-9b149fb993b8'},
#     {'label': 'notes', 'value': 'F25_18_recto'},
#     {'label': 'originalFileName', 'value': 'F25_18_recto.jpg'},
#     {'label': 'filename', 'value': '35.jpg'},
#     {'label': 'fileMD5', 'value': '110b89f70d6984d92d8c6776fd81acd4'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/65066/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[1018.3438742160797,
#      904.7550008296967,
#      241.20515370368958,
#      248.29410767555237],
#     [443.7527638077736,
#      807.7699191570282,
#      247.15270739793777,
#      207.66799128055573],
#     [681.0609166324139,
#      970.9074772596359,
#      176.67798095941544,
#      176.42659163475037],
#     [666.3188849687576,
#      752.8370414972305,
#      155.57286989688873,
#      198.24677503108978],
#     [391.474612519145,
#      761.0712418556213,
#      105.8402960151434,
#      218.72994697093964],
#     [1746.1793436408043,
#      683.9960727095604,
#      100.65019965171814,
#      238.12990933656693]],
#    'anim': [[771.138974070549,
#      628.3219075798988,
#      175.7445603311062,
#      141.74411469697952]],
#    'bag_luggag': [[681.3499930202961,
#      973.0025485754013,
#      177.83693647384644,
#      168.86545944213867]],
#    'cloth': [[1001.9467102885246,
#      909.6750465631485,
#      243.08052092790604,
#      257.0328701734543]],
#    'contain': [[1402.877456188202,
#      1079.5708347558975,
#      257.85279673337936,
#      293.433908700943]]},
#   'landmark_info': {},
#   'country': None},
#  'T20_169_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/78248/canvas.json',
#    'label': 'T20_169_recto',
#    '@type': 'sc:Canvas',
#    'width': 3245,
#    'height': 2265,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/77208/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/74b5d17a8235c51098c2addb752a594c.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3245,
#       'height': 2265,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/74b5d17a8235c51098c2addb752a594c.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/78248/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '0db0b417-85b3-4a77-8208-2aecd932e954'},
#     {'label': 'notes', 'value': 'T20_169_recto'},
#     {'label': 'originalFileName', 'value': 'T20_169_recto.jpg'},
#     {'label': 'filename', 'value': '337.jpg'},
#     {'label': 'fileMD5', 'value': '26462b1af598bd83d2ef0efd3a314eb4'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/78248/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[640.3364721685648,
#      650.0676240026951,
#      1207.0095204561949,
#      1456.886634081602],
#     [1451.4222127199173,
#      515.7486902922392,
#      1206.1297145485878,
#      1572.3790524154902],
#     [302.26197365671396,
#      638.3718448877335,
#      1016.7991339787841,
#      1458.600043952465]],
#    'cloth': [[1455.7285471260548,
#      574.7958536446095,
#      1212.3309560120106,
#      1498.4766666591167]],
#    'pant': [[626.6780354827642,
#      674.0536746382713,
#      1194.7376907616854,
#      1422.241571545601]],
#    'なぶつい ー\nニニゴ ten\n': [[2151, 1063, 303, 509]],
#    'なぶ': [[2320, 1566, 17, 7]],
#    'つい': [[2338, 1475, 12, 7]],
#    'ー': [[2412, 1081, 3, 7]],
#    'ニニゴ': [[2281, 1131, 29, 8]],
#    'ten': [[2202, 1449, 8, 3]]},
#   'landmark_info': {},
#   'country': None},
#  'T14_38_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/68054/canvas.json',
#    'label': 'T14_38_recto',
#    '@type': 'sc:Canvas',
#    'width': 3844,
#    'height': 3108,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/67014/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/52eb2bf4ca6d22622aba2bd917001f44.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3844,
#       'height': 3108,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/52eb2bf4ca6d22622aba2bd917001f44.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/68054/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'cebe7ff3-4613-4a9c-b837-83700d58dbc6'},
#     {'label': 'notes', 'value': 'T14_38_recto'},
#     {'label': 'originalFileName', 'value': 'T14_38_recto.jpg'},
#     {'label': 'filename', 'value': '75.jpg'},
#     {'label': 'fileMD5', 'value': '6b42e36c3766975eafcb2b162f21251d'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/68054/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'truck': [[1963.6799528598785,
#      1699.4998404979706,
#      786.905953168869,
#      312.0627465248108],
#     [2778.1117260456085,
#      1711.0332119464874,
#      496.80832147598267,
#      297.1233458518982]]},
#   'landmark_info': {},
#   'country': 'Laos'},
#  'F20_88_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/63398/canvas.json',
#    'label': 'F20_88_recto',
#    '@type': 'sc:Canvas',
#    'width': 2011,
#    'height': 3131,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/62358/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/cefdfe45f24a813d926cd8720d65cbfc.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2011,
#       'height': 3131,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/cefdfe45f24a813d926cd8720d65cbfc.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/63398/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'e7cb81f1-1d9c-4821-8ba7-e87c9d1a7caa'},
#     {'label': 'notes', 'value': 'F20_88_recto'},
#     {'label': 'originalFileName', 'value': 'F20_88_recto.jpg'},
#     {'label': 'filename', 'value': '175.jpg'},
#     {'label': 'fileMD5', 'value': '2bbaa7503474f7e3f547268dfccae6af'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/63398/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'glass': [[699.0843977034092,
#      1405.0336970090866,
#      456.01220241189003,
#      231.19908106327057]],
#    'person': [[69.31348264589906,
#      1090.3343639075756,
#      1744.1729482971132,
#      1959.2793463766575],
#     [103.7407987266779,
#      1070.30439594388,
#      1688.3698776215315,
#      1961.5484850108624]],
#    'bookcas': [[359.8163023740053,
#      629.0954518765211,
#      1460.5726710408926,
#      1381.8852263838053]],
#    'cloth': [[87.95929074287415,
#      1305.0582555830479,
#      1556.6844258904457,
#      1687.4083953797817]],
#    'paz\n': [[667, 488, 138, 94]],
#    'paz': [[669, 488, 136, 91]]},
#   'landmark_info': {},
#   'country': None},
#  'F25_239_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/65506/canvas.json',
#    'label': 'F25_239_recto',
#    '@type': 'sc:Canvas',
#    'width': 2445,
#    'height': 3145,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/64466/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/71236606becbe7b5904a9f2197aac4a7.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2445,
#       'height': 3145,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/71236606becbe7b5904a9f2197aac4a7.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/65506/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '6765cfc6-caf2-4ad8-9f6c-805167af1b2c'},
#     {'label': 'notes', 'value': 'F25_239_recto'},
#     {'label': 'originalFileName', 'value': 'F25_239_recto.jpg'},
#     {'label': 'filename', 'value': '475.jpg'},
#     {'label': 'fileMD5', 'value': '00e377ef1f0bfbdb6e7288cc8aaa59f1'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/65506/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[787.3294861614704,
#      623.3150128275156,
#      604.347558170557,
#      2086.2780245393515],
#     [937.7786283195019,
#      1132.6273523271084,
#      992.2808633744717,
#      1856.2805296480656],
#     [42.467342214658856,
#      732.7527428418398,
#      299.2932272236794,
#      1290.8216556161642],
#     [113.37065057829022,
#      823.4114916622639,
#      343.3274125121534,
#      1321.1505882441998],
#     [371.8122448772192,
#      835.765725672245,
#      525.2649515122175,
#      1493.9440590143204],
#     [922.9904817044735,
#      1084.8857159912586,
#      979.2039178311825,
#      1897.8031055629253]],
#    'cloth': [[230.9160153195262,
#      1073.146808296442,
#      221.41492914408445,
#      497.36399590969086],
#     [73.36410717107356,
#      848.5698555409908,
#      266.63053832016885,
#      666.7212933301926],
#     [802.1792051196098,
#      1455.4993331432343,
#      530.1008579134941,
#      1190.6109616160393],
#     [65.09828425012529,
#      1471.5168441832066,
#      187.46620257385075,
#      506.00827619433403]],
#    '下\n': [[1703, 888, 86, 65]],
#    '下': [[1790, 892, 3, 4]]},
#   'landmark_info': {},
#   'country': None}}

# %%
with open('tagged_images.json', 'w') as fp:
    json.dump(tagged_images, fp, indent=4)
    
with open('annotated_images.json', 'w') as fp:
    json.dump(annotated_images, fp, indent=4)

if len(failed_images) > 0:
    print("There are failed images")
    with open('failed_images.json', 'w') as fp:
        json.dump(failed_images, fp, indent=4)

# %% [markdown]
# ## Inserting the data into Mangodb
#
# # TODO: The insert the data into database.

# %%
# creating a client to work with mango db
mangoclient = pymongo.MongoClient(MANGO_CLIENT_URI)
# selecting the <terzani_photos> database
mango_db = mangoclient["terzani_photos"]

# %% [markdown]
# ### Storing the Image Tags

# %%
# creating a new collection named <sample_tagging>
mango_tag_collection = mango_db["sample_taggings"]
# inserting the dictionary into the db
for tag, img_labels in tagged_images.items():
    mango_tag_collection.insert_one({"tag":tag,"images":img_labels})

# %% [markdown]
# ### Storing the Image information

# %%
# creating a new collection named <sample_annotations>
mango_box_collection = mango_db["sample_annotations"]
# inserting the dictionary into the db
for img_label, annotation in annotated_images.items():
    mango_box_collection.insert_one({"label":img_label,"annotation":annotation})
