# %% [markdown]
# # Image annotation script

# %% [markdown]
# This notebook will serve as a prototype to create a script to annotate all the images of Terzani collection

# %% [markdown]
# ## Installing the client library
#
# If the Google cloud vision library is not installed already, install it.
#
# If you have python environment use
#
# ```shell
# pip install --upgrade google-cloud-vision
# ```
#
# If you have conda environment use
#
# ```shell
# conda install -c conda-forge google-cloud-vision
# ```

# %% [markdown]
# ## Installing other libraries
#
# Install `dotenv` to get the environment variables
#
# If you have python environment use
#
# ```shell
# pip install python-dotenv
# ```
#
# If you have conda environment use
#
# ```shell
# conda install -c conda-forge python-dotenvn
# ```
#
# pip install python-dotenv

# %% [markdown]
# ## Import the libraries

# %%
## Import the standard libraries
import os, io, pickle, random, json
## Import Vison API related libraries
from google.cloud import vision
from google.cloud.vision import types
## Import dotenv library to get environment variables
from dotenv import load_dotenv
# Import urllib to read images
import urllib.request as ur
# Import pymango to inset data into mangodb
import pymongo
from tqdm import tqdm
# 
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
import nltk
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Maxime\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Setup the service account credentials to use the API

# %%
load_dotenv()

GOOGLE_APPLICATION_CREDENTIALS = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = GOOGLE_APPLICATION_CREDENTIALS

MANGO_CLIENT_URI = os.getenv('MONGO_URI')
os.environ['MANGO_CLIENT_URI'] = MANGO_CLIENT_URI

# %% [markdown]
# ## Creation of Client to access the API

# %%
client = vision.ImageAnnotatorClient()

# %% [markdown]
# ## Image selection
#
# As this is a prototyping script we shall select 10 images randomly each from the color and monochrome photos (using the already created pickle files).

# %% [markdown]
# Generic class to store an image and its IIIF representation

# %%
class Terzani_Photo(object):
    def __init__(self, iiif, country):
        self.iiif = iiif
        self.photo = country
        
    def get_photo_link(self):
        return self.iiif["images"][0]["resource"]["@id"]

# %%
nu_of_images_per_type = 40

'''
# loading the color photos
color_photos = pickle.load(open("terzani_recto_iiif_color.pickle", "rb" ))
# randomly selecting 10 images
color_photos = random.sample(color_photos, nu_of_images_per_type)

# loading the monochrome photos
bw_photos = pickle.load(open("terzani_recto_iiif_color.pickle", "rb" ))
# randomly selecting 10 images
bw_photos = random.sample(bw_photos, nu_of_images_per_type)

all_photos = color_photos + bw_photos

'''

all_photos = pickle.load(open("terzani_recto_iiif.pickle", "rb"))
all_photos = random.sample(all_photos, nu_of_images_per_type)
print(all_photos)
# Out:
# [<__main__.Terzani_Photo object at 0x000002678212F5B0>, <__main__.Terzani_Photo object at 0x0000026780598580>, <__main__.Terzani_Photo object at 0x0000026780733DF0>, <__main__.Terzani_Photo object at 0x00000267830C8280>, <__main__.Terzani_Photo object at 0x00000267823DEA00>, <__main__.Terzani_Photo object at 0x00000267811204C0>, <__main__.Terzani_Photo object at 0x00000267FFFC6A00>, <__main__.Terzani_Photo object at 0x0000026780416D30>, <__main__.Terzani_Photo object at 0x000002678022CB20>, <__main__.Terzani_Photo object at 0x0000026780089070>, <__main__.Terzani_Photo object at 0x0000026781180A30>, <__main__.Terzani_Photo object at 0x00000267FF63F3D0>, <__main__.Terzani_Photo object at 0x00000267809392E0>, <__main__.Terzani_Photo object at 0x0000026780D61A00>, <__main__.Terzani_Photo object at 0x00000267805D6D60>, <__main__.Terzani_Photo object at 0x0000026781AD5880>, <__main__.Terzani_Photo object at 0x0000026782093F40>, <__main__.Terzani_Photo object at 0x0000026780B91D30>, <__main__.Terzani_Photo object at 0x00000267809396A0>, <__main__.Terzani_Photo object at 0x0000026781256490>, <__main__.Terzani_Photo object at 0x0000026781416EE0>, <__main__.Terzani_Photo object at 0x0000026781180490>, <__main__.Terzani_Photo object at 0x00000267815E8940>, <__main__.Terzani_Photo object at 0x0000026781256610>, <__main__.Terzani_Photo object at 0x00000267820AFBE0>, <__main__.Terzani_Photo object at 0x00000267828F5D30>, <__main__.Terzani_Photo object at 0x00000267816B7F70>, <__main__.Terzani_Photo object at 0x0000026780E6CB20>, <__main__.Terzani_Photo object at 0x00000267832CCBB0>, <__main__.Terzani_Photo object at 0x00000267811205E0>, <__main__.Terzani_Photo object at 0x00000267819035B0>, <__main__.Terzani_Photo object at 0x0000026780C7ECD0>, <__main__.Terzani_Photo object at 0x000002678174A3A0>, <__main__.Terzani_Photo object at 0x0000026781479820>, <__main__.Terzani_Photo object at 0x0000026781AE1C40>, <__main__.Terzani_Photo object at 0x0000026780143C40>, <__main__.Terzani_Photo object at 0x0000026780FF6190>, <__main__.Terzani_Photo object at 0x0000026781AE1580>, <__main__.Terzani_Photo object at 0x00000267805D6340>, <__main__.Terzani_Photo object at 0x0000026782109400>]

# %% [markdown]
# ## Function to clean text

# %%
def clean_text(text: str, lower: bool=True, rmv_punc: bool = True, stem: bool = True, norm: bool = True):
    """
    This function accepts a string and performs preprocessing steps on it. 
    
    :param text (str): The string or text on which the preprocessing has to be performed.
    :param lower (bool): Default=True, indicates if the text has to be made into lower case.
    :param rmv_punc (bool): Default=True, indicates if the punctuation should be removed in the text.
    :param stem (bool): Default=True, indicates if the stemming should be performed on the words in the text.
    :param norm (bool): Default=True, indicates if the words in the has to be normalised.
    :return cleaned_text (list): The modified text is returned as list after performing the indicated operations.
    """
    
    # split into words
    tokens = word_tokenize(text)
    if lower:
        # convert to lower case
        tokens = [w.lower() for w in tokens]
    if rmv_punc:
        # remove punctuation from each word
        table = str.maketrans('', '', string.punctuation)
        tokens = [w.translate(table) for w in tokens if w.translate(table) != '']
    if stem:
        # stemming of words
        porter = PorterStemmer()
        tokens = [porter.stem(word) for word in tokens]
    cleaned_text = sorted(list(set(tokens)),key=str.lower)
    return cleaned_text

# %% [markdown]
# ## Calling the Vision API
#
# The structure of tagged images will be
# ```json
# {'tag1': [label_1],
#  'tag2': [label_2, label_4],
#  'tag3': [label_3],
#  'tag4': [label_3]
# }
# ```
#
# The structure of annotated_images will be
# ```json
# {'label_1':
#     {
#     'iiif': IIIF ANNOTATION,
#     'obj_boxes':
#     {
#     frozenset({'tag1'}): [[x1, y1, w1, h1]],
#     frozenset({'tag2'}): [[x4, y4, w4, h4], [x2, y2, w2, h2], [x3, y3, w3, h3]],
#     frozenset({'tag3', 'tag4'}): [[x5, y5, w5, h5], [x6, y6, w6, h6], [x7, y7, w7, h7]]
#     },
#     'landmark_info':
#     {
#     'landmark1_name':{"latitude":la1, "longitude":lt1},
#     'landmark2_name':{"latitude":la2, "longitude":lt2}
#     },
#     'country': None
#     },
# 'label_2':
#     {
#     'iiif': IIIF ANNOTATION,
#     'obj_boxes':
#     {
#     frozenset({'tag4'}): [[x1, y1, w1, h1]],
#     frozenset({'tag5'}): [[x4, y4, w4, h4],],
#     frozenset({'tag6'}): [[x5, y5, w5, h5], [x6, y6, w6, h6]]
#     },
#     'landmark_info':
#     {
#     'landmark3_name':{"latitude":la3, "longitude":lt3},
#     'landmark4_name':{"latitude":la4, "longitude":lt4}
#     },
#     'country': None
#     }
# }
# ```

# %%
tagged_images = dict() # The keys would be the tags, entities and objects found in the annotation and the values would be the image labels.
annotated_images = dict() # The keys would be the image labels and the values will be the IIIF annotation, name of the country, lat,lon if there is geotag and object localization.
failed_images = dict() # We store information about images that are failed to be annotated by google api.

for img in tqdm(all_photos):

    # if the image is already not present in the either annotated and failed dictionaries
    if img.iiif["label"] not in annotated_images and img.iiif["label"] not in failed_images:

        # get the image label
        img_lbl = img.iiif["label"]
        img_country = img.country
                
        # reading the image
        image_data = ur.urlopen(img.get_photo_link()).read()
        image = types.Image(content=image_data)
        
        # call the goole vision api to get the annotations of various types
        response = client.annotate_image({
            'image': image,
            'features': [{'type': vision.enums.Feature.Type.LANDMARK_DETECTION}, 
                         {'type': vision.enums.Feature.Type.LOGO_DETECTION},
                         {'type': vision.enums.Feature.Type.LABEL_DETECTION},
                         {'type': vision.enums.Feature.Type.TEXT_DETECTION},
                         {'type': vision.enums.Feature.Type.OBJECT_LOCALIZATION},
                         {'type': vision.enums.Feature.Type.WEB_DETECTION}],})
        
        # check if there is any error returned by the api
        if response.error.code != 0:
            failed_images[img_lbl] = {}
            failed_images[img_lbl]["error"] = [response.error.code, response.error.message]
        else:
            # if the API call is successful
            annotated_images[img_lbl] = {}
        
            # store the iiif description
            annotated_images[img_lbl]["iiif"] = img.iiif

            # get the list of labels
            labels = list()
            for lbl in response.label_annotations:
                labels.extend(clean_text(lbl.description))
            labels = list(set(labels))
            
            # Add the label and image label to the dictionary to perform search
            for label in labels:
                if label not in tagged_images:
                    tagged_images[label] = []
                if img_lbl not in tagged_images[label]:
                    tagged_images[label].append(img_lbl)
            
            # get the list of web entities
            webent = list()
            for weben in response.web_detection.web_entities:
                webent.extend(clean_text(weben.description))
            webent = list(set(webent))
            
            # Add the web entity and image label to the dictionary to perform search
            for web_entity in labels:
                if web_entity not in tagged_images:
                    tagged_images[web_entity] = []
                if img_lbl not in tagged_images[web_entity]:
                    tagged_images[web_entity].append(img_lbl)
            

            obj_boxes = {} # this dictionary will store the information of annotations along with bounding boxes.
            # The key will the the name to identify the annotation and the value be a list of lists containing the top left x coordinate
            # top left y coordinate, width and height of for the bounding box.
            # It would be a list of list to store coordinates for different boxes for same tag

            # storing the landmarks
            landmark_info = dict() # this dictionary will store the information of landmarks which are name, latitude, longitude.
            for lndmk in response.landmark_annotations:
                print("landmark detected !")
                # if there are any landamrks identified, we store them in a seperate field,to access easily.
                landmark_name = lndmk.description.lower()
                landmark_info[landmark_name] = {"latitude":lndmk.locations[0].lat_lng.latitude, "longitude":lndmk.locations[0].lat_lng.longitude}
                
                
                lndmks = clean_text(lndmk.description)
                # we add the landmarks and image label to the dictionary to perform search
                for land_mark in lndmks:
                    if land_mark not in tagged_images:
                        tagged_images[land_mark] = []
                    if img_lbl not in tagged_images[land_mark]:
                        tagged_images[land_mark].append(img_lbl)
                
                # storing the landmarks with bounding boxes 
                lndmk_desc = '_'.join(lndmks)
                '_'.join(lndmks)
                if lndmk_desc not in obj_boxes:
                    obj_boxes[lndmk_desc] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lndmk.bounding_poly.vertices[0].x, lndmk.bounding_poly.vertices[0].y
                box_width = lndmk.bounding_poly.vertices[1].x - lndmk.bounding_poly.vertices[0].x
                box_height = lndmk.bounding_poly.vertices[3].y - lndmk.bounding_poly.vertices[0].y
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height] 
                    obj_boxes[lndmk_desc].append(vert)    

            for lgo in response.logo_annotations:
                
                logos = clean_text(lgo.description)
                # we add the logo names and image label to the dictionary to perform search
                for lgo_name in logos:
                    if lgo_name not in tagged_images:
                        tagged_images[lgo_name] = []
                    if img_lbl not in tagged_images[lgo_name]:
                        tagged_images[lgo_name].append(img_lbl)
                        
                lgo_desc = '_'.join(logos)
                if lgo_desc not in obj_boxes:
                    obj_boxes[lgo_desc] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lgo.bounding_poly.vertices[0].x, lgo.bounding_poly.vertices[0].y
                box_width = abs(lgo.bounding_poly.vertices[1].x - lgo.bounding_poly.vertices[0].x)
                box_height = abs(lgo.bounding_poly.vertices[3].y - lgo.bounding_poly.vertices[0].y)
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[lgo_desc].append(vert)

            if len(response.localized_object_annotations) > 0:
                img_width, img_height = img.iiif["width"], img.iiif["height"]
            for lobj in response.localized_object_annotations:
                
                objects = clean_text(lobj.name)  
                # we add the object names and image label to the dictionary to perform search
                for obj_name in objects:
                    if obj_name not in tagged_images:
                        tagged_images[obj_name] = []
                    if img_lbl not in tagged_images[obj_name]:
                        tagged_images[obj_name].append(img_lbl)
                
                lobj_name = '_'.join(objects)
                if lobj_name not in obj_boxes:
                    obj_boxes[lobj_name] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lobj.bounding_poly.normalized_vertices[0].x * img_width, lobj.bounding_poly.normalized_vertices[0].y * img_height
                box_width = (lobj.bounding_poly.normalized_vertices[1].x - lobj.bounding_poly.normalized_vertices[0].x) * img_width
                box_height = (lobj.bounding_poly.normalized_vertices[3].y - lobj.bounding_poly.normalized_vertices[0].y) * img_height
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[lobj_name].append(vert)

            for txt in response.text_annotations:
                modified_text = txt.description.replace(".", "_").lower()
                # we add the text and image label to the dictionary to perform search
                if modified_text not in tagged_images:
                    tagged_images[modified_text] = []
                if img_lbl not in tagged_images[modified_text]:
                        tagged_images[modified_text].append(img_lbl)    
                
                # the text identified on the images in not cleaned to store the original information.
                if modified_text not in obj_boxes:
                    obj_boxes[modified_text] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = txt.bounding_poly.vertices[0].x, txt.bounding_poly.vertices[0].y
                box_width = abs(txt.bounding_poly.vertices[1].x - txt.bounding_poly.vertices[0].x)
                box_height = abs(txt.bounding_poly.vertices[3].y - txt.bounding_poly.vertices[0].y)
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[modified_text].append(vert)

            # store the generated object boxes into the dictionary.
            annotated_images[img_lbl]["obj_boxes"] = obj_boxes
            
            # store the generated land mark information into the dictionary.
            if landmark_info != dict():
                annotated_images[img_lbl]["landmark_info"] = landmark_info
            
            # store the generated land mark information into the dictionary.
            annotated_images[img_lbl]["country"] = img_country
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 40/40 [02:58<00:00,  4.46s/it]

# %% [markdown]
# ## Saving the dictionaries to JSON file

# %%
tagged_images
# Out:
# {'photograph': ['T6_65_recto',
#   'T4_63_recto',
#   'T14_152_recto',
#   'T35_167_recto',
#   'T14_74_recto',
#   'T6_169_recto',
#   'T36_59_recto',
#   'F27_85_recto',
#   'T42_205_recto',
#   'T48_106_recto',
#   'T10_152_recto',
#   'T60_169_recto',
#   'T11_191_recto',
#   'F20_102_recto',
#   'T42_215_recto',
#   'Cina8_360_recto',
#   'Cina8_107_recto',
#   'F27_70_recto',
#   'Cina8_364_recto',
#   'T63_69_recto',
#   'F22_49_recto',
#   'F20_444_recto',
#   'Cina6_9_recto',
#   'T34_40_recto',
#   'T36_20_recto',
#   'T10_173_recto',
#   'T10_125_recto',
#   'T12_43_recto'],
#  'blackandwhit': ['T6_65_recto',
#   'T4_63_recto',
#   'T14_152_recto',
#   'T35_167_recto',
#   'T14_74_recto',
#   'Cina5_123_recto',
#   'T6_169_recto',
#   'T36_59_recto',
#   'F26_57_recto',
#   'F27_85_recto',
#   'F27_110_recto',
#   'T42_205_recto',
#   'T48_106_recto',
#   'T10_152_recto',
#   'T60_169_recto',
#   'T11_191_recto',
#   'T42_215_recto',
#   'Cina8_107_recto',
#   'F27_70_recto',
#   'T55_13_recto',
#   'Cina8_364_recto',
#   'T63_69_recto',
#   'F22_49_recto',
#   'Cina6_9_recto',
#   'T14_77_recto',
#   'T34_40_recto',
#   'T11_13_recto',
#   'T36_20_recto',
#   'F56_33_recto',
#   'T10_173_recto',
#   'T10_125_recto',
#   'T12_43_recto'],
#  'photographi': ['T6_65_recto',
#   'T4_63_recto',
#   'T14_152_recto',
#   'T35_167_recto',
#   'T14_74_recto',
#   'Cina5_123_recto',
#   'T6_169_recto',
#   'T36_59_recto',
#   'F26_57_recto',
#   'F27_85_recto',
#   'F27_110_recto',
#   'T42_205_recto',
#   'T48_106_recto',
#   'T10_152_recto',
#   'T60_169_recto',
#   'T11_191_recto',
#   'F20_102_recto',
#   'T42_215_recto',
#   'Cina8_360_recto',
#   'Cina8_107_recto',
#   'F27_70_recto',
#   'T55_13_recto',
#   'Cina8_364_recto',
#   'T63_69_recto',
#   'F22_49_recto',
#   'F20_444_recto',
#   'Cina6_9_recto',
#   'F20_182_recto',
#   'T14_77_recto',
#   'F20_334_recto',
#   'F56_21_recto',
#   'T34_40_recto',
#   'T11_13_recto',
#   'T36_20_recto',
#   'F56_33_recto',
#   'T10_173_recto',
#   'T10_125_recto',
#   'T12_43_recto'],
#  'photo': ['T6_65_recto', 'T14_152_recto'],
#  'snapshot': ['T6_65_recto',
#   'T4_63_recto',
#   'T14_152_recto',
#   'T35_167_recto',
#   'T14_74_recto',
#   'T6_169_recto',
#   'T36_59_recto',
#   'F26_57_recto',
#   'F27_85_recto',
#   'T42_205_recto',
#   'T48_106_recto',
#   'T60_169_recto',
#   'T11_191_recto',
#   'F20_102_recto',
#   'T42_215_recto',
#   'Cina8_360_recto',
#   'Cina8_107_recto',
#   'F27_70_recto',
#   'Cina8_364_recto',
#   'T63_69_recto',
#   'F22_49_recto',
#   'F20_444_recto',
#   'Cina6_9_recto',
#   'T14_77_recto',
#   'F20_334_recto',
#   'T34_40_recto',
#   'T36_20_recto',
#   'T10_173_recto',
#   'T10_125_recto',
#   'T12_43_recto'],
#  'poster': ['T6_65_recto', 'T6_169_recto'],
#  'stock': ['T6_65_recto',
#   'T4_63_recto',
#   'T14_152_recto',
#   'T35_167_recto',
#   'T14_74_recto',
#   'T6_169_recto',
#   'T36_59_recto',
#   'F26_57_recto',
#   'T42_205_recto',
#   'T10_152_recto',
#   'T60_169_recto',
#   'T11_191_recto',
#   'Cina8_107_recto',
#   'T55_13_recto',
#   'Cina8_364_recto',
#   'T63_69_recto',
#   'F22_49_recto',
#   'F20_444_recto',
#   'Cina6_9_recto',
#   'F20_182_recto',
#   'F20_334_recto',
#   'F56_21_recto',
#   'T34_40_recto',
#   'T11_13_recto',
#   'T36_20_recto',
#   'F56_33_recto',
#   'T10_173_recto'],
#  'caption': ['T6_65_recto', 'T14_152_recto'],
#  'art': ['T6_65_recto',
#   'F26_57_recto',
#   'F56_21_recto',
#   'T11_13_recto',
#   'T36_20_recto',
#   'F56_33_recto',
#   'T10_173_recto'],
#  'person': ['T6_65_recto',
#   'T42_1_recto',
#   'T14_152_recto',
#   'T35_167_recto',
#   'T14_74_recto',
#   'T6_169_recto',
#   'T36_59_recto',
#   'F26_57_recto',
#   'T42_205_recto',
#   'T48_106_recto',
#   'T60_169_recto',
#   'T11_191_recto',
#   'F20_102_recto',
#   'T42_215_recto',
#   'Cina8_360_recto',
#   'Cina8_107_recto',
#   'F27_70_recto',
#   'T55_13_recto',
#   'Cina8_364_recto',
#   'T63_69_recto',
#   'F22_49_recto',
#   'F20_444_recto',
#   'Cina6_9_recto',
#   'F20_334_recto',
#   'T20_109_recto',
#   'T36_20_recto',
#   'T10_173_recto'],
#  'वि बचाओंँ आन्दालग\nिहरी\nगढ़वाल\nा्य वा\n': ['T6_65_recto'],
#  'वि': ['T6_65_recto'],
#  'बचाओंँ': ['T6_65_recto'],
#  'आन्दालग': ['T6_65_recto'],
#  'िहरी': ['T6_65_recto'],
#  'गढ़वाल': ['T6_65_recto'],
#  'ा्य': ['T6_65_recto'],
#  'वा': ['T6_65_recto'],
#  'offic': ['T42_1_recto', 'F22_49_recto'],
#  'militari': ['T42_1_recto', 'F22_49_recto'],
#  'vehicl': ['T42_1_recto',
#   'T48_106_recto',
#   'T11_191_recto',
#   'Cina8_360_recto'],
#  'noncommiss': ['T42_1_recto'],
#  'uniform': ['T42_1_recto', 'F22_49_recto'],
#  'tank': ['T42_1_recto'],
#  'armi': ['T42_1_recto'],
#  'combat': ['T42_1_recto'],
#  '40\nmay\n72\n': ['T42_1_recto'],
#  '40': ['T42_1_recto'],
#  'may': ['T42_1_recto'],
#  '72': ['T42_1_recto'],
#  'black': ['T4_63_recto', 'Cina6_9_recto', 'T34_40_recto', 'T10_125_recto'],
#  'monochrom': ['T4_63_recto',
#   'T14_152_recto',
#   'T35_167_recto',
#   'Cina5_123_recto',
#   'T6_169_recto',
#   'T36_59_recto',
#   'F26_57_recto',
#   'F27_85_recto',
#   'F27_110_recto',
#   'T42_205_recto',
#   'T10_152_recto',
#   'T60_169_recto',
#   'T11_191_recto',
#   'Cina8_360_recto',
#   'Cina8_107_recto',
#   'F27_70_recto',
#   'T55_13_recto',
#   'Cina8_364_recto',
#   'T63_69_recto',
#   'F22_49_recto',
#   'Cina6_9_recto',
#   'T14_77_recto',
#   'T34_40_recto',
#   'T11_13_recto',
#   'T36_20_recto',
#   'T10_125_recto',
#   'T12_43_recto'],
#  'white': ['T4_63_recto',
#   'T35_167_recto',
#   'F27_85_recto',
#   'T10_125_recto',
#   'T12_43_recto'],
#  'room': ['T4_63_recto',
#   'T14_74_recto',
#   'T42_215_recto',
#   'T34_40_recto',
#   'T11_13_recto'],
#  'frame': ['T4_63_recto',
#   'T14_74_recto',
#   'T10_152_recto',
#   'T55_13_recto',
#   'T11_13_recto',
#   'T36_20_recto',
#   'F56_33_recto',
#   'T10_125_recto',
#   'T12_43_recto'],
#  'pictur': ['T4_63_recto',
#   'T14_74_recto',
#   'T10_152_recto',
#   'T55_13_recto',
#   'T11_13_recto',
#   'T36_20_recto',
#   'F56_33_recto',
#   'T10_125_recto',
#   'T12_43_recto'],
#  'adapt': ['T14_152_recto',
#   'F26_57_recto',
#   'T60_169_recto',
#   'T55_13_recto',
#   'Cina8_364_recto',
#   'F20_444_recto',
#   'F20_334_recto'],
#  'style': ['T14_152_recto',
#   'T36_59_recto',
#   'F27_110_recto',
#   'Cina8_360_recto',
#   'T14_77_recto'],
#  'tabl': ['T14_152_recto', 'T20_109_recto'],
#  'top': ['T14_152_recto', 'F26_57_recto'],
#  'cloth': ['T14_152_recto',
#   'F26_57_recto',
#   'T42_205_recto',
#   'T42_215_recto',
#   'Cina8_107_recto',
#   'T55_13_recto',
#   'Cina8_364_recto',
#   'F20_444_recto'],
#  'portrait': ['T35_167_recto', 'T60_169_recto'],
#  'stand': ['T35_167_recto',
#   'T14_74_recto',
#   'T42_205_recto',
#   'F27_70_recto',
#   'Cina8_364_recto',
#   'T63_69_recto'],
#  'outerwear': ['T35_167_recto'],
#  'hous': ['T14_74_recto', 'T36_59_recto', 'T48_106_recto', 'T14_77_recto'],
#  'pant': ['T14_74_recto', 'F22_49_recto'],
#  '379\n': ['T14_74_recto'],
#  '379': ['T14_74_recto'],
#  'text': ['Cina5_123_recto', 'T6_169_recto', 'F27_85_recto'],
#  'paper': ['Cina5_123_recto', 'T12_43_recto'],
#  'font': ['Cina5_123_recto', 'T6_169_recto', 'F56_21_recto'],
#  'anim': ['Cina5_123_recto',
#   'T6_169_recto',
#   'T36_59_recto',
#   'Cina6_9_recto',
#   'T12_43_recto'],
#  '和り也是啡了处我的 不是这方吃三就是那5哈\n立结片乡阳时,在要订好南法楚楚。\n有到,特好论切制时,也们各种码式的那台佳f4低活及4 经片会同時要法意些什么间题\nを,中斗台有台业生,在差一个多种维 成的的首在,多层大的能\n名建构,我d舞第的计划统片的前程1_要发样不的调有\n林作图,发展南品海請冰的约故动法外, 大青四\n素性片名间自争现,達新老未同容利有打一个统-送街的德\n同法律头加两uz(t42间有子型 -定代,\n《化,坚决打去反为\n三主危者社会\n該好紀、場\n要分子\n成会分\nそ和\n依法严惩严重危害社会治安的犯罪\n杀人罪犯陈立波、抢劫杀人罪犯陈志明被判死刑\n:继续整\n技。要里,\n設的连法死\n侍、流很团\n最像帶和地\nに統和方去\n罪活動,\n群众,使\n支。\ne e/6 r rarm*\naeran naterer\nroes\nancrr2ee\n3)通过人\n香!\n_ e s r\nseafon\nserso perar\nter 2l pee\nam ee c\n:_blr\n19bz\nsansr narar\n戈火犯罪\n白\n二,\n_ rarrca\n城 锁科\nww_w\n': ['Cina5_123_recto'],
#  '和': ['Cina5_123_recto'],
#  'り': ['Cina5_123_recto'],
#  '也是': ['Cina5_123_recto'],
#  '啡': ['Cina5_123_recto'],
#  '了': ['Cina5_123_recto'],
#  '处': ['Cina5_123_recto'],
#  '我': ['Cina5_123_recto'],
#  '的': ['Cina5_123_recto'],
#  '不是': ['Cina5_123_recto'],
#  '这': ['Cina5_123_recto'],
#  '方': ['Cina5_123_recto'],
#  '吃': ['Cina5_123_recto'],
#  '三': ['Cina5_123_recto'],
#  '就是': ['Cina5_123_recto'],
#  '那': ['Cina5_123_recto'],
#  '5': ['Cina5_123_recto', 'F56_33_recto'],
#  '哈': ['Cina5_123_recto'],
#  '立': ['Cina5_123_recto'],
#  '结': ['Cina5_123_recto'],
#  '片': ['Cina5_123_recto'],
#  '乡': ['Cina5_123_recto'],
#  '阳': ['Cina5_123_recto'],
#  '时': ['Cina5_123_recto'],
#  ',': ['Cina5_123_recto'],
#  '在': ['Cina5_123_recto'],
#  '要': ['Cina5_123_recto'],
#  '订': ['Cina5_123_recto'],
#  '好': ['Cina5_123_recto'],
#  '南': ['Cina5_123_recto'],
#  '法': ['Cina5_123_recto'],
#  '楚楚': ['Cina5_123_recto'],
#  '。': ['Cina5_123_recto'],
#  '有': ['Cina5_123_recto'],
#  '到': ['Cina5_123_recto'],
#  '特': ['Cina5_123_recto'],
#  '论': ['Cina5_123_recto'],
#  '切': ['Cina5_123_recto'],
#  '制': ['Cina5_123_recto'],
#  '也': ['Cina5_123_recto'],
#  '们': ['Cina5_123_recto'],
#  '各种': ['Cina5_123_recto'],
#  '码': ['Cina5_123_recto'],
#  '式': ['Cina5_123_recto'],
#  '台': ['Cina5_123_recto'],
#  '佳': ['Cina5_123_recto'],
#  'f4': ['Cina5_123_recto'],
#  '低': ['Cina5_123_recto'],
#  '活': ['Cina5_123_recto'],
#  '及': ['Cina5_123_recto'],
#  '4': ['Cina5_123_recto'],
#  '经': ['Cina5_123_recto'],
#  '会': ['Cina5_123_recto'],
#  '同時': ['Cina5_123_recto'],
#  '意': ['Cina5_123_recto'],
#  '些': ['Cina5_123_recto'],
#  '什么': ['Cina5_123_recto'],
#  '间': ['Cina5_123_recto'],
#  '题': ['Cina5_123_recto'],
#  'を': ['Cina5_123_recto'],
#  '中': ['Cina5_123_recto', 'T36_59_recto'],
#  '斗': ['Cina5_123_recto'],
#  '业': ['Cina5_123_recto'],
#  '生': ['Cina5_123_recto', 'F27_70_recto'],
#  '差': ['Cina5_123_recto'],
#  '一个': ['Cina5_123_recto'],
#  '多种': ['Cina5_123_recto'],
#  '维': ['Cina5_123_recto'],
#  '成': ['Cina5_123_recto'],
#  '首': ['Cina5_123_recto'],
#  '多层': ['Cina5_123_recto'],
#  '大': ['Cina5_123_recto'],
#  '能': ['Cina5_123_recto'],
#  '名': ['Cina5_123_recto'],
#  '建构': ['Cina5_123_recto'],
#  'd': ['Cina5_123_recto'],
#  '舞': ['Cina5_123_recto'],
#  '第': ['Cina5_123_recto'],
#  '计划': ['Cina5_123_recto'],
#  '统': ['Cina5_123_recto'],
#  '前程': ['Cina5_123_recto'],
#  '1_': ['Cina5_123_recto'],
#  '发': ['Cina5_123_recto'],
#  '样': ['Cina5_123_recto'],
#  '不': ['Cina5_123_recto'],
#  '调': ['Cina5_123_recto'],
#  '林': ['Cina5_123_recto'],
#  '作图': ['Cina5_123_recto'],
#  '发展': ['Cina5_123_recto'],
#  '品': ['Cina5_123_recto'],
#  '海': ['Cina5_123_recto', 'T36_59_recto'],
#  '請': ['Cina5_123_recto'],
#  '冰': ['Cina5_123_recto'],
#  '约': ['Cina5_123_recto'],
#  '故': ['Cina5_123_recto'],
#  '动': ['Cina5_123_recto'],
#  '外': ['Cina5_123_recto'],
#  '大青': ['Cina5_123_recto'],
#  '四': ['Cina5_123_recto'],
#  '素性': ['Cina5_123_recto'],
#  '片名': ['Cina5_123_recto'],
#  '自': ['Cina5_123_recto'],
#  '争': ['Cina5_123_recto'],
#  '现': ['Cina5_123_recto'],
#  '達': ['Cina5_123_recto'],
#  '新': ['Cina5_123_recto'],
#  '老': ['Cina5_123_recto'],
#  '未': ['Cina5_123_recto'],
#  '同': ['Cina5_123_recto'],
#  '容': ['Cina5_123_recto'],
#  '利': ['Cina5_123_recto'],
#  '打': ['Cina5_123_recto'],
#  '-': ['Cina5_123_recto'],
#  '送': ['Cina5_123_recto'],
#  '街': ['Cina5_123_recto'],
#  '德': ['Cina5_123_recto'],
#  '法律': ['Cina5_123_recto'],
#  '头': ['Cina5_123_recto'],
#  '加': ['Cina5_123_recto'],
#  '两': ['Cina5_123_recto'],
#  'uz': ['Cina5_123_recto'],
#  '(': ['Cina5_123_recto'],
#  't42': ['Cina5_123_recto'],
#  '子': ['Cina5_123_recto'],
#  '型': ['Cina5_123_recto'],
#  '定': ['Cina5_123_recto'],
#  '代': ['Cina5_123_recto'],
#  '《': ['Cina5_123_recto'],
#  '化': ['Cina5_123_recto'],
#  '坚决': ['Cina5_123_recto'],
#  '去': ['Cina5_123_recto'],
#  '反': ['Cina5_123_recto'],
#  '为': ['Cina5_123_recto'],
#  '主': ['Cina5_123_recto'],
#  '危': ['Cina5_123_recto'],
#  '者': ['Cina5_123_recto'],
#  '社会': ['Cina5_123_recto'],
#  '該': ['Cina5_123_recto'],
#  '紀': ['Cina5_123_recto'],
#  '、': ['Cina5_123_recto'],
#  '場': ['Cina5_123_recto'],
#  '分子': ['Cina5_123_recto'],
#  '分': ['Cina5_123_recto'],
#  'そ': ['Cina5_123_recto'],
#  '依法': ['Cina5_123_recto'],
#  '严惩': ['Cina5_123_recto'],
#  '严重': ['Cina5_123_recto'],
#  '危害': ['Cina5_123_recto'],
#  '治安': ['Cina5_123_recto'],
#  '犯罪': ['Cina5_123_recto'],
#  '杀人': ['Cina5_123_recto'],
#  '罪犯': ['Cina5_123_recto'],
#  '陈立波': ['Cina5_123_recto'],
#  '抢劫': ['Cina5_123_recto'],
#  '陈志明': ['Cina5_123_recto'],
#  '被判': ['Cina5_123_recto'],
#  '死刑': ['Cina5_123_recto'],
#  ':': ['Cina5_123_recto'],
#  '继续': ['Cina5_123_recto'],
#  '整': ['Cina5_123_recto'],
#  '技': ['Cina5_123_recto', 'T36_20_recto'],
#  '里': ['Cina5_123_recto'],
#  '設': ['Cina5_123_recto'],
#  '连': ['Cina5_123_recto'],
#  '死': ['Cina5_123_recto'],
#  '侍': ['Cina5_123_recto'],
#  '流': ['Cina5_123_recto'],
#  '很': ['Cina5_123_recto'],
#  '团': ['Cina5_123_recto'],
#  '最': ['Cina5_123_recto'],
#  '像': ['Cina5_123_recto'],
#  '帶': ['Cina5_123_recto'],
#  '地': ['Cina5_123_recto'],
#  'に': ['Cina5_123_recto'],
#  '統': ['Cina5_123_recto'],
#  '罪': ['Cina5_123_recto'],
#  '活動': ['Cina5_123_recto'],
#  '群众': ['Cina5_123_recto'],
#  '使': ['Cina5_123_recto'],
#  '支': ['Cina5_123_recto'],
#  'e': ['Cina5_123_recto', 'T6_169_recto'],
#  'e/6': ['Cina5_123_recto'],
#  'r': ['Cina5_123_recto'],
#  'rarm*': ['Cina5_123_recto'],
#  'aeran': ['Cina5_123_recto'],
#  'naterer': ['Cina5_123_recto'],
#  'roes': ['Cina5_123_recto'],
#  'ancrr2ee': ['Cina5_123_recto'],
#  '3': ['Cina5_123_recto'],
#  ')': ['Cina5_123_recto'],
#  '通过': ['Cina5_123_recto'],
#  '人': ['Cina5_123_recto'],
#  '香': ['Cina5_123_recto'],
#  '!': ['Cina5_123_recto'],
#  '_': ['Cina5_123_recto'],
#  's': ['Cina5_123_recto'],
#  'seafon': ['Cina5_123_recto'],
#  'serso': ['Cina5_123_recto'],
#  'perar': ['Cina5_123_recto'],
#  'ter': ['Cina5_123_recto'],
#  '2l': ['Cina5_123_recto'],
#  'pee': ['Cina5_123_recto'],
#  'am': ['Cina5_123_recto'],
#  'ee': ['Cina5_123_recto'],
#  'c': ['Cina5_123_recto', 'T6_169_recto'],
#  ':_blr': ['Cina5_123_recto'],
#  '19bz': ['Cina5_123_recto'],
#  'sansr': ['Cina5_123_recto'],
#  'narar': ['Cina5_123_recto'],
#  '戈': ['Cina5_123_recto'],
#  '火': ['Cina5_123_recto'],
#  '白': ['Cina5_123_recto'],
#  '二': ['Cina5_123_recto'],
#  'rarrca': ['Cina5_123_recto'],
#  '城': ['Cina5_123_recto'],
#  '锁': ['Cina5_123_recto'],
#  '科': ['Cina5_123_recto'],
#  'ww_w': ['Cina5_123_recto'],
#  'newsprint': ['T6_169_recto'],
#  "ייטיסו\nswaglam\nyou deserve\nthe best\nthe times of india shoirectely\nhotels':\ntours\nmission road manali\nby super deluxe coaches taxis\nsight seeing\nrohtang\nmanali to\ndelhi\nchandigarh\noutdoor roto e\ndharamshala\ndalhousie\njammu leh privale verrole om\nmanikaran shimla\nend lart se'nc news aper\nnaggar\nst seinc newsaper\nrush directely\nआप ततवाता है, या\nhimachal joues\ndirecton\ntogrism de6 v ba:jk estate sh\ntourist infortdation c\nmarali\n": ['T6_169_recto'],
#  'ייטיסו': ['T6_169_recto'],
#  'swaglam': ['T6_169_recto'],
#  'you': ['T6_169_recto'],
#  'deserve': ['T6_169_recto'],
#  'the': ['T6_169_recto'],
#  'best': ['T6_169_recto'],
#  'times': ['T6_169_recto'],
#  'of': ['T6_169_recto', 'T48_106_recto', 'T11_191_recto'],
#  'india': ['T6_169_recto'],
#  'shoirectely': ['T6_169_recto'],
#  "hotels':": ['T6_169_recto'],
#  'tours': ['T6_169_recto'],
#  'mission': ['T6_169_recto'],
#  'road': ['T6_169_recto', 'F27_85_recto'],
#  'manali': ['T6_169_recto'],
#  'by': ['T6_169_recto'],
#  'super': ['T6_169_recto'],
#  'deluxe': ['T6_169_recto'],
#  'coaches': ['T6_169_recto'],
#  'taxis': ['T6_169_recto'],
#  'sight': ['T6_169_recto'],
#  'seeing': ['T6_169_recto'],
#  'rohtang': ['T6_169_recto'],
#  'to': ['T6_169_recto'],
#  'delhi': ['T6_169_recto'],
#  'chandigarh': ['T6_169_recto'],
#  'outdoor': ['T6_169_recto'],
#  'roto': ['T6_169_recto'],
#  'dharamshala': ['T6_169_recto'],
#  'dalhousie': ['T6_169_recto'],
#  'jammu': ['T6_169_recto'],
#  'leh': ['T6_169_recto'],
#  'privale': ['T6_169_recto'],
#  'verrole': ['T6_169_recto'],
#  'om': ['T6_169_recto'],
#  'manikaran': ['T6_169_recto'],
#  'shimla': ['T6_169_recto'],
#  'end': ['T6_169_recto'],
#  'lart': ['T6_169_recto'],
#  "se'nc": ['T6_169_recto'],
#  'news': ['T6_169_recto'],
#  'aper': ['T6_169_recto'],
#  'naggar': ['T6_169_recto'],
#  'st': ['T6_169_recto'],
#  'seinc': ['T6_169_recto'],
#  'newsaper': ['T6_169_recto'],
#  'rush': ['T6_169_recto'],
#  'directely': ['T6_169_recto'],
#  'आप': ['T6_169_recto'],
#  'ततवाता': ['T6_169_recto'],
#  'है,': ['T6_169_recto'],
#  'या': ['T6_169_recto'],
#  'himachal': ['T6_169_recto'],
#  'joues': ['T6_169_recto'],
#  'directon': ['T6_169_recto'],
#  'togrism': ['T6_169_recto'],
#  'de6': ['T6_169_recto'],
#  'v': ['T6_169_recto'],
#  'ba:jk': ['T6_169_recto'],
#  'estate': ['T6_169_recto'],
#  'sh': ['T6_169_recto'],
#  'tourist': ['T6_169_recto'],
#  'infortdation': ['T6_169_recto'],
#  'marali': ['T6_169_recto'],
#  'dog': ['T36_59_recto'],
#  'tire': ['T36_59_recto', 'Cina8_364_recto', 'T14_77_recto', 'F20_334_recto'],
#  'window': ['T36_59_recto', 'T42_205_recto'],
#  'bicycl': ['T36_59_recto', 'Cina8_364_recto', 'T14_77_recto'],
#  '律治\n歌批海耀\n** chua soon hup &\n顺\n雜唐權中\n货洋頭西\n益廣\n乾\n發各\nkwong yik\nprai\nmalaysia\nclose up\ntiger\n7ea\nklim\norion\npra\nmalaysia\n|尊誓糖袖\n|米置育轮\n': ['T36_59_recto'],
#  '律': ['T36_59_recto'],
#  '治': ['T36_59_recto'],
#  '歌': ['T36_59_recto'],
#  '批': ['T36_59_recto'],
#  '耀': ['T36_59_recto'],
#  '**': ['T36_59_recto'],
#  'chua': ['T36_59_recto'],
#  'soon': ['T36_59_recto'],
#  'hup': ['T36_59_recto'],
#  '&': ['T36_59_recto'],
#  '顺': ['T36_59_recto'],
#  '雜': ['T36_59_recto'],
#  '唐': ['T36_59_recto'],
#  '權': ['T36_59_recto'],
#  '货': ['T36_59_recto'],
#  '洋': ['T36_59_recto'],
#  '頭': ['T36_59_recto'],
#  '西': ['T36_59_recto'],
#  '益': ['T36_59_recto'],
#  '廣': ['T36_59_recto'],
#  '乾': ['T36_59_recto'],
#  '發': ['T36_59_recto'],
#  '各': ['T36_59_recto'],
#  'kwong': ['T36_59_recto'],
#  'yik': ['T36_59_recto'],
#  'prai': ['T36_59_recto'],
#  'malaysia': ['T36_59_recto'],
#  'close': ['T36_59_recto'],
#  'up': ['T36_59_recto'],
#  'tiger': ['T36_59_recto'],
#  '7ea': ['T36_59_recto'],
#  'klim': ['T36_59_recto'],
#  'orion': ['T36_59_recto'],
#  'pra': ['T36_59_recto'],
#  '|': ['T36_59_recto'],
#  '尊': ['T36_59_recto'],
#  '誓': ['T36_59_recto'],
#  '糖': ['T36_59_recto'],
#  '袖': ['T36_59_recto'],
#  '米': ['T36_59_recto'],
#  '置': ['T36_59_recto'],
#  '育': ['T36_59_recto'],
#  '轮': ['T36_59_recto'],
#  'furnitur': ['F26_57_recto',
#   'Cina6_9_recto',
#   'T20_109_recto',
#   'T34_40_recto',
#   'T11_13_recto'],
#  'bed': ['F26_57_recto'],
#  'sigigtst\n': ['F26_57_recto'],
#  'sigigtst': ['F26_57_recto'],
#  'tree': ['F27_85_recto',
#   'F27_110_recto',
#   'T10_152_recto',
#   'T55_13_recto',
#   'T63_69_recto'],
#  'architectur': ['F27_85_recto', 'T14_77_recto', 'T34_40_recto'],
#  'candy\nbox\n高級\n300\nb_v_c\n': ['F27_85_recto'],
#  'candy': ['F27_85_recto'],
#  'box': ['F27_85_recto'],
#  '高級': ['F27_85_recto'],
#  '300': ['F27_85_recto'],
#  'b_v_c': ['F27_85_recto'],
#  'water': ['F27_110_recto', 'T55_13_recto', 'T12_43_recto'],
#  'picket': ['F27_110_recto'],
#  'fenc': ['F27_110_recto'],
#  'bridg': ['F27_110_recto'],
#  'flower': ['F27_110_recto'],
#  'lake': ['F27_110_recto'],
#  'lure': ['F27_110_recto'],
#  '來\n塚\nwes\nfodg\n': ['F27_110_recto'],
#  '來': ['F27_110_recto'],
#  '塚': ['F27_110_recto'],
#  'wes': ['F27_110_recto'],
#  'fodg': ['F27_110_recto'],
#  'human': ['T42_205_recto', 'T63_69_recto', 'F20_444_recto'],
#  'street': ['T42_205_recto', 'T11_191_recto', 'T14_77_recto', 'T36_20_recto'],
#  'carriag': ['T48_106_recto'],
#  'buggi': ['T48_106_recto'],
#  'hors': ['T48_106_recto'],
#  'and': ['T48_106_recto'],
#  'wagon': ['T48_106_recto'],
#  'transport': ['T48_106_recto', 'T11_191_recto'],
#  'mode': ['T48_106_recto', 'T11_191_recto'],
#  'cart': ['T48_106_recto'],
#  'sky': ['T10_152_recto', 'T12_43_recto'],
#  'tower': ['T10_152_recto'],
#  'landscap': ['T10_152_recto', 'F20_182_recto'],
#  'poa\n': ['T10_152_recto'],
#  'poa': ['T10_152_recto'],
#  'eyewear': ['T60_169_recto'],
#  'glass': ['T60_169_recto'],
#  'bu': ['T11_191_recto'],
#  'motorcycl': ['T11_191_recto'],
#  'wheel': ['T11_191_recto'],
#  "'heכסב\n": ['T11_191_recto'],
#  "'heכסב": ['T11_191_recto'],
#  'event': ['F20_102_recto', 'T42_215_recto'],
#  'tourism': ['F20_102_recto'],
#  'crowd': ['F20_102_recto'],
#  'fun': ['F20_102_recto', 'F20_444_recto', 'F20_334_recto'],
#  'peopl': ['F20_102_recto', 'F20_444_recto', 'F20_334_recto'],
#  '10\n': ['F20_102_recto'],
#  '10': ['F20_102_recto'],
#  'school': ['T42_215_recto', 'T14_77_recto'],
#  'classroom': ['T42_215_recto'],
#  'class': ['T42_215_recto'],
#  'student': ['T42_215_recto'],
#  'classic': ['Cina8_360_recto'],
#  'retro': ['Cina8_360_recto'],
#  'famili': ['Cina8_360_recto'],
#  'car': ['Cina8_360_recto'],
#  'build': ['Cina8_360_recto', 'T14_77_recto', 'T34_40_recto', 'T10_173_recto'],
#  'hat': ['Cina8_360_recto', 'F22_49_recto', 'T20_109_recto', 'T36_20_recto'],
#  'coat': ['Cina8_360_recto', 'Cina6_9_recto'],
#  '31-23831\nfailiq\n': ['Cina8_360_recto'],
#  '31-23831': ['Cina8_360_recto'],
#  'failiq': ['Cina8_360_recto'],
#  'laugh': ['Cina8_107_recto'],
#  'facial': ['Cina8_107_recto'],
#  'express': ['Cina8_107_recto'],
#  'smile': ['Cina8_107_recto'],
#  'bowti': ['Cina8_107_recto'],
#  'statu': ['F27_70_recto'],
#  'memori': ['F27_70_recto'],
#  'landmark': ['F27_70_recto'],
#  'monument': ['F27_70_recto'],
#  '生\n': ['F27_70_recto'],
#  'organ': ['T55_13_recto'],
#  'rock': ['T55_13_recto', 'F20_182_recto'],
#  'dress': ['T63_69_recto'],
#  'footwear': ['T63_69_recto'],
#  '边防执勤\nborderouty\n': ['F22_49_recto'],
#  '边防': ['F22_49_recto'],
#  '执勤': ['F22_49_recto'],
#  'borderouty': ['F22_49_recto'],
#  'vintag': ['F20_444_recto'],
#  'monk': ['F20_444_recto'],
#  'templ': ['Cina6_9_recto'],
#  'still': ['Cina6_9_recto',
#   'F20_182_recto',
#   'T11_13_recto',
#   'F56_33_recto',
#   'T10_125_recto'],
#  'life': ['Cina6_9_recto',
#   'F20_182_recto',
#   'T11_13_recto',
#   'F56_33_recto',
#   'T10_125_recto'],
#  'stone': ['F20_182_recto', 'F56_21_recto'],
#  'wall': ['F20_182_recto', 'T10_125_recto'],
#  'boca': ['T14_77_recto'],
#  'junior': ['T14_77_recto'],
#  'east': ['T14_77_recto'],
#  'high': ['T14_77_recto'],
#  'victoria': ['T14_77_recto'],
#  'lan\n17\nlao international tour\ntur\nsirikane lad\nbijoux-artisanat\nlao\n': ['T14_77_recto'],
#  'lan': ['T14_77_recto'],
#  '17': ['T14_77_recto'],
#  'lao': ['T14_77_recto'],
#  'international': ['T14_77_recto'],
#  'tour': ['T14_77_recto'],
#  'tur': ['T14_77_recto'],
#  'sirikane': ['T14_77_recto'],
#  'lad': ['T14_77_recto'],
#  'bijoux-artisanat': ['T14_77_recto'],
#  'child': ['F20_334_recto'],
#  'happi': ['F20_334_recto'],
#  'sit': ['F20_334_recto'],
#  'share': ['F20_334_recto'],
#  'food': ['F20_334_recto', 'T20_109_recto'],
#  'tablewar': ['F20_334_recto'],
#  'sculptur': ['F56_21_recto'],
#  'head': ['F56_21_recto'],
#  'visual': ['F56_21_recto', 'T11_13_recto'],
#  'relief': ['F56_21_recto'],
#  'carv': ['F56_21_recto'],
#  'artifact': ['F56_21_recto'],
#  'convers': ['T20_109_recto'],
#  'meal': ['T20_109_recto'],
#  'stool': ['T20_109_recto'],
#  '11\n': ['T34_40_recto'],
#  '11': ['T34_40_recto'],
#  'collect': ['T11_13_recto'],
#  '707\n저 하\n': ['T11_13_recto'],
#  '707': ['T11_13_recto'],
#  '저': ['T11_13_recto'],
#  '하': ['T11_13_recto'],
#  'sun': ['T36_20_recto'],
#  '技家\na881\nkg\nincapen\n': ['T36_20_recto'],
#  '家': ['T36_20_recto'],
#  'a881': ['T36_20_recto'],
#  'kg': ['T36_20_recto'],
#  'incapen': ['T36_20_recto'],
#  'draw': ['F56_33_recto'],
#  'printmak': ['F56_33_recto'],
#  'illustr': ['F56_33_recto'],
#  'artwork': ['F56_33_recto'],
#  'bag': ['F56_33_recto'],
#  'luggag': ['F56_33_recto'],
#  '34_5\nviiis-xs siècle\ncarreau\nvuang-binh\nmy-đưc\n34 5\n': ['F56_33_recto'],
#  '34_5': ['F56_33_recto'],
#  'viiis-xs': ['F56_33_recto'],
#  'siècle': ['F56_33_recto'],
#  'carreau': ['F56_33_recto'],
#  'vuang-binh': ['F56_33_recto'],
#  'my-đưc': ['F56_33_recto'],
#  '34': ['F56_33_recto'],
#  'sea': ['T12_43_recto']}

# %%
annotated_images
# Out:
# {'T6_65_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/68478/canvas.json',
#    'label': 'T6_65_recto',
#    '@type': 'sc:Canvas',
#    'width': 2994,
#    'height': 3914,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/67438/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/ab3a6ac551de9c143be06619928e4bd9.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2994,
#       'height': 3914,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/ab3a6ac551de9c143be06619928e4bd9.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/68478/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '3a932291-be7d-4fc6-a02e-cbb3ac8fc417'},
#     {'label': 'notes', 'value': 'T6_65_recto'},
#     {'label': 'originalFileName', 'value': 'T6_65_recto.jpg'},
#     {'label': 'filename', 'value': '129.jpg'},
#     {'label': 'fileMD5', 'value': 'c33b6c2a33874bee8ecbaf312f9bdbb3'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/68478/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[677.1538825035095,
#      1421.0402763485909,
#      951.7315739393234,
#      1193.1271902918816],
#     [1014.3602793216705,
#      1309.6624328494072,
#      1287.095587849617,
#      1740.6653413176537]],
#    'वि बचाओंँ आन्दालग\nिहरी\nगढ़वाल\nा्य वा\n': [[241, 181, 2284, 1894]],
#    'वि': [[241, 498, 316, 474]],
#    'बचाओंँ': [[559, 451, 631, 475]],
#    'आन्दालग': [[1207, 360, 1250, 474]],
#    'िहरी': [[377, 890, 382, 304]],
#    'गढ़वाल': [[898, 1003, 660, 280]],
#    'ा्य': [[1242, 1992, 111, 83]],
#    'वा': [[1366, 1999, 65, 57]]},
#   'country': 'India'},
#  'T42_1_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/72464/canvas.json',
#    'label': 'T42_1_recto',
#    '@type': 'sc:Canvas',
#    'width': 1983,
#    'height': 1452,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/71424/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/0d7425de8e130e4ea86b54a243cb1fa4.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 1983,
#       'height': 1452,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/0d7425de8e130e4ea86b54a243cb1fa4.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/72464/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '7fcf14c2-c9b4-47f5-b014-34f4de4e4a7c'},
#     {'label': 'notes', 'value': 'T42_1_recto'},
#     {'label': 'originalFileName', 'value': 'T42_1_recto.jpg'},
#     {'label': 'filename', 'value': '1.jpg'},
#     {'label': 'fileMD5', 'value': 'b8eeefd26bfe1019f435e09493d231c5'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/72464/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[569.0182295143604,
#      644.3570566177368,
#      486.43834099173546,
#      669.1649322509766],
#     [546.3394881784916,
#      312.45033144950867,
#      191.32884657382965,
#      198.39433085918427]],
#    '40\nmay\n72\n': [[205, 584, 1671, 303]],
#    '40': [[221, 584, 30, 31]],
#    'may': [[1857, 888, 0, 0]],
#    '72': [[1858, 690, 0, 0]]},
#   'country': 'Vietnam'},
#  'T4_63_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/66712/canvas.json',
#    'label': 'T4_63_recto',
#    '@type': 'sc:Canvas',
#    'width': 3909,
#    'height': 3149,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/65672/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/29688b9035f1de792408077fd5793daa.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3909,
#       'height': 3149,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/29688b9035f1de792408077fd5793daa.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/66712/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '8e4122ce-43cf-44ae-97bc-ae2fb3cfcad0'},
#     {'label': 'notes', 'value': 'T4_63_recto'},
#     {'label': 'originalFileName', 'value': 'T4_63_recto.jpg'},
#     {'label': 'filename', 'value': '125.jpg'},
#     {'label': 'fileMD5', 'value': 'a9c4bb90689b68a4e639097c33f6c231'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/66712/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'frame_pictur': [[195.54468607529998,
#      379.21086660027504,
#      3505.549378339201,
#      2279.2151475846767]]},
#   'country': 'India'},
#  'T14_152_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/68282/canvas.json',
#    'label': 'T14_152_recto',
#    '@type': 'sc:Canvas',
#    'width': 3840,
#    'height': 3105,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/67242/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/204d2715f148c7e8ed5a85b5781f121b.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3840,
#       'height': 3105,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/204d2715f148c7e8ed5a85b5781f121b.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/68282/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '75b3c7cd-4e74-4b81-9d7d-63ef5573b17b'},
#     {'label': 'notes', 'value': 'T14_152_recto'},
#     {'label': 'originalFileName', 'value': 'T14_152_recto.jpg'},
#     {'label': 'filename', 'value': '303.jpg'},
#     {'label': 'fileMD5', 'value': '25ce72dc80b50d5c97005993074c0ddf'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/68282/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[563.5787773132324,
#      575.039679184556,
#      740.8288764953613,
#      2071.987323090434],
#     [2973.980712890625,
#      1175.9631246328354,
#      678.8296508789062,
#      804.9432581663132],
#     [2290.312728881836,
#      1077.2365187108517,
#      418.99269104003906,
#      1034.6883688867092],
#     [1255.6704711914062,
#      622.937995120883,
#      673.1133270263672,
#      1992.9933238774538],
#     [1869.4175720214844,
#      1353.6153455078602,
#      641.2790679931641,
#      1197.4926920235157]],
#    'tabl_top': [[2411.6764068603516,
#      1847.5267240405083,
#      1239.5745849609375,
#      841.1963546276093]],
#    'cloth': [[2985.3561401367188,
#      1419.5006650686264,
#      664.4696044921875,
#      473.671210706234],
#     [555.7098197937012,
#      775.7278644293547,
#      731.4629173278809,
#      1075.4081419855356],
#     [1361.726417541504,
#      1625.3219264745712,
#      339.2223358154297,
#      864.3194881081581],
#     [649.6995735168457,
#      1347.2579227387905,
#      521.0987663269043,
#      1264.7853948175907]]},
#   'country': 'Laos'},
#  'T35_167_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/71382/canvas.json',
#    'label': 'T35_167_recto',
#    '@type': 'sc:Canvas',
#    'width': 1859,
#    'height': 1351,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/70342/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/0ef8d065f7bd9d6c86673c6ceeb53d38.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 1859,
#       'height': 1351,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/0ef8d065f7bd9d6c86673c6ceeb53d38.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/71382/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '70d5bc4b-b082-4b94-83ca-f0f8d1a98ce2'},
#     {'label': 'notes', 'value': 'T35_167_recto'},
#     {'label': 'originalFileName', 'value': 'T35_167_recto.jpg'},
#     {'label': 'filename', 'value': '331.jpg'},
#     {'label': 'fileMD5', 'value': '26a0d319e25a97b5c5fd69a36b289779'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/71382/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'outerwear': [[502.9406726658344,
#      646.3144031465054,
#      986.9121328294277,
#      563.0034601390362]],
#    'person': [[517.5442222058773,
#      429.7284663617611,
#      990.9570706188679,
#      790.2101961672306]]},
#   'country': 'Japan'},
#  'T14_74_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/68126/canvas.json',
#    'label': 'T14_74_recto',
#    '@type': 'sc:Canvas',
#    'width': 2014,
#    'height': 2716,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/67086/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/bc4bf88c27e3d734253edd1e7d472f61.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2014,
#       'height': 2716,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/bc4bf88c27e3d734253edd1e7d472f61.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/68126/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '919487a8-6b22-4312-ae53-882c83069fa8'},
#     {'label': 'notes', 'value': 'T14_74_recto'},
#     {'label': 'originalFileName', 'value': 'T14_74_recto.jpg'},
#     {'label': 'filename', 'value': '147.jpg'},
#     {'label': 'fileMD5', 'value': 'b10051d21c9901befc54c30409149214'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/68126/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[1033.40962600708,
#      1171.8702718019485,
#      407.0346394777298,
#      1245.2489222288132],
#     [694.1019322276115,
#      1112.8648508787155,
#      407.6442816853523,
#      1280.245808005333],
#     [696.1597222685814,
#      1157.518735051155,
#      391.95960479974747,
#      1228.1984184980392]],
#    'pant': [[1093.6624674797058,
#      1813.762146949768,
#      276.9813965559006,
#      517.5248138904572],
#     [737.9437120556831,
#      1695.6384704113007,
#      332.070495903492,
#      608.3635401725769]],
#    '379\n': [[623, 703, 43, 18]],
#    '379': [[623, 703, 43, 18]]},
#   'country': 'Laos'},
#  'Cina5_123_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/79494/canvas.json',
#    'label': 'Cina5_123_recto',
#    '@type': 'sc:Canvas',
#    'width': 3804,
#    'height': 2905,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/78454/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/327a5fdd157e23821c7f1c0d3ace96f4.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3804,
#       'height': 2905,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/327a5fdd157e23821c7f1c0d3ace96f4.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/79494/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'e22e0f37-40cb-43f6-88f4-515f64be4acf'},
#     {'label': 'notes', 'value': 'Cina5_123_recto'},
#     {'label': 'originalFileName', 'value': 'Cina5_123_recto.jpg'},
#     {'label': 'filename', 'value': '245.jpg'},
#     {'label': 'fileMD5', 'value': '8a618b9d47a08d5fd927fd93b719507b'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/79494/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'anim': [[2608.432499885559,
#      402.7968640625477,
#      1063.3994178771973,
#      1413.9724941551685],
#     [3249.3799953460693,
#      1484.1069003939629,
#      444.09251976013184,
#      1076.4620542526245]],
#    '和り也是啡了处我的 不是这方吃三就是那5哈\n立结片乡阳时,在要订好南法楚楚。\n有到,特好论切制时,也们各种码式的那台佳f4低活及4 经片会同時要法意些什么间题\nを,中斗台有台业生,在差一个多种维 成的的首在,多层大的能\n名建构,我d舞第的计划统片的前程1_要发样不的调有\n林作图,发展南品海請冰的约故动法外, 大青四\n素性片名间自争现,達新老未同容利有打一个统-送街的德\n同法律头加两uz(t42间有子型 -定代,\n《化,坚决打去反为\n三主危者社会\n該好紀、場\n要分子\n成会分\nそ和\n依法严惩严重危害社会治安的犯罪\n杀人罪犯陈立波、抢劫杀人罪犯陈志明被判死刑\n:继续整\n技。要里,\n設的连法死\n侍、流很团\n最像帶和地\nに統和方去\n罪活動,\n群众,使\n支。\ne e/6 r rarm*\naeran naterer\nroes\nancrr2ee\n3)通过人\n香!\n_ e s r\nseafon\nserso perar\nter 2l pee\nam ee c\n:_blr\n19bz\nsansr narar\n戈火犯罪\n白\n二,\n_ rarrca\n城 锁科\nww_w\n': [[1042,
#      83,
#      2689,
#      2184]],
#    '和': [[2596, 83, 73, 76],
#     [3603, 1005, 62, 75],
#     [3026, 1351, 70, 56],
#     [2949, 1429, 76, 76]],
#    'り': [[2671, 85, 62, 76]],
#    '也是': [[2758, 90, 44, 62]],
#    '啡': [[2814, 96, 49, 55]],
#    '了': [[2876, 107, 19, 43]],
#    '处': [[2909, 93, 43, 54]],
#    '我': [[2954, 94, 74, 76], [1277, 378, 50, 75]],
#    '的': [[3030, 97, 37, 76],
#     [1904, 213, 52, 81],
#     [2015, 320, 51, 43],
#     [2079, 321, 39, 39],
#     [2414, 317, 45, 75],
#     [1470, 383, 45, 75],
#     [1775, 408, 43, 47],
#     [2259, 425, 47, 43],
#     [1915, 507, 43, 43],
#     [2294, 583, 69, 75],
#     [2397, 774, 70, 143],
#     [2876, 1176, 53, 41]],
#    '不是': [[3093, 103, 78, 62]],
#    '这': [[3181, 117, 40, 50]],
#    '方': [[3231, 114, 33, 54], [3017, 1448, 73, 49]],
#    '吃': [[3275, 116, 53, 56]],
#    '三': [[3331, 106, 57, 76], [3186, 624, 129, 75]],
#    '就是': [[3390, 108, 113, 76]],
#    '那': [[3506, 112, 37, 76], [1958, 215, 52, 81]],
#    '5': [[3544, 113, 49, 76]],
#    '哈': [[3583, 115, 52, 67]],
#    '立': [[2600, 190, 37, 51]],
#    '结': [[2652, 189, 51, 51]],
#    '片': [[2714, 185, 45, 55], [2941, 263, 80, 81], [1719, 414, 43, 43]],
#    '乡': [[2772, 190, 35, 47]],
#    '阳': [[2817, 201, 35, 39]],
#    '时': [[2874, 194, 43, 45], [1487, 207, 55, 61]],
#    ',': [[2929, 233, 7, 7],
#     [1193, 178, 12, 81],
#     [1544, 195, 16, 81],
#     [1136, 298, 23, 43],
#     [1590, 297, 33, 75],
#     [2226, 313, 45, 75],
#     [1257, 377, 18, 75],
#     [1299, 533, 7, 7],
#     [2250, 551, 7, 7],
#     [1489, 563, 26, 75],
#     [3687, 395, 10, 75],
#     [3273, 543, 22, 71],
#     [3058, 1073, 47, 77],
#     [3109, 1533, 48, 73],
#     [3009, 1605, 47, 75],
#     [2421, 2075, 7, 7]],
#    '在': [[2950, 194, 57, 47], [1625, 298, 62, 75], [2187, 324, 31, 51]],
#    '要': [[3016, 191, 41, 61],
#     [3199, 294, 31, 63],
#     [2023, 410, 43, 59],
#     [3361, 811, 57, 70],
#     [2908, 1078, 57, 55]],
#    '订': [[3070, 202, 49, 41]],
#    '好': [[3121, 185, 72, 75], [1255, 205, 35, 53], [3367, 735, 71, 43]],
#    '南': [[3195, 187, 50, 75], [1436, 481, 31, 63]],
#    '法': [[3247, 188, 76, 75],
#     [3265, 297, 46, 51],
#     [2137, 492, 62, 75],
#     [3010, 1177, 47, 41]],
#    '楚楚': [[3364, 197, 45, 71]],
#    '。': [[3422, 254, 15, 15], [2882, 1117, 9, 13], [2898, 1678, 53, 85]],
#    '有': [[1046, 171, 77, 81],
#     [1356, 291, 43, 51],
#     [2383, 408, 57, 75],
#     [1921, 573, 38, 75],
#     [3371, 374, 62, 75]],
#    '到': [[1125, 175, 66, 81]],
#    '特': [[1209, 195, 29, 59]],
#    '论': [[1306, 184, 63, 81]],
#    '切': [[1371, 187, 54, 81]],
#    '制': [[1419, 211, 53, 43]],
#    '也': [[1562, 218, 41, 43]],
#    '们': [[1621, 211, 37, 55]],
#    '各种': [[1671, 215, 91, 50]],
#    '码': [[1775, 213, 47, 55]],
#    '式': [[1824, 209, 78, 81]],
#    '台': [[2012, 218, 54, 81], [1308, 302, 27, 55], [1420, 297, 35, 67]],
#    '佳': [[2068, 221, 52, 81]],
#    'f4': [[2145, 224, 87, 50]],
#    '低': [[2245, 229, 47, 49]],
#    '活': [[2306, 234, 43, 47]],
#    '及': [[2366, 235, 35, 49]],
#    '4': [[2403, 237, 58, 81]],
#    '经': [[2902, 261, 37, 81]],
#    '会': [[2999, 286, 45, 55], [3637, 919, 32, 69]],
#    '同時': [[3061, 281, 111, 49]],
#    '意': [[3329, 292, 59, 69]],
#    '些': [[3417, 296, 35, 39]],
#    '什么': [[3477, 299, 93, 53]],
#    '间': [[3591, 303, 43, 59], [1291, 586, 39, 35], [3329, 399, 39, 39]],
#    '题': [[3657, 298, 67, 81]],
#    'を': [[1084, 288, 31, 63]],
#    '中': [[1208, 300, 31, 47]],
#    '斗': [[1248, 293, 39, 63]],
#    '业': [[1471, 310, 39, 47]],
#    '生': [[1527, 311, 39, 51]],
#    '差': [[1689, 299, 38, 75]],
#    '一个': [[1747, 321, 19, 43], [1987, 591, 67, 55]],
#    '多种': [[1784, 310, 82, 59]],
#    '维': [[1884, 312, 71, 51]],
#    '成': [[1965, 306, 26, 75], [3551, 920, 84, 69]],
#    '首': [[2139, 323, 31, 51]],
#    '多层': [[2271, 322, 75, 59]],
#    '大': [[2367, 328, 39, 55]],
#    '能': [[2461, 319, 38, 75]],
#    '名': [[1068, 388, 43, 55]],
#    '建构': [[1128, 378, 127, 67]],
#    'd': [[1329, 379, 58, 75]],
#    '舞': [[1383, 401, 19, 39]],
#    '第': [[1427, 398, 31, 55]],
#    '计划': [[1531, 401, 99, 47]],
#    '统': [[1647, 404, 59, 51], [2063, 589, 63, 59]],
#    '前程': [[1835, 398, 108, 59]],
#    '1_': [[1959, 413, 47, 51]],
#    '发': [[2079, 412, 39, 51]],
#    '样': [[2135, 409, 55, 59]],
#    '不': [[2207, 427, 35, 47]],
#    '调': [[2323, 422, 51, 55]],
#    '林': [[1046, 468, 89, 75]],
#    '作图': [[1137, 470, 162, 75]],
#    '发展': [[1328, 486, 95, 59]],
#    '品': [[1470, 477, 45, 75]],
#    '海': [[1548, 491, 79, 55]],
#    '請': [[1668, 494, 87, 63]],
#    '冰': [[1762, 484, 109, 75]],
#    '约': [[1971, 505, 43, 47]],
#    '故': [[2026, 490, 73, 75]],
#    '动': [[2101, 491, 34, 75]],
#    '外': [[2201, 494, 50, 75]],
#    '大青': [[2266, 495, 137, 75]],
#    '四': [[2435, 539, 59, 35]],
#    '素性': [[1072, 552, 91, 71]],
#    '片名': [[1183, 579, 87, 43]],
#    '自': [[1348, 571, 15, 55]],
#    '争': [[1388, 576, 27, 55]],
#    '现': [[1432, 573, 55, 55]],
#    '達': [[1531, 580, 35, 51]],
#    '新': [[1587, 585, 43, 47]],
#    '老': [[1660, 579, 23, 51]],
#    '未': [[1707, 584, 43, 47]],
#    '同': [[1759, 593, 27, 39], [2639, 337, 43, 63]],
#    '容': [[1819, 591, 27, 47]],
#    '利': [[1862, 572, 57, 75]],
#    '打': [[1955, 606, 11, 31], [3417, 561, 71, 49]],
#    '-': [[2135, 623, 19, 7], [3524, 384, 61, 75]],
#    '送': [[2167, 591, 51, 63]],
#    '街': [[2227, 597, 55, 51]],
#    '德': [[2427, 606, 59, 55]],
#    '法律': [[2716, 330, 139, 75]],
#    '头': [[2871, 345, 63, 67]],
#    '加': [[2945, 374, 55, 43]],
#    '两': [[3014, 374, 59, 35]],
#    'uz': [[3101, 380, 75, 35]],
#    '(': [[3180, 361, 38, 75]],
#    't42': [[3220, 364, 110, 75]],
#    '子': [[3435, 378, 34, 75]],
#    '型': [[3469, 397, 43, 47]],
#    '定': [[3587, 388, 62, 75]],
#    '代': [[3651, 393, 34, 75]],
#    '《': [[3065, 535, 86, 71]],
#    '化': [[3153, 539, 118, 71]],
#    '坚决': [[3297, 544, 142, 72]],
#    '去': [[3505, 558, 49, 55], [3113, 1438, 54, 77]],
#    '反': [[3577, 563, 51, 49]],
#    '为': [[3642, 580, 35, 37]],
#    '主': [[3336, 631, 55, 63]],
#    '危': [[3414, 625, 77, 81]],
#    '者': [[3493, 628, 80, 81]],
#    '社会': [[3575, 630, 108, 82], [1924, 771, 255, 143]],
#    '該': [[3283, 730, 73, 61]],
#    '紀': [[3463, 737, 69, 47]],
#    '、': [[3558, 726, 47, 75], [1823, 967, 9, 9], [2880, 1293, 7, 7]],
#    '場': [[3602, 728, 129, 75]],
#    '分子': [[3452, 822, 117, 63]],
#    '分': [[3686, 951, 1, 1]],
#    'そ': [[3530, 1004, 35, 77]],
#    '依法': [[1069, 764, 246, 143]],
#    '严惩': [[1317, 766, 238, 143]],
#    '严重': [[1557, 766, 214, 145]],
#    '危害': [[1736, 785, 187, 119]],
#    '治安': [[2181, 772, 214, 144]],
#    '犯罪': [[2484, 795, 259, 123], [1638, 1846, 70, 53]],
#    '杀人': [[1390, 928, 111, 55], [1978, 928, 115, 58]],
#    '罪犯': [[1512, 927, 109, 57], [2102, 931, 115, 58]],
#    '陈立波': [[1630, 926, 173, 58]],
#    '抢劫': [[1854, 925, 115, 59]],
#    '陈志明': [[2219, 923, 190, 79]],
#    '被判': [[2411, 925, 118, 79]],
#    '死刑': [[2531, 926, 106, 80]],
#    ':': [[2780, 992, 23, 47]],
#    '继续': [[2828, 984, 119, 59]],
#    '整': [[2972, 976, 67, 75]],
#    '技': [[2794, 1072, 59, 61]],
#    '里': [[2987, 1087, 53, 45]],
#    '設': [[2798, 1164, 65, 51]],
#    '连': [[2942, 1176, 59, 45]],
#    '死': [[3074, 1163, 59, 69]],
#    '侍': [[2812, 1246, 53, 55]],
#    '流': [[2899, 1256, 55, 47]],
#    '很': [[2961, 1260, 63, 47]],
#    '团': [[3042, 1250, 79, 71]],
#    '最': [[2832, 1333, 49, 64]],
#    '像': [[2893, 1338, 61, 60]],
#    '帶': [[2968, 1338, 48, 67]],
#    '地': [[3105, 1344, 63, 78]],
#    'に': [[2824, 1439, 42, 60]],
#    '統': [[2869, 1424, 78, 76]],
#    '罪': [[2866, 1521, 44, 68]],
#    '活動': [[2939, 1528, 138, 69]],
#    '群众': [[2855, 1605, 127, 66]],
#    '使': [[3058, 1607, 48, 75]],
#    '支': [[2853, 1683, 40, 71]],
#    'e': [[1156, 1013, 32, 19], [1803, 1313, 34, 11]],
#    'e/6': [[1197, 1013, 86, 19]],
#    'r': [[1369, 1013, 19, 19], [1886, 1315, 26, 10]],
#    'rarm*': [[1439, 1017, 102, 13]],
#    'aeran': [[1183, 1114, 121, 19]],
#    'naterer': [[1319, 1115, 109, 19]],
#    'roes': [[1149, 1198, 77, 16]],
#    'ancrr2ee': [[1430, 1206, 111, 14]],
#    '3': [[1192, 1234, 41, 29]],
#    ')': [[1244, 1240, 13, 21]],
#    '通过': [[1260, 1221, 159, 54]],
#    '人': [[1421, 1223, 16, 53]],
#    '香': [[3600, 1280, 68, 69]],
#    '!': [[3670, 1278, 39, 69]],
#    '_': [[1736, 1309, 38, 17], [2224, 2060, 14, 16]],
#    's': [[1872, 1311, 16, 17]],
#    'seafon': [[1722, 1386, 77, 16]],
#    'serso': [[1725, 1417, 72, 18]],
#    'perar': [[1832, 1420, 82, 17]],
#    'ter': [[1749, 1448, 47, 17]],
#    '2l': [[1798, 1448, 28, 17]],
#    'pee': [[1834, 1448, 46, 17]],
#    'am': [[1095, 1450, 34, 10]],
#    'ee': [[1161, 1448, 24, 16]],
#    'c': [[1218, 1449, 21, 16]],
#    ':_blr': [[1737, 1480, 53, 16]],
#    '19bz': [[1719, 1495, 93, 16]],
#    'sansr': [[1095, 1522, 68, 13]],
#    'narar': [[1173, 1522, 125, 16]],
#    '戈': [[1545, 1845, 28, 43]],
#    '火': [[1575, 1842, 61, 53]],
#    '白': [[1824, 2018, 40, 49]],
#    '二': [[2376, 2052, 34, 32]],
#    'rarrca': [[2271, 2061, 63, 16]],
#    '城': [[2774, 2176, 98, 72]],
#    '锁': [[3026, 2186, 118, 72]],
#    '科': [[3146, 2191, 95, 72]],
#    'ww_w': [[2489, 1351, 0, 0]]},
#   'country': 'China'},
#  'T6_169_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/68686/canvas.json',
#    'label': 'T6_169_recto',
#    '@type': 'sc:Canvas',
#    'width': 4594,
#    'height': 3665,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/67646/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/c40691855393be376eb347dd0b31ecbe.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 4594,
#       'height': 3665,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/c40691855393be376eb347dd0b31ecbe.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/68686/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '61886215-12f8-4c2c-9dd8-c6fde58e3bdd'},
#     {'label': 'notes', 'value': 'T6_169_recto'},
#     {'label': 'originalFileName', 'value': 'T6_169_recto.jpg'},
#     {'label': 'filename', 'value': '337.jpg'},
#     {'label': 'fileMD5', 'value': 'abca8dfa57bbefc00e3deb1dd6b9fe91'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/68686/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[1020.7096788585186,
#      1846.683369576931,
#      309.79945382475853,
#      879.0515044331551],
#     [2287.189990758896,
#      2323.9691457152367,
#      475.7391719818115,
#      559.7772514820099]],
#    'poster': [[635.098768800497,
#      689.8999517410994,
#      3337.1690997183323,
#      2278.574859276414]],
#    'anim': [[1547.6599824428558,
#      2364.7137567400932,
#      769.5966762304306,
#      533.5133218765259],
#     [2275.391473531723,
#      2314.6884724497795,
#      494.92189395427704,
#      566.2514844536781],
#     [1067.8346072733402,
#      2453.272272348404,
#      582.4972287118435,
#      451.72198206186295]],
#    "ייטיסו\nswaglam\nyou deserve\nthe best\nthe times of india shoirectely\nhotels':\ntours\nmission road manali\nby super deluxe coaches taxis\nsight seeing\nrohtang\nmanali to\ndelhi\nchandigarh\noutdoor roto e\ndharamshala\ndalhousie\njammu leh privale verrole om\nmanikaran shimla\nend lart se'nc news aper\nnaggar\nst seinc newsaper\nrush directely\nआप ततवाता है, या\nhimachal joues\ndirecton\ntogrism de6 v ba:jk estate sh\ntourist infortdation c\nmarali\n": [[718,
#      738,
#      3202,
#      1371]],
#    'ייטיסו': [[3039, 760, 171, 47]],
#    'swaglam': [[2824, 783, 653, 180]],
#    'you': [[1057, 1103, 191, 135]],
#    'deserve': [[1368, 1075, 598, 136]],
#    'the': [[1170, 1261, 211, 137], [727, 1496, 328, 191]],
#    'best': [[1474, 1248, 291, 143]],
#    'times': [[1095, 1513, 470, 192]],
#    'of': [[1647, 1540, 247, 191]],
#    'india': [[1975, 1555, 718, 192]],
#    'shoirectely': [[2726, 1591, 702, 192]],
#    "hotels':": [[3542, 881, 326, 57]],
#    'tours': [[2901, 969, 423, 87]],
#    'mission': [[2886, 1071, 197, 34]],
#    'road': [[3100, 1046, 122, 44]],
#    'manali': [[3229, 1041, 180, 35], [2952, 1201, 206, 55]],
#    'by': [[2818, 1107, 95, 87]],
#    'super': [[2915, 1102, 130, 88]],
#    'deluxe': [[3048, 1098, 173, 87]],
#    'coaches': [[3224, 1091, 231, 87]],
#    'taxis': [[3517, 1079, 231, 88]],
#    'sight': [[2819, 1424, 85, 40]],
#    'seeing': [[2919, 1352, 89, 29]],
#    'rohtang': [[2853, 1477, 144, 33]],
#    'to': [[3192, 1183, 79, 53]],
#    'delhi': [[3057, 1262, 156, 48]],
#    'chandigarh': [[3056, 1317, 373, 55]],
#    'outdoor': [[3476, 1248, 231, 71]],
#    'roto': [[3724, 1253, 139, 72]],
#    'e': [[3880, 1245, 39, 79]],
#    'dharamshala': [[3054, 1445, 392, 56]],
#    'dalhousie': [[3054, 1509, 294, 52]],
#    'jammu': [[3045, 1555, 197, 64]],
#    'leh': [[3302, 1554, 96, 57]],
#    'privale': [[3461, 1552, 175, 65]],
#    'verrole': [[3648, 1551, 181, 65]],
#    'om': [[3831, 1550, 85, 64]],
#    'manikaran': [[2851, 1525, 185, 62]],
#    'shimla': [[3076, 1389, 191, 70]],
#    'end': [[736, 1752, 150, 147]],
#    'lart': [[1055, 1811, 386, 123]],
#    "se'nc": [[1503, 1836, 338, 146]],
#    'news': [[1897, 1879, 361, 147]],
#    'aper': [[2352, 1949, 305, 126]],
#    'naggar': [[2871, 1616, 122, 35]],
#    'st': [[1369, 1823, 114, 125]],
#    'seinc': [[1531, 1840, 307, 124]],
#    'newsaper': [[1907, 1878, 747, 125]],
#    'rush': [[2828, 1671, 182, 120]],
#    'directely': [[3030, 1672, 394, 117]],
#    'आप': [[3768, 1636, 37, 25]],
#    'ततवाता': [[3808, 1636, 58, 26]],
#    'है,': [[3869, 1637, 23, 25]],
#    'या': [[3895, 1636, 14, 26]],
#    'himachal': [[3486, 1781, 118, 46]],
#    'joues': [[3610, 1785, 88, 48]],
#    'directon': [[3550, 1888, 159, 23]],
#    'togrism': [[3468, 1916, 114, 37]],
#    'de6': [[3584, 1927, 52, 36]],
#    'v': [[3639, 1932, 22, 36]],
#    'ba:jk': [[3663, 1933, 72, 37]],
#    'estate': [[3737, 1940, 90, 37]],
#    'sh': [[3831, 1949, 33, 36]],
#    'tourist': [[3482, 1979, 108, 41]],
#    'infortdation': [[3593, 1989, 188, 41]],
#    'c': [[3783, 2006, 18, 40]],
#    'marali': [[3587, 2027, 168, 42]]},
#   'country': 'India'},
#  'T36_59_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/72112/canvas.json',
#    'label': 'T36_59_recto',
#    '@type': 'sc:Canvas',
#    'width': 2463,
#    'height': 1805,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/71072/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/9da442513b2088ee0182963a82b867cb.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2463,
#       'height': 1805,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/9da442513b2088ee0182963a82b867cb.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/72112/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'a78bf8d7-6d6a-4f6e-8354-1101a2b56caf'},
#     {'label': 'notes', 'value': 'T36_59_recto'},
#     {'label': 'originalFileName', 'value': 'T36_59_recto.jpg'},
#     {'label': 'filename', 'value': '117.jpg'},
#     {'label': 'fileMD5', 'value': '9195a39f5d4c65d7bfc92666fe5ecf77'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/72112/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'dog': [[453.630988240242,
#      1451.9996070861816,
#      282.4968988895416,
#      205.57466357946396]],
#    'person': [[2114.5001900196075,
#      1063.7301382422447,
#      152.41952347755432,
#      394.1229212284088],
#     [268.3274542093277, 1020.14259070158, 257.744816288352, 562.6730218529701],
#     [1741.2112655639648,
#      1143.974303305149,
#      148.7609651684761,
#      354.96578097343445]],
#    'tire': [[1765.171071588993,
#      1346.8283224105835,
#      210.87307047843933,
#      212.9679998755455],
#     [1489.4501615166664,
#      1360.6502678990364,
#      206.65106981992722,
#      186.7555457353592]],
#    'anim': [[460.7048102170229,
#      1447.3530587553978,
#      279.64023296535015,
#      209.31920766830444]],
#    'window': [[1007.9718646109104,
#      199.07606944441795,
#      239.76784166693687,
#      270.0664606690407],
#     [1728.3370923399925,
#      197.62060049921274,
#      269.38871651887894,
#      290.0650345906615]],
#    'bicycl': [[1493.1501191854477,
#      1255.11426538229,
#      491.7197204232216,
#      316.8642783164978]],
#    '律治\n歌批海耀\n** chua soon hup &\n顺\n雜唐權中\n货洋頭西\n益廣\n乾\n發各\nkwong yik\nprai\nmalaysia\nclose up\ntiger\n7ea\nklim\norion\npra\nmalaysia\n|尊誓糖袖\n|米置育轮\n': [[579,
#      466,
#      1724,
#      1018]],
#    '律': [[582, 544, 25, 31]],
#    '治': [[625, 547, 23, 27]],
#    '歌': [[579, 576, 29, 40]],
#    '批': [[622, 575, 28, 40]],
#    '海': [[667, 574, 29, 40]],
#    '耀': [[713, 577, 25, 33]],
#    '**': [[580, 610, 165, 43]],
#    'chua': [[801, 608, 140, 43]],
#    'soon': [[961, 613, 142, 32]],
#    'hup': [[1188, 604, 97, 43]],
#    '&': [[1367, 603, 32, 42]],
#    '顺': [[923, 495, 137, 113]],
#    '雜': [[1612, 511, 60, 73]],
#    '唐': [[1692, 511, 63, 77]],
#    '權': [[1775, 510, 61, 76]],
#    '中': [[1869, 508, 58, 78]],
#    '货': [[1596, 603, 78, 88]],
#    '洋': [[1700, 609, 53, 83]],
#    '頭': [[1779, 613, 57, 67]],
#    '西': [[1866, 615, 64, 64]],
#    '益': [[1956, 484, 181, 183]],
#    '廣': [[2144, 496, 157, 169]],
#    '乾': [[1317, 531, 31, 38]],
#    '發': [[1318, 563, 31, 43]],
#    '各': [[1367, 563, 35, 43]],
#    'kwong': [[1994, 662, 181, 35]],
#    'yik': [[2208, 660, 89, 29]],
#    'prai': [[812, 903, 52, 20]],
#    'malaysia': [[780, 932, 114, 23], [942, 1457, 106, 27]],
#    'close': [[2101, 916, 50, 10]],
#    'up': [[2155, 917, 21, 9]],
#    'tiger': [[1425, 1283, 49, 8]],
#    '7ea': [[1432, 1297, 37, 18]],
#    'klim': [[1360, 1371, 92, 47]],
#    'orion': [[727, 1391, 62, 16]],
#    'pra': [[968, 1431, 48, 22]],
#    '|': [[1466, 476, 42, 3], [1415, 466, 40, 21]],
#    '尊': [[1465, 481, 42, 32]],
#    '誓': [[1464, 515, 42, 41]],
#    '糖': [[1463, 558, 42, 34]],
#    '袖': [[1461, 594, 42, 41]],
#    '米': [[1415, 489, 40, 25]],
#    '置': [[1415, 516, 40, 46]],
#    '育': [[1415, 564, 40, 32]],
#    '轮': [[1415, 598, 40, 39]]},
#   'country': None},
#  'F26_57_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/65756/canvas.json',
#    'label': 'F26_57_recto',
#    '@type': 'sc:Canvas',
#    'width': 3848,
#    'height': 3111,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/64716/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/f729a1bf2503f8f2882ddf4c6a1c017a.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3848,
#       'height': 3111,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/f729a1bf2503f8f2882ddf4c6a1c017a.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/65756/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'f2b5cee1-313a-4e52-9783-cbcc49a993cc'},
#     {'label': 'notes', 'value': 'F26_57_recto'},
#     {'label': 'originalFileName', 'value': 'F26_57_recto.jpg'},
#     {'label': 'filename', 'value': '113.jpg'},
#     {'label': 'fileMD5', 'value': '75c4f94d56b51612b5bc9eaf236092b3'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/65756/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[1190.8665840625763,
#      952.4188023805618,
#      779.8152453899384,
#      1093.28203779459],
#     [1817.3991346359253,
#      493.63254775106907,
#      748.6040024757385,
#      1487.3771254867315],
#     [161.76564002037048,
#      1173.9350234270096,
#      361.61835193634033,
#      575.0705051422119],
#     [1789.0569393634796,
#      419.2359720021486,
#      870.3915083408356,
#      1687.623778089881]],
#    'cloth': [[1184.9711487293243,
#      1113.0786426365376,
#      762.1190769672394,
#      913.3319094479084],
#     [117.95136737823486,
#      1548.4687706530094,
#      383.8043884038925,
#      329.8037542998791]],
#    'top': [[1827.2633924484253,
#      723.3242406249046,
#      711.1490430831909,
#      1257.6772736907005]],
#    'furnitur': [[306.33700573444366,
#      1783.9325764775276,
#      3315.5116728544235,
#      1052.719956099987],
#     [823.406581401825,
#      1353.6778409779072,
#      428.4112672805786,
#      536.2183666527271]],
#    'bed': [[102.10032497346401,
#      1737.3000712394714,
#      3438.058133736253,
#      1084.6285736560822]],
#    'sigigtst\n': [[1260, 1395, 97, 65]],
#    'sigigtst': [[1272, 1395, 85, 28]]},
#   'country': None},
#  'F27_85_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/76836/canvas.json',
#    'label': 'F27_85_recto',
#    '@type': 'sc:Canvas',
#    'width': 3858,
#    'height': 3123,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/75796/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/2e7e76c6a3622c93be1b1f24b8ab2ddb.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3858,
#       'height': 3123,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/2e7e76c6a3622c93be1b1f24b8ab2ddb.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/76836/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '5dbaabcf-617c-48a0-8683-c9c561c746c5'},
#     {'label': 'notes', 'value': 'F27_85_recto'},
#     {'label': 'originalFileName', 'value': 'F27_85_recto.jpg'},
#     {'label': 'filename', 'value': '169.jpg'},
#     {'label': 'fileMD5', 'value': 'd80b70333e4fd4b8ecf7fed51a16e3bb'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/76836/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'candy\nbox\n高級\n300\nb_v_c\n': [[1850, 675, 1325, 1513]],
#    'candy': [[1850, 678, 123, 33]],
#    'box': [[1879, 715, 68, 30]],
#    '高級': [[2958, 900, 197, 87]],
#    '300': [[3107, 1600, 44, 25]],
#    'b_v_c': [[2970, 2124, 149, 62]]},
#   'country': 'Japan'},
#  'F27_110_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/76886/canvas.json',
#    'label': 'F27_110_recto',
#    '@type': 'sc:Canvas',
#    'width': 3152,
#    'height': 3911,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/75846/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/983cae1447f7b6d0cc9951da30705df9.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3152,
#       'height': 3911,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/983cae1447f7b6d0cc9951da30705df9.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/76886/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '4532dec5-93ab-4e6b-bae7-f6f38fe38813'},
#     {'label': 'notes', 'value': 'F27_110_recto'},
#     {'label': 'originalFileName', 'value': 'F27_110_recto.jpg'},
#     {'label': 'filename', 'value': '219.jpg'},
#     {'label': 'fileMD5', 'value': '81ad09ecb96950ff44c08e3a83b6c6e6'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/76886/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'bridg_flower_lake_lure': [[1409, 2406, 1410, 286]],
#    '來\n塚\nwes\nfodg\n': [[1110, 1632, 1512, 1025]],
#    '來': [[1111, 1632, 200, 191]],
#    '塚': [[1121, 2296, 211, 174]],
#    'wes': [[2623, 2531, 0, 0]],
#    'fodg': [[1854, 2546, 11, 4]]},
#   'landmark_info': {'lake lure flowering bridge': {'latitude': 35.4359357,
#     'longitude': -82.2347018}},
#   'country': 'Japan'},
#  'T42_205_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/72870/canvas.json',
#    'label': 'T42_205_recto',
#    '@type': 'sc:Canvas',
#    'width': 4159,
#    'height': 3382,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/71830/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/c22a52ff9692b4b335d15da0b20cbd04.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 4159,
#       'height': 3382,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/c22a52ff9692b4b335d15da0b20cbd04.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/72870/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'e50e1576-0f31-49f2-8fc1-a82e861baeba'},
#     {'label': 'notes', 'value': 'T42_205_recto'},
#     {'label': 'originalFileName', 'value': 'T42_205_recto.jpg'},
#     {'label': 'filename', 'value': '407.jpg'},
#     {'label': 'fileMD5', 'value': '614f8f7343d390c79347b093add864bb'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/72870/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[1508.2608833611012,
#      1275.8618714213371,
#      501.1821755170822,
#      1231.294712483883],
#     [568.1174898147583,
#      1231.0441449284554,
#      421.97478371858597,
#      1106.1395446658134],
#     [2649.4358049035072,
#      1258.81057792902,
#      433.4211205840111,
#      1109.6331780552864],
#     [608.9860116392374,
#      1306.4190182089806,
#      341.31825552880764,
#      1011.4431511759758]],
#    'window': [[906.722712635994,
#      144.49995825439692,
#      716.0236020982265,
#      872.2841320857406],
#     [212.9083512686193,
#      142.32650393247604,
#      390.7725060917437,
#      843.8007568717003]],
#    'cloth': [[1610.2642695605755,
#      1531.6824758648872,
#      305.02514496445656,
#      879.888330757618],
#     [2675.4373388290405,
#      1299.018405675888,
#      334.0045261979103,
#      1056.4036991596222],
#     [592.5579624325037,
#      1518.7114220261574,
#      325.378560885787,
#      757.8730183243752]]},
#   'country': 'Vietnam'},
#  'T48_106_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/73962/canvas.json',
#    'label': 'T48_106_recto',
#    '@type': 'sc:Canvas',
#    'width': 3850,
#    'height': 3119,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/72922/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/f96a65182df8e5259bbe6cf7c6c927f8.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3850,
#       'height': 3119,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/f96a65182df8e5259bbe6cf7c6c927f8.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/73962/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'c1be2373-fd29-48fd-805e-e4953597da0d'},
#     {'label': 'notes', 'value': 'T48_106_recto'},
#     {'label': 'originalFileName', 'value': 'T48_106_recto.jpg'},
#     {'label': 'filename', 'value': '211.jpg'},
#     {'label': 'fileMD5', 'value': 'ba6b020da750ec9761448a6b9cd8d46a'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/73962/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'hors': [[1361.7645516991615,
#      1294.730203062296,
#      568.1143775582314,
#      476.9174410998821]],
#    'cart': [[1408.8426277041435,
#      1102.482125043869,
#      1190.7351449131966,
#      608.646878361702]],
#    'person': [[1890.8578217029572,
#      880.8486749231815,
#      315.0286138057709,
#      489.4051785171032]],
#    'hous': [[1764.8042440414429,
#      619.2913489937782,
#      809.0368956327438,
#      355.97004556655884]]},
#   'country': 'Myanmar'},
#  'T10_152_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/77768/canvas.json',
#    'label': 'T10_152_recto',
#    '@type': 'sc:Canvas',
#    'width': 3849,
#    'height': 3120,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/76728/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/060f757938efe14027512398e87c0d07.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3849,
#       'height': 3120,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/060f757938efe14027512398e87c0d07.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/77768/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '5ba28981-46e3-46f2-8ee8-d4898a83c5d9'},
#     {'label': 'notes', 'value': 'T10_152_recto'},
#     {'label': 'originalFileName', 'value': 'T10_152_recto.jpg'},
#     {'label': 'filename', 'value': '303.jpg'},
#     {'label': 'fileMD5', 'value': '60a0b60894079122d1e3285666b11bd8'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/77768/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'frame_pictur': [[77.4505853522569,
#      180.95679849386215,
#      3727.4655454885215,
#      2704.949325621128]],
#    'poa\n': [[2908, 1838, 149, 66]],
#    'poa': [[2908, 1847, 146, 57]]},
#   'country': None},
#  'T60_169_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/75472/canvas.json',
#    'label': 'T60_169_recto',
#    '@type': 'sc:Canvas',
#    'width': 3854,
#    'height': 3145,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/74432/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/25bdb4fa1a1be4a938303d3832adb699.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3854,
#       'height': 3145,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/25bdb4fa1a1be4a938303d3832adb699.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/75472/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '806fd57e-9ac0-471d-b28e-380bf9ca0dc9'},
#     {'label': 'notes', 'value': 'T60_169_recto'},
#     {'label': 'originalFileName', 'value': 'T60_169_recto.jpg'},
#     {'label': 'filename', 'value': '337.jpg'},
#     {'label': 'fileMD5', 'value': 'efb12ca3e32e35a35164612e1d0167e0'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/75472/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'glass': [[2097.1111232042313,
#      1198.3160842955112,
#      847.8601249456406,
#      343.2469207048416]],
#    'person': [[1252.7662319540977,
#      674.793784096837,
#      2149.846749842167,
#      2360.170124396682]]},
#   'country': 'Cambodia'},
#  'T11_191_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/67910/canvas.json',
#    'label': 'T11_191_recto',
#    '@type': 'sc:Canvas',
#    'width': 3848,
#    'height': 3111,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/66870/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/7c3a1b0402b0c45c839f89bf3ffaac0a.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3848,
#       'height': 3111,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/7c3a1b0402b0c45c839f89bf3ffaac0a.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/67910/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'b90c2a7a-4fbd-4096-b483-179e566678d7'},
#     {'label': 'notes', 'value': 'T11_191_recto'},
#     {'label': 'originalFileName', 'value': 'T11_191_recto.jpg'},
#     {'label': 'filename', 'value': '377.jpg'},
#     {'label': 'fileMD5', 'value': 'ead921fa7641bff15b02888c1f134d70'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/67910/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'bu': [[1372.0134906768799,
#      573.8929779678583,
#      1340.5308017730713,
#      506.61487640440464]],
#    'person': [[788.3286379575729,
#      713.9731422811747,
#      281.8706279993057,
#      923.7925284951925],
#     [585.0037224292755,
#      712.9889722913504,
#      245.08918035030365,
#      729.6250146478415],
#     [1196.7010099887848,
#      707.4294085353613,
#      221.97905778884888,
#      732.4474454373121],
#     [312.79898566007614,
#      709.4066027998924,
#      271.5494017004967,
#      820.2721700370312],
#     [2500.205638408661,
#      911.5662445127964,
#      669.7553071975708,
#      1531.0906372368336],
#     [1193.019459247589,
#      675.2792683392763,
#      238.94483351707458,
#      799.7014410942793],
#     [1336.6298694610596,
#      931.9921989440918,
#      310.628249168396,
#      769.3053300976753]],
#    'motorcycl': [[1279.45144033432,
#      996.6521209180355,
#      566.136677980423,
#      922.89008679986]],
#    'wheel': [[1336.3006250858307,
#      1495.6742394268513,
#      278.3492269515991,
#      432.4422537982464]],
#    "'heכסב\n": [[1909, 706, 304, 82]],
#    "'heכסב": [[1909, 714, 302, 74]]},
#   'country': 'South Korea'},
#  'F20_102_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/63426/canvas.json',
#    'label': 'F20_102_recto',
#    '@type': 'sc:Canvas',
#    'width': 2002,
#    'height': 1420,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/62386/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/dca14e451234b6d99e7bcbf4bbeb9498.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2002,
#       'height': 1420,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/dca14e451234b6d99e7bcbf4bbeb9498.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/63426/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'e5b61d37-bb06-4388-bb19-3920dba82ed1'},
#     {'label': 'notes', 'value': 'F20_102_recto'},
#     {'label': 'originalFileName', 'value': 'F20_102_recto.jpg'},
#     {'label': 'filename', 'value': '203.jpg'},
#     {'label': 'fileMD5', 'value': 'f5ae7104ffa2e38809b4bf69d59fa715'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/63426/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[87.6262056902051,
#      604.1321402788162,
#      134.0106698796153,
#      458.8802069425583],
#     [811.68772315979, 538.1065875291824, 464.8488210439682, 835.0632160902023],
#     [1351.5018097162247,
#      611.3298487663269,
#      198.68553042411804,
#      636.8733537197113],
#     [389.38849142193794,
#      394.38449680805206,
#      637.5449325740337,
#      953.1096810102463],
#     [1663.5399870872498,
#      615.9722757339478,
#      267.44082152843475,
#      703.2858741283417],
#     [1133.9827816486359,
#      568.8312864303589,
#      323.6287931203842,
#      775.2228403091431],
#     [1578.5241594314575,
#      654.2510962486267,
#      131.67315137386322,
#      384.7434413433075],
#     [823.1163504719734,
#      557.101731300354,
#      451.44363647699356,
#      802.5929307937622],
#     [160.2074145823717,
#      589.7720175981522,
#      276.5385903567076,
#      730.0299352407455],
#     [1675.1951595544815,
#      609.2254370450974,
#      257.12904930114746,
#      727.4045306444168]],
#    '10\n': [[1528, 1250, 61, 51]],
#    '10': [[1528, 1251, 60, 50]]},
#   'country': None},
#  'T42_215_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/72890/canvas.json',
#    'label': 'T42_215_recto',
#    '@type': 'sc:Canvas',
#    'width': 3612,
#    'height': 2722,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/71850/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/87187436f5dc2700e2087bc818ecec42.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3612,
#       'height': 2722,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/87187436f5dc2700e2087bc818ecec42.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
# ...
#     [776.352905601263,
#      202.84589360654354,
#      262.7000756561756,
#      465.45992209017277],
#     [510.49177123606205,
#      357.2436876296997,
#      222.7581845074892,
#      329.0545426905155],
#     [1115.9604273438454,
#      505.48987403512,
#      628.1573356986046,
#      734.2518974840641],
#     [310.09220315515995,
#      535.7169339358807,
#      715.6071741431952,
#      631.4785241782665]],
#    'food': [[962.5150421857834,
#      721.6070177257061,
#      229.75025820732117,
#      221.85651943087578],
#     [917.1578390598297,
#      926.1494910120964,
#      214.2028071284294,
#      187.53593838214874]],
#    'tire': [[60.890451937913895,
#      102.44139944761992,
#      334.0264959782362,
#      349.79103968292475]],
#    'tablewar': [[1164.0345427393913,
#      1025.2185940146446,
#      228.9415352344513,
#      186.3757803440094],
#     [956.7081135511398,
#      722.5733624696732,
#      242.1255802512169,
#      234.0159221291542]]},
#   'country': None},
#  'F56_21_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/66100/canvas.json',
#    'label': 'F56_21_recto',
#    '@type': 'sc:Canvas',
#    'width': 2683,
#    'height': 1842,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/65060/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/6b921a7a506347c8607c8a74d3536393.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2683,
#       'height': 1842,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/6b921a7a506347c8607c8a74d3536393.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/66100/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '80b0235e-ae98-46c5-a808-61e5d4d6358f'},
#     {'label': 'notes', 'value': 'F56_21_recto'},
#     {'label': 'originalFileName', 'value': 'F56_21_recto.jpg'},
#     {'label': 'filename', 'value': '41.jpg'},
#     {'label': 'fileMD5', 'value': '017e4fe49281277ddc570c4632163d59'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/66100/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {},
#   'country': None},
#  'T20_109_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/78128/canvas.json',
#    'label': 'T20_109_recto',
#    '@type': 'sc:Canvas',
#    'width': 1913,
#    'height': 1329,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/77088/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/9258b62b95c7bdf46ea4fb0fd0e4ee5f.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 1913,
#       'height': 1329,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/9258b62b95c7bdf46ea4fb0fd0e4ee5f.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/78128/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '509ab74f-89b4-499a-b8f6-cec8eed37f38'},
#     {'label': 'notes', 'value': 'T20_109_recto'},
#     {'label': 'originalFileName', 'value': 'T20_109_recto.jpg'},
#     {'label': 'filename', 'value': '217.jpg'},
#     {'label': 'fileMD5', 'value': 'f7ea59460bfdffbca0dcf0083d0b6d62'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/78128/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[1149.3504256606102,
#      299.9939843416214,
#      733.8416165113449,
#      959.9623562693596],
#     [566.1336985528469,
#      392.2064408361912,
#      319.92777067422867,
#      626.3119614422321]],
#    'tabl': [[593.6956178247929,
#      746.2734412550926,
#      767.8224421441555,
#      522.5979450345039],
#     [24.354128343053162,
#      1012.0300950407982,
#      364.6171218184754,
#      290.42185378074646]],
#    'stool': [[517.8874266445637,
#      963.317568719387,
#      575.1028016507626,
#      347.3644573688507]],
#    'food': [[717.6267642974854,
#      741.2481479644775,
#      477.6273166537285,
#      98.60091376304626]],
#    'hat': [[1155.6023443341255,
#      307.07158859074116,
#      230.88884115219116,
#      182.10695596039295]]},
#   'country': None},
#  'T34_40_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/71602/canvas.json',
#    'label': 'T34_40_recto',
#    '@type': 'sc:Canvas',
#    'width': 3848,
#    'height': 3114,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/70562/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/5323a9cfbd831a08e11accc968d2d750.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3848,
#       'height': 3114,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/5323a9cfbd831a08e11accc968d2d750.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/71602/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '226be7f9-f866-4f8a-bde9-732a380aa6ab'},
#     {'label': 'notes', 'value': 'T34_40_recto'},
#     {'label': 'originalFileName', 'value': 'T34_40_recto.jpg'},
#     {'label': 'filename', 'value': '79.jpg'},
#     {'label': 'fileMD5', 'value': 'e810d85f6e5e474d37bb694107101d9e'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/71602/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'furnitur': [[169.3757177889347,
#      1646.3417129516602,
#      419.8226307332516,
#      592.0343656539917],
#     [2095.857536315918,
#      1454.076636850834,
#      642.6113963127136,
#      297.40154653787613],
#     [622.9132133722305,
#      1509.2524909973145,
#      476.3910948038101,
#      658.1758986711502]],
#    'build': [[123.33566257357597,
#      67.67568308115005,
#      3665.7742045223713,
#      2435.5998811125755]],
#    '11\n': [[994, 1248, 151, 117]],
#    '11': [[996, 1248, 149, 114]]},
#   'country': 'Japan'},
#  'T11_13_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/67558/canvas.json',
#    'label': 'T11_13_recto',
#    '@type': 'sc:Canvas',
#    'width': 3120,
#    'height': 3846,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/66518/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/7f876d17fd5d19d42eb6bc96e003477f.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3120,
#       'height': 3846,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/7f876d17fd5d19d42eb6bc96e003477f.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/67558/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '97cce98b-0110-4453-b93a-186f71f11ba7'},
#     {'label': 'notes', 'value': 'T11_13_recto'},
#     {'label': 'originalFileName', 'value': 'T11_13_recto.jpg'},
#     {'label': 'filename', 'value': '25.jpg'},
#     {'label': 'fileMD5', 'value': 'c44956308d2794efc038e5c6ef5410ba'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/67558/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'furnitur': [[852.8237342834473,
#      3078.2667199373245,
#      973.1948232650757,
#      614.7473437786102]],
#    'frame_pictur': [[223.73217165470123,
#      1252.9694963693619,
#      985.3915518522263,
#      1965.737113237381]],
#    '707\n저 하\n': [[940, 454, 497, 3236]],
#    '707': [[940, 454, 169, 73]],
#    '저': [[1195, 3534, 89, 120]],
#    '하': [[1365, 3572, 72, 107]]},
#   'country': 'South Korea'},
#  'T36_20_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/72034/canvas.json',
#    'label': 'T36_20_recto',
#    '@type': 'sc:Canvas',
#    'width': 2762,
#    'height': 1988,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/70994/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/f9dd01bddebf682e3d20bf47ba8751b8.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2762,
#       'height': 1988,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/f9dd01bddebf682e3d20bf47ba8751b8.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/72034/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'c1156c7b-66bf-4b58-ae2b-93f2026b6735'},
#     {'label': 'notes', 'value': 'T36_20_recto'},
#     {'label': 'originalFileName', 'value': 'T36_20_recto.jpg'},
#     {'label': 'filename', 'value': '39.jpg'},
#     {'label': 'fileMD5', 'value': 'f229cd1395782a102e1bda78db599075'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/72034/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'hat_sun': [[555.3354494571686,
#      594.1701437234879,
#      614.8653562664986,
#      326.052686214447]],
#    'person': [[449.56704437732697,
#      602.645310997963,
#      782.6134978532791,
#      1220.3081411123276]],
#    '技家\na881\nkg\nincapen\n': [[1363, 1128, 342, 490]],
#    '技': [[1464, 1165, 70, 25]],
#    '家': [[1387, 1169, 22, 22]],
#    'a881': [[1527, 1134, 127, 41]],
#    'kg': [[1514, 1500, 167, 73]],
#    'incapen': [[1508, 1584, 197, 33]]},
#   'country': None},
#  'F56_33_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/66124/canvas.json',
#    'label': 'F56_33_recto',
#    '@type': 'sc:Canvas',
#    'width': 1913,
#    'height': 2818,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/65084/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/500d23cfd21a09aa1079929db6507454.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 1913,
#       'height': 2818,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/500d23cfd21a09aa1079929db6507454.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/66124/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'a8a24932-afc9-48cc-86c8-ccadb9d3052b'},
#     {'label': 'notes', 'value': 'F56_33_recto'},
#     {'label': 'originalFileName', 'value': 'F56_33_recto.jpg'},
#     {'label': 'filename', 'value': '65.jpg'},
#     {'label': 'fileMD5', 'value': 'f052c9afc17c06685d44109e58277c3b'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/66124/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'frame_pictur': [[98.93738266825676,
#      356.56105449795723,
#      1688.9517247974873,
#      1967.601259559393]],
#    'bag_luggag': [[73.9911311082542,
#      398.6713626086712,
#      1693.603926796466,
#      1905.5705329477787]],
#    '34_5\nviiis-xs siècle\ncarreau\nvuang-binh\nmy-đưc\n34 5\n': [[803,
#      251,
#      788,
#      1994]],
#    '34_5': [[817, 278, 90, 28]],
#    'viiis-xs': [[1024, 267, 142, 41]],
#    'siècle': [[1161, 257, 78, 39]],
#    'carreau': [[900, 347, 231, 46]],
#    'vuang-binh': [[803, 453, 187, 42]],
#    'my-đưc': [[1110, 429, 143, 53]],
#    '34': [[1318, 2148, 109, 65]],
#    '5': [[1436, 2173, 155, 61]]},
#   'country': None},
#  'T10_173_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/77810/canvas.json',
#    'label': 'T10_173_recto',
#    '@type': 'sc:Canvas',
#    'width': 3862,
#    'height': 3121,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/76770/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/e6a18046a0b69ef9d694fee4b2286758.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3862,
#       'height': 3121,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/e6a18046a0b69ef9d694fee4b2286758.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/77810/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '2d5ff951-9ef1-4e2b-8280-1cccde153297'},
#     {'label': 'notes', 'value': 'T10_173_recto'},
#     {'label': 'originalFileName', 'value': 'T10_173_recto.jpg'},
#     {'label': 'filename', 'value': '345.jpg'},
#     {'label': 'fileMD5', 'value': '1277f6a8f75be6ee7aa5d49ce97ffa61'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/77810/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'person': [[534.5329822897911,
#      1724.3372756242752,
#      279.38667780160904,
#      630.1064773797989],
#     [1424.5289424061775,
#      1666.9333428144455,
#      192.7029628753662,
#      660.7526025176048],
#     [1053.5266616940498,
#      1736.2546654343605,
#      206.5345779657364,
#      545.4430245161057],
#     [1252.3928156495094,
#      1734.3309695720673,
#      201.64251339435577,
#      562.8809247612953]],
#    'build': [[838.742939978838,
#      421.9076050668955,
#      2866.4745853841305,
#      1897.1457992643118]]},
#   'country': None},
#  'T10_125_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/77714/canvas.json',
#    'label': 'T10_125_recto',
#    '@type': 'sc:Canvas',
#    'width': 3855,
#    'height': 3116,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/76674/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/09f3d41ea923f888bc5c4f965263e025.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3855,
#       'height': 3116,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/09f3d41ea923f888bc5c4f965263e025.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/77714/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '2ee7ee35-25ff-4fb7-a95c-af8953dabdf6'},
#     {'label': 'notes', 'value': 'T10_125_recto'},
#     {'label': 'originalFileName', 'value': 'T10_125_recto.jpg'},
#     {'label': 'filename', 'value': '249.jpg'},
#     {'label': 'fileMD5', 'value': 'e25675bd252c88d6191a5e97a2206124'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/77714/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'frame_pictur': [[148.78973616287112,
#      428.27607494592667,
#      3600.43269591406,
#      2478.3652977347374]]},
#   'country': None},
#  'T12_43_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/67172/canvas.json',
#    'label': 'T12_43_recto',
#    '@type': 'sc:Canvas',
#    'width': 3855,
#    'height': 3110,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/66132/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/182d15ebc59f03371da1898950cf6e03.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3855,
#       'height': 3110,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/182d15ebc59f03371da1898950cf6e03.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/67172/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '2239f4b9-c5de-460d-a050-000f53ec42fe'},
#     {'label': 'notes', 'value': 'T12_43_recto'},
#     {'label': 'originalFileName', 'value': 'T12_43_recto.jpg'},
#     {'label': 'filename', 'value': '85.jpg'},
#     {'label': 'fileMD5', 'value': '03565a920ee17c153836ff70738b387e'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/67172/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {'frame_pictur': [[118.88492622412741,
#      116.07906550168991,
#      3609.6025281306356,
#      2782.829227745533]],
#    'anim': [[3091.1745688319206,
#      1572.7106630802155,
#      462.1804475784302,
#      264.6291011571884]]},
#   'country': None}}

# %%
with open('tagged_images.json', 'w') as fp:
    json.dump(tagged_images, fp, indent=4)
    
with open('annotated_images.json', 'w') as fp:
    json.dump(annotated_images, fp, indent=4)

if len(failed_images) > 0:
    print("There are failed images")
    with open('failed_images.json', 'w') as fp:
        json.dump(failed_images, fp, indent=4)

# %% [markdown]
# ## Inserting the data into Mangodb
#
# # TODO: The insert the data into database.

# %%
# creating a client to work with mango db
mangoclient = pymongo.MongoClient(MANGO_CLIENT_URI)
# selecting the <terzani_photos> database
mango_db = mangoclient["terzani_photos"]

# %% [markdown]
# ### Storing the Image Tags

# %%
# creating a new collection named <sample_tagging>
mango_tag_collection = mango_db["sample_taggings"]
# inserting the dictionary into the db
for tag, img_labels in tagged_images.items():
    mango_tag_collection.insert_one({"tag":tag,"images":img_labels})

# %% [markdown]
# ### Storing the Image information

# %%
# creating a new collection named <sample_annotations>
mango_box_collection = mango_db["sample_annotations"]
# inserting the dictionary into the db
for img_label, annotation in annotated_images.items():
    mango_box_collection.insert_one({"label":img_label,"annotation":annotation})
