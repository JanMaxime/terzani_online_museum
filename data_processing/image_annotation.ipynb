# %% [markdown]
# # Image annotation script

# %% [markdown]
# This notebook will serve as a prototype to create a script to annotate all the images of Terzani collection

# %% [markdown]
# ## Installing the client library
#
# If the Google cloud vision library is not installed already, install it.
#
# If you have python environment use
#
# ```shell
# pip install --upgrade google-cloud-vision
# ```
#
# If you have conda environment use
#
# ```shell
# conda install -c conda-forge google-cloud-vision
# ```

# %% [markdown]
# ## Installing other libraries
#
# Install `dotenv` to get the environment variables
#
# If you have python environment use
#
# ```shell
# pip install python-dotenv
# ```
#
# If you have conda environment use
#
# ```shell
# conda install -c conda-forge python-dotenvn
# ```
#
# pip install python-dotenv

# %% [markdown]
# ## Import the libraries

# %%
## Import the standard libraries
import os, io, pickle, random, json
## Import Vison API related libraries
from google.cloud import vision
from google.cloud.vision import types
## Import dotenv library to get environment variables
from dotenv import load_dotenv
# Import urllib to read images
import urllib.request as ur
# Import pymango to inset data into mangodb
import pymongo
from tqdm import tqdm
# 
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
import nltk
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Maxime\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Setup the service account credentials to use the API

# %%
load_dotenv()

GOOGLE_APPLICATION_CREDENTIALS = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = GOOGLE_APPLICATION_CREDENTIALS

MANGO_CLIENT_URI = os.getenv('MONGO_URI')
os.environ['MANGO_CLIENT_URI'] = MANGO_CLIENT_URI

# %% [markdown]
# ## Creation of Client to access the API

# %%
client = vision.ImageAnnotatorClient()

# %% [markdown]
# ## Image selection
#
# As this is a prototyping script we shall select 10 images randomly each from the color and monochrome photos (using the already created pickle files).

# %% [markdown]
# Generic class to store an image and its IIIF representation

# %%
class Terzani_Photo(object):
    def __init__(self, iiif, country):
        self.iiif = iiif
        self.photo = country
        
    def get_photo_link(self):
        return self.iiif["images"][0]["resource"]["@id"]

# %%
nu_of_images_per_type = 20

'''
# loading the color photos
color_photos = pickle.load(open("terzani_recto_iiif_color.pickle", "rb" ))
# randomly selecting 10 images
color_photos = random.sample(color_photos, nu_of_images_per_type)

# loading the monochrome photos
bw_photos = pickle.load(open("terzani_recto_iiif_color.pickle", "rb" ))
# randomly selecting 10 images
bw_photos = random.sample(bw_photos, nu_of_images_per_type)

all_photos = color_photos + bw_photos

'''

all_photos = pickle.load(open("terzani_recto_iiif.pickle", "rb"))
all_photos = random.sample(all_photos, nu_of_images_per_type)

# %% [markdown]
# ## Function to clean text

# %%
def clean_text(text: str, lower: bool=True, rmv_punc: bool = True, stem: bool = True, norm: bool = True):
    """
    This function accepts a string and performs preprocessing steps on it. 
    
    :param text (str): The string or text on which the preprocessing has to be performed.
    :param lower (bool): Default=True, indicates if the text has to be made into lower case.
    :param rmv_punc (bool): Default=True, indicates if the punctuation should be removed in the text.
    :param stem (bool): Default=True, indicates if the stemming should be performed on the words in the text.
    :param norm (bool): Default=True, indicates if the words in the has to be normalised.
    :return cleaned_text (list): The modified text is returned as list after performing the indicated operations.
    """
    
    # split into words
    tokens = word_tokenize(text)
    if lower:
        # convert to lower case
        tokens = [w.lower() for w in tokens]
    if rmv_punc:
        # remove punctuation from each word
        table = str.maketrans('', '', string.punctuation)
        tokens = [w.translate(table) for w in tokens if w.translate(table) != '']
    if stem:
        # stemming of words
        porter = PorterStemmer()
        tokens = [porter.stem(word) for word in tokens]
    cleaned_text = list(set(tokens))
    return cleaned_text

# %% [markdown]
# ## Calling the Vision API
#
# The structure of tagged images will be
# ```json
# {'tag1': [label_1],
#  'tag2': [label_2, label_4],
#  'tag3': [label_3],
#  'tag4': [label_3]
# }
# ```
#
# The structure of annotated_images will be
# ```json
# {'label_1':
#     {
#     'iiif': IIIF ANNOTATION,
#     'obj_boxes':
#     {
#     frozenset({'tag1'}): [[x1, y1, w1, h1]],
#     frozenset({'tag2'}): [[x4, y4, w4, h4], [x2, y2, w2, h2], [x3, y3, w3, h3]],
#     frozenset({'tag3', 'tag4'}): [[x5, y5, w5, h5], [x6, y6, w6, h6], [x7, y7, w7, h7]]
#     },
#     'landmark_info':
#     {
#     'landmark1_name':{"latitude":la1, "longitude":lt1},
#     'landmark2_name':{"latitude":la2, "longitude":lt2}
#     },
#     'country': None
#     },
# 'label_2':
#     {
#     'iiif': IIIF ANNOTATION,
#     'obj_boxes':
#     {
#     frozenset({'tag4'}): [[x1, y1, w1, h1]],
#     frozenset({'tag5'}): [[x4, y4, w4, h4],],
#     frozenset({'tag6'}): [[x5, y5, w5, h5], [x6, y6, w6, h6]]
#     },
#     'landmark_info':
#     {
#     'landmark3_name':{"latitude":la3, "longitude":lt3},
#     'landmark4_name':{"latitude":la4, "longitude":lt4}
#     },
#     'country': None
#     }
# }
# ```

# %%
tagged_images = dict() # The keys would be the tags, entities and objects found in the annotation and the values would be the image labels.
annotated_images = dict() # The keys would be the image labels and the values will be the IIIF annotation, name of the country, lat,lon if there is geotag and object localization.
failed_images = dict() # We store information about images that are failed to be annotated by google api.

for img in tqdm(all_photos):

    # if the image is already not present in the either annotated and failed dictionaries
    if img.iiif["label"] not in annotated_images and img.iiif["label"] not in failed_images:

        # get the image label
        img_lbl = img.iiif["label"]
        img_country = img.country
                
        # reading the image
        image_data = ur.urlopen(img.get_photo_link()).read()
        image = types.Image(content=image_data)
        
        # call the goole vision api to get the annotations of various types
        response = client.annotate_image({
            'image': image,
            'features': [{'type': vision.enums.Feature.Type.LANDMARK_DETECTION}, 
                         {'type': vision.enums.Feature.Type.LOGO_DETECTION},
                         {'type': vision.enums.Feature.Type.LABEL_DETECTION},
                         {'type': vision.enums.Feature.Type.TEXT_DETECTION},
                         {'type': vision.enums.Feature.Type.OBJECT_LOCALIZATION},
                         {'type': vision.enums.Feature.Type.WEB_DETECTION}],})
        
        # check if there is any error returned by the api
        if response.error.code != 0:
            failed_images[img_lbl] = {}
            failed_images[img_lbl]["error"] = [response.error.code, response.error.message]
        else:
            # if the API call is successful
            annotated_images[img_lbl] = {}
        
            # store the iiif description
            annotated_images[img_lbl]["iiif"] = img.iiif

            # get the list of labels
            labels = list()
            for lbl in response.label_annotations:
                labels.extend(clean_text(lbl.description))
            labels = list(set(labels))
            
            # Add the label and image label to the dictionary to perform search
            for label in labels:
                if label not in tagged_images:
                    tagged_images[label] = []
                if img_lbl not in tagged_images[label]:
                    tagged_images[label].append(img_lbl)
            
            # get the list of web entities
            webent = list()
            for weben in response.web_detection.web_entities:
                webent.extend(clean_text(weben.description))
            webent = list(set(webent))
            
            # Add the web entity and image label to the dictionary to perform search
            for web_entity in labels:
                if web_entity not in tagged_images:
                    tagged_images[web_entity] = []
                if img_lbl not in tagged_images[web_entity]:
                    tagged_images[web_entity].append(img_lbl)
            

            obj_boxes = {} # this dictionary will store the information of annotations along with bounding boxes.
            # The key will the the name to identify the annotation and the value be a list of lists containing the top left x coordinate
            # top left y coordinate, width and height of for the bounding box.
            # It would be a list of list to store coordinates for different boxes for same tag

            # storing the landmarks
            landmark_info = dict() # this dictionary will store the information of landmarks which are name, latitude, longitude.
            for lndmk in response.landmark_annotations:
                
                # if there are any landamrks identified, we store them in a seperate field,to access easily.
                landmark_name = lndmk.description.lower()
                landmark_info[landmark_name] = {"latitude":lndmk.locations[0].lat_lng.latitude, "longitude":lndmk.locations[0].lat_lng.longitude}
                
                
                lndmks = clean_text(lndmk.description)
                # we add the landmarks and image label to the dictionary to perform search
                for land_mark in lndmks:
                    if land_mark not in tagged_images:
                        tagged_images[land_mark] = []
                    if img_lbl not in tagged_images[land_mark]:
                        tagged_images[land_mark].append(img_lbl)
                
                # storing the landmarks with bounding boxes 
                lndmk_desc = frozenset(lndmks)
                if lndmk_desc not in obj_boxes:
                    obj_boxes[lndmk_desc] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lndmk.bounding_poly.vertices[0].x, lndmk.bounding_poly.vertices[0].y
                box_width = lndmk.bounding_poly.vertices[1].x - lndmk.bounding_poly.vertices[0].x
                box_height = lndmk.bounding_poly.vertices[3].y - lndmk.bounding_poly.vertices[0].y
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height] 
                    obj_boxes[lndmk_desc].append(vert)    

            for lgo in response.logo_annotations:
                
                logos = clean_text(lgo.description)
                # we add the logo names and image label to the dictionary to perform search
                for lgo_name in logos:
                    if lgo_name not in tagged_images:
                        tagged_images[lgo_name] = []
                    if img_lbl not in tagged_images[lgo_name]:
                        tagged_images[lgo_name].append(img_lbl)
                        
                lgo_desc = frozenset(logos)
                if lgo_desc not in obj_boxes:
                    obj_boxes[lgo_desc] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lgo.bounding_poly.vertices[0].x, lgo.bounding_poly.vertices[0].y
                box_width = abs(lgo.bounding_poly.vertices[1].x - lgo.bounding_poly.vertices[0].x)
                box_height = abs(lgo.bounding_poly.vertices[3].y - lgo.bounding_poly.vertices[0].y)
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[lgo_desc].append(vert)

            if len(response.localized_object_annotations) > 0:
                img_width, img_height = img.iiif["width"], img.iiif["height"]
            for lobj in response.localized_object_annotations:
                
                objects = clean_text(lobj.name)  
                # we add the object names and image label to the dictionary to perform search
                for obj_name in objects:
                    if obj_name not in tagged_images:
                        tagged_images[obj_name] = []
                    if img_lbl not in tagged_images[obj_name]:
                        tagged_images[obj_name].append(img_lbl)
                
                lobj_name = frozenset(objects)
                if lobj_name not in obj_boxes:
                    obj_boxes[lobj_name] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = lobj.bounding_poly.normalized_vertices[0].x * img_width, lobj.bounding_poly.normalized_vertices[0].y * img_height
                box_width = (lobj.bounding_poly.normalized_vertices[1].x - lobj.bounding_poly.normalized_vertices[0].x) * img_width
                box_height = (lobj.bounding_poly.normalized_vertices[3].y - lobj.bounding_poly.normalized_vertices[0].y) * img_height
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[lobj_name].append(vert)

            for txt in response.text_annotations:
                modified_text = txt.description.replace(".", "_").lower()
                # we add the text and image label to the dictionary to perform search
                if modified_text not in tagged_images:
                    tagged_images[modified_text] = []
                if img_lbl not in tagged_images[modified_text]:
                        tagged_images[modified_text].append(img_lbl)    
                
                # the text identified on the images in not cleaned to store the original information.
                if modified_text not in obj_boxes:
                    obj_boxes[modified_text] = list()
                ulx, uly, box_width, box_height = None, None, None, None
                ulx, uly = txt.bounding_poly.vertices[0].x, txt.bounding_poly.vertices[0].y
                box_width = abs(txt.bounding_poly.vertices[1].x - txt.bounding_poly.vertices[0].x)
                box_height = abs(txt.bounding_poly.vertices[3].y - txt.bounding_poly.vertices[0].y)
                if (ulx and uly and box_width and box_height) is not None:
                    vert = [ulx, uly, box_width, box_height]
                    obj_boxes[modified_text].append(vert)

            # store the generated object boxes into the dictionary.
            annotated_images[img_lbl]["obj_boxes"] = obj_boxes
            
            # store the generated land mark information into the dictionary.
            annotated_images[img_lbl]["landmark_info"] = landmark_info
            
            # store the generated land mark information into the dictionary.
            annotated_images[img_lbl]["country"] = img_country
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:36<00:00,  4.81s/it]

# %% [markdown]
# ## Saving the dictionaries to JSON file

# %%
tagged_images
# Out:
# {'room': ['F26_148_recto',
#   'T6_155_recto',
#   'T6_163_recto',
#   'T10_79_recto',
#   'F26_105_recto',
#   'T35_49_recto'],
#  'stock': ['F26_148_recto',
#   'T43_7_recto',
#   'T4_157_recto',
#   'F25_164_recto',
#   'F25_155_recto',
#   'T6_155_recto',
#   'T42_130_recto',
#   'Cina5_193_recto',
#   'F27_180_recto',
#   'T42_203_recto',
#   'T6_163_recto',
#   'Cina7_83_recto',
#   'T10_79_recto',
#   'T36_12_recto',
#   'T55_55_recto',
#   'F26_105_recto'],
#  'photograph': ['F26_148_recto',
#   'T43_7_recto',
#   'T4_157_recto',
#   'T4_122_recto',
#   'F25_155_recto',
#   'T6_155_recto',
#   'Cina5_193_recto',
#   'F27_180_recto',
#   'T6_163_recto',
#   'T10_79_recto',
#   'T62_20_recto',
#   'T21_71_recto',
#   'T36_12_recto',
#   'T55_55_recto',
#   'F26_105_recto',
#   'T35_49_recto'],
#  'blackandwhit': ['F26_148_recto',
#   'T43_7_recto',
#   'T4_157_recto',
#   'T4_122_recto',
#   'F25_164_recto',
#   'F25_155_recto',
#   'T6_155_recto',
#   'T42_130_recto',
#   'Cina5_193_recto',
#   'F27_180_recto',
#   'T42_203_recto',
#   'T6_163_recto',
#   'Cina7_83_recto',
#   'T10_79_recto',
#   'T62_20_recto',
#   'T21_71_recto',
#   'T36_12_recto',
#   'T55_55_recto',
#   'F26_105_recto',
#   'T35_49_recto'],
#  'art': ['F26_148_recto', 'F25_164_recto', 'T6_155_recto', 'T55_55_recto'],
#  'photographi': ['F26_148_recto',
#   'T43_7_recto',
#   'T4_157_recto',
#   'T4_122_recto',
#   'F25_164_recto',
#   'F25_155_recto',
#   'T6_155_recto',
#   'T42_130_recto',
#   'Cina5_193_recto',
#   'F27_180_recto',
#   'T42_203_recto',
#   'T6_163_recto',
#   'Cina7_83_recto',
#   'T10_79_recto',
#   'T62_20_recto',
#   'T21_71_recto',
#   'T36_12_recto',
#   'T55_55_recto',
#   'F26_105_recto',
#   'T35_49_recto'],
#  'person': ['F26_148_recto',
#   'T43_7_recto',
#   'T4_157_recto',
#   'T4_122_recto',
#   'T42_130_recto',
#   'Cina5_193_recto',
#   'F27_180_recto',
#   'T6_163_recto',
#   'T10_79_recto',
#   'T21_71_recto',
#   'T36_12_recto',
#   'T35_49_recto'],
#  'footwear': ['F26_148_recto'],
#  'luggag': ['F26_148_recto'],
#  'bag': ['F26_148_recto'],
#  'coat': ['F26_148_recto'],
#  'anim': ['F26_148_recto'],
#  'snapshot': ['T43_7_recto',
#   'T4_157_recto',
#   'T4_122_recto',
#   'T42_130_recto',
#   'Cina5_193_recto',
#   'F27_180_recto',
#   'T6_163_recto',
#   'Cina7_83_recto',
#   'T10_79_recto',
#   'T36_12_recto',
#   'F26_105_recto',
#   'T35_49_recto'],
#  'monochrom': ['T43_7_recto',
#   'T4_157_recto',
#   'T4_122_recto',
#   'F25_155_recto',
#   'T6_155_recto',
#   'T42_130_recto',
#   'Cina5_193_recto',
#   'F27_180_recto',
#   'T42_203_recto',
#   'T6_163_recto',
#   'Cina7_83_recto',
#   'T10_79_recto',
#   'T62_20_recto',
#   'T36_12_recto',
#   'F26_105_recto'],
#  'cloth': ['T43_7_recto',
#   'T4_122_recto',
#   'T42_130_recto',
#   'Cina5_193_recto',
#   'T6_163_recto',
#   'T10_79_recto',
#   'T36_12_recto',
#   'T35_49_recto'],
#  'ece tlle\nteak ete\nii\nd_llna\nglnlang\n': ['T43_7_recto'],
#  'ece': ['T43_7_recto'],
#  'tlle': ['T43_7_recto'],
#  'teak': ['T43_7_recto'],
#  'ete': ['T43_7_recto'],
#  'ii': ['T43_7_recto'],
#  'd_llna': ['T43_7_recto'],
#  'glnlang': ['T43_7_recto'],
#  'adapt': ['T4_157_recto', 'F25_164_recto', 'T6_163_recto', 'T10_79_recto'],
#  'stand': ['T4_157_recto', 'Cina5_193_recto', 'F27_180_recto'],
#  'phenomenon': ['T4_157_recto'],
#  'atmospher': ['T4_157_recto'],
#  'pant': ['T4_157_recto', 'F27_180_recto'],
#  'hair': ['T4_122_recto'],
#  'moustach': ['T4_122_recto'],
#  'facial': ['T4_122_recto'],
#  'portrait': ['T4_122_recto', 'F27_180_recto', 'T6_163_recto'],
#  'forehead': ['T4_122_recto'],
#  'outerwear': ['T4_122_recto', 'F27_180_recto', 'T6_163_recto'],
#  'histori': ['F25_164_recto', 'F25_155_recto', 'T10_79_recto', 'T21_71_recto'],
#  'build': ['F25_164_recto',
#   'F25_155_recto',
#   'T42_203_recto',
#   'T62_20_recto',
#   'T36_12_recto'],
#  'site': ['F25_155_recto'],
#  'canal': ['F25_155_recto'],
#  'histor': ['F25_155_recto'],
#  'architectur': ['F25_155_recto',
#   'T42_203_recto',
#   'T62_20_recto',
#   'T36_12_recto',
#   'F26_105_recto'],
#  'waterway': ['F25_155_recto'],
#  'frame': ['F25_155_recto', 'T6_155_recto', 'T6_163_recto'],
#  'pictur': ['F25_155_recto', 'T6_155_recto', 'T6_163_recto'],
#  'paper': ['T6_155_recto'],
#  'visual': ['T6_155_recto'],
#  'still': ['T6_155_recto', 'Cina7_83_recto', 'T55_55_recto'],
#  'life': ['T6_155_recto', 'Cina7_83_recto', 'T55_55_recto'],
#  'style': ['T42_130_recto', 'F27_180_recto', 'T36_12_recto'],
#  'crew': ['T42_130_recto', 'T21_71_recto'],
#  'hat': ['T42_130_recto', 'T21_71_recto', 'T35_49_recto'],
#  'c gi quý hơn đốc-lập từ-do!\n': ['T42_130_recto'],
#  'c': ['T42_130_recto'],
#  'gi': ['T42_130_recto'],
#  'quý': ['T42_130_recto'],
#  'hơn': ['T42_130_recto'],
#  'đốc-lập': ['T42_130_recto'],
#  'từ-do!': ['T42_130_recto'],
#  'street': ['Cina5_193_recto', 'Cina7_83_recto'],
#  'tree': ['Cina5_193_recto', 'T36_12_recto'],
#  'hous': ['Cina5_193_recto', 'T62_20_recto'],
#  'tablewar': ['Cina5_193_recto'],
#  'v030\n': ['Cina5_193_recto'],
#  'v030': ['Cina5_193_recto'],
#  'glass': ['F27_180_recto'],
#  'furnitur': ['F27_180_recto', 'F26_105_recto'],
#  '1986\n209\n1777\n1684\n1552\n421\n145\nhakue\n': ['F27_180_recto'],
#  '1986': ['F27_180_recto'],
#  '209': ['F27_180_recto'],
#  '1777': ['F27_180_recto'],
#  '1684': ['F27_180_recto'],
#  '1552': ['F27_180_recto'],
#  '421': ['F27_180_recto'],
#  '145': ['F27_180_recto'],
#  'hakue': ['F27_180_recto'],
#  'vehicl': ['T42_203_recto', 'Cina7_83_recto'],
#  'ship': ['T42_203_recto'],
#  'cloud': ['T42_203_recto'],
#  'passeng': ['T42_203_recto'],
#  'sky': ['T42_203_recto'],
#  '927\ncaution\nchú-ý\nsteady red_ stop\nđến đó ngưng lại\nflashing red_ stop\njf clear go\nđen chớp đó quan-sat hay đi\n': ['T42_203_recto'],
#  '927': ['T42_203_recto'],
#  'caution': ['T42_203_recto'],
#  'chú-ý': ['T42_203_recto'],
#  'steady': ['T42_203_recto'],
#  'red_': ['T42_203_recto'],
#  'stop': ['T42_203_recto'],
#  'đến': ['T42_203_recto'],
#  'đó': ['T42_203_recto'],
#  'ngưng': ['T42_203_recto'],
#  'lại': ['T42_203_recto'],
#  'flashing': ['T42_203_recto'],
#  'jf': ['T42_203_recto'],
#  'clear': ['T42_203_recto'],
#  'go': ['T42_203_recto'],
#  'đen': ['T42_203_recto'],
#  'chớp': ['T42_203_recto'],
#  'quan-sat': ['T42_203_recto'],
#  'hay': ['T42_203_recto'],
#  'đi': ['T42_203_recto'],
#  '1tot\n': ['T6_163_recto'],
#  '1tot': ['T6_163_recto'],
#  'bicycl': ['Cina7_83_recto'],
#  'wheel': ['Cina7_83_recto', 'F26_105_recto'],
#  'tire': ['Cina7_83_recto'],
#  '囍\n囍\n0402192\n11657228\n': ['Cina7_83_recto'],
#  '囍': ['Cina7_83_recto'],
#  '0402192': ['Cina7_83_recto'],
#  '11657228': ['Cina7_83_recto'],
#  'peopl': ['T10_79_recto'],
#  'facad': ['T62_20_recto'],
#  'black': ['T62_20_recto'],
#  'white': ['T62_20_recto', 'F26_105_recto'],
#  'window': ['T62_20_recto'],
#  'door': ['T62_20_recto'],
#  '6v0\n': ['T62_20_recto'],
#  '6v0': ['T62_20_recto'],
#  'headgear': ['T21_71_recto'],
#  'uniform': ['T21_71_recto', 'T35_49_recto'],
#  'sailor': ['T21_71_recto'],
#  'team': ['T21_71_recto'],
#  'ducado': ['T21_71_recto'],
#  'tie': ['T21_71_recto'],
#  'coronel\nbilladas\ngotangogan\n': ['T21_71_recto'],
#  'coronel': ['T21_71_recto'],
#  'billadas': ['T21_71_recto'],
#  'gotangogan': ['T21_71_recto'],
#  'carv': ['T55_55_recto'],
#  'stone': ['T55_55_recto'],
#  'sculptur': ['T55_55_recto'],
#  'statu': ['T55_55_recto'],
#  'classic': ['T55_55_recto'],
#  'chef': ['T35_49_recto'],
#  'chief': ['T35_49_recto'],
#  'cook': ['T35_49_recto'],
#  's': ['T35_49_recto'],
#  'にしひら\n%3d\nfrance\n': ['T35_49_recto'],
#  'にしひら': ['T35_49_recto'],
#  '%3d': ['T35_49_recto'],
#  'france': ['T35_49_recto']}

# %%
annotated_images
# Out:
# {'F26_148_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/65938/canvas.json',
#    'label': 'F26_148_recto',
#    '@type': 'sc:Canvas',
#    'width': 3824,
#    'height': 2911,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/64898/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/f55c28dfc6bbd6fb03d8569a50397b54.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3824,
#       'height': 2911,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/f55c28dfc6bbd6fb03d8569a50397b54.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/65938/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '535aaa5b-2db5-4897-a585-f5d400c4cd31'},
#     {'label': 'notes', 'value': 'F26_148_recto'},
#     {'label': 'originalFileName', 'value': 'F26_148_recto.jpg'},
#     {'label': 'filename', 'value': '295.jpg'},
#     {'label': 'fileMD5', 'value': '8b7c9ad9247ac0c2a19e5676b4c99fb7'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/65938/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[263.368341088295,
#      258.5332098826766,
#      914.6897586584091,
#      2216.2386601939797],
#     [2810.7107124328613,
#      558.2095098048449,
#      822.1238870620728,
#      2028.8260581940413]],
#    frozenset({'footwear'}): [[896.0786550045013,
#      2223.1211814284325,
#      465.426855802536,
#      241.20821571350098],
#     [651.520626783371,
#      2304.622232735157,
#      357.6820228099823,
#      297.54419815540314]],
#    frozenset({'bag',
#               'luggag'}): [[2601.4851961135864,
#      1514.0029378533363,
#      298.7759838104248,
#      453.8620353937149], [2331.718997001648,
#      2191.1550755500793,
#      525.5335063934326,
#      348.2536268234253]],
#    frozenset({'coat'}): [[2796.3001823425293,
#      956.3834891915321,
#      626.1485185623169,
#      1511.1398638486862]],
#    frozenset({'anim'}): [[1044.3685460090637,
#      1589.1610162258148,
#      1328.1935820579529,
#      490.947527885437]]},
#   'landmark_info': {},
#   'country': None},
#  'T43_7_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/73412/canvas.json',
#    'label': 'T43_7_recto',
#    '@type': 'sc:Canvas',
#    'width': 3075,
#    'height': 3846,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/72372/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/3d1ec81ea9b1e794ed2d4874efdae1d8.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3075,
#       'height': 3846,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/3d1ec81ea9b1e794ed2d4874efdae1d8.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/73412/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'efc8ef50-2468-4597-a0cc-3466f8a54f22'},
#     {'label': 'notes', 'value': 'T43_7_recto'},
#     {'label': 'originalFileName', 'value': 'T43_7_recto.jpg'},
#     {'label': 'filename', 'value': '13.jpg'},
#     {'label': 'fileMD5', 'value': 'e3b33e3de16196e939ee2b5bbc380de1'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/73412/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[686.162881180644,
#      1478.5153393149376,
#      1429.5834515243769,
#      2234.0888412594795],
#     [2185.9137877821922,
#      1020.0510830283165,
#      369.6631371974945,
#      621.0158969163895],
#     [1627.6646867394447,
#      1775.3043374419212,
#      1354.0665239095688,
#      2008.0119650959969],
#     [1463.5392934083939,
#      1192.627365410328,
#      378.48552614450455,
#      425.91603487730026]],
#    frozenset({'cloth'}): [[1635.7279121875763,
#      2733.1982860565186,
#      1252.4936735630035,
#      1027.0303931236267],
#     [2113.073681294918,
#      1522.3119973540306,
#      754.2952850461006,
#      1354.048855483532]],
#    'ece tlle\nteak ete\nii\nd_llna\nglnlang\n': [[1725, 156, 1098, 476]],
#    'ece': [[2547, 176, 78, 28]],
#    'tlle': [[2659, 165, 94, 28]],
#    'teak': [[1839, 243, 68, 35]],
#    'ete': [[1932, 233, 138, 35]],
#    'ii': [[1725, 380, 77, 124]],
#    'd_llna': [[1768, 546, 307, 86]],
#    'glnlang': [[2200, 512, 619, 111]]},
#   'landmark_info': {},
#   'country': 'Vietnam'},
#  'T4_157_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/66900/canvas.json',
#    'label': 'T4_157_recto',
#    '@type': 'sc:Canvas',
#    'width': 2298,
#    'height': 3291,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/65860/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/c62c2cb5678d34115b03cd40ab8741d3.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2298,
#       'height': 3291,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/c62c2cb5678d34115b03cd40ab8741d3.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/66900/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'd09c6522-0bc8-4476-864d-20efb52dc644'},
#     {'label': 'notes', 'value': 'T4_157_recto'},
#     {'label': 'originalFileName', 'value': 'T4_157_recto.jpg'},
#     {'label': 'filename', 'value': '313.jpg'},
#     {'label': 'fileMD5', 'value': 'c283963881831275caf98038134f44f3'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/66900/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[1445.4535242319107,
#      1160.077668696642,
#      220.18000030517578,
#      665.594464212656],
#     [491.1860053539276,
#      1462.6182263195515,
#      492.91574960947037,
#      1398.9217090308666],
#     [1138.6058512330055,
#      1128.2077344954014,
#      245.03230994939804,
#      472.2644836306572],
#     [1934.2003415822983,
#      1111.190166503191,
#      173.5179283618927,
#      493.85981154441833],
#     [890.0137211680412,
#      1181.762346982956,
#      428.4894363284111,
#      1164.4613294005394],
#     [172.32413636147976,
#      1535.8994590938091,
#      132.99767442047596,
#      1190.1403910815716],
#     [241.2046934813261,
#      1252.507147282362,
#      231.25676353275776,
#      372.34801268577576],
#     [718.2585471868515,
#      1180.9423047602177,
#      172.91785633563995,
#      449.27544683218]],
#    frozenset({'pant'}): [[590.774060189724,
#      2186.5285695791245,
#      362.8156553506851,
#      592.0037907958031]]},
#   'landmark_info': {},
#   'country': 'India'},
#  'T4_122_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/66830/canvas.json',
#    'label': 'T4_122_recto',
#    '@type': 'sc:Canvas',
#    'width': 3642,
#    'height': 2889,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/65790/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/31f12c82144d3595c88c965898c3b802.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3642,
#       'height': 2889,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/31f12c82144d3595c88c965898c3b802.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/66830/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'bf091d73-3eb8-4574-9c29-293da11c875a'},
#     {'label': 'notes', 'value': 'T4_122_recto'},
#     {'label': 'originalFileName', 'value': 'T4_122_recto.jpg'},
#     {'label': 'filename', 'value': '243.jpg'},
#     {'label': 'fileMD5', 'value': 'c615384e20cd5a58dd73ae5b48082769'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/66830/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[1123.4996613264084,
#      228.76366140693426,
#      2085.9013463258743,
#      2204.5504562035203],
#     [3058.2817701101303,
#      511.47621063888073,
#      469.9552241563797,
#      1866.4287816435099]],
#    frozenset({'outerwear'}): [[1111.4258823394775,
#      1049.4788064658642,
#      2087.642763018608,
#      1358.617629379034]],
#    frozenset({'cloth'}): [[1117.0540099740028,
#      893.391643434763,
#      2095.5849646925926,
#      1505.6972967088223]]},
#   'landmark_info': {},
#   'country': 'India'},
#  'F25_164_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/65358/canvas.json',
#    'label': 'F25_164_recto',
#    '@type': 'sc:Canvas',
#    'width': 2733,
#    'height': 2013,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/64318/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/1a3c6f5c5d035c92d6f0a45eccac1a2a.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2733,
#       'height': 2013,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/1a3c6f5c5d035c92d6f0a45eccac1a2a.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/65358/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '852b08ad-2d46-42f7-b3dc-75b5f82de5fc'},
#     {'label': 'notes', 'value': 'F25_164_recto'},
#     {'label': 'originalFileName', 'value': 'F25_164_recto.jpg'},
#     {'label': 'filename', 'value': '327.jpg'},
#     {'label': 'fileMD5', 'value': '0b02ba4e6e5f175491a93d3290892723'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/65358/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'build'}): [[629.6271110326052,
#      248.0151118710637,
#      899.035262927413,
#      673.0177184566855],
#     [146.0880322046578,
#      204.17719291895628,
#      528.0799951963127,
#      949.5495982244611]]},
#   'landmark_info': {},
#   'country': None},
#  'F25_155_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/65340/canvas.json',
#    'label': 'F25_155_recto',
#    '@type': 'sc:Canvas',
#    'width': 2732,
#    'height': 2014,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/64300/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/7b599f01511c7804bdb0a5214d81368a.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2732,
#       'height': 2014,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/7b599f01511c7804bdb0a5214d81368a.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/65340/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '3bc0b223-73aa-4057-bc14-0de0d8eff833'},
#     {'label': 'notes', 'value': 'F25_155_recto'},
#     {'label': 'originalFileName', 'value': 'F25_155_recto.jpg'},
#     {'label': 'filename', 'value': '309.jpg'},
#     {'label': 'fileMD5', 'value': '75059fb4427da62be6823a4a14ca3992'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/65340/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'build'}): [[1009.4965839385986,
#      584.9447656869888,
#      683.5262985229492,
#      353.4685352444649],
#     [2224.464377641678,
#      800.7895586490631,
#      358.53826332092285,
#      280.3238948583603]],
#    frozenset({'frame',
#               'pictur'}): [[87.0778676122427,
#      212.3169471025467,
#      2533.9159709364176,
#      1628.5506681203842]]},
#   'landmark_info': {},
#   'country': None},
#  'T6_155_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/68658/canvas.json',
#    'label': 'T6_155_recto',
#    '@type': 'sc:Canvas',
#    'width': 3666,
#    'height': 4619,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/67618/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/78d049bb5048d9a9f9512dd5e86a4716.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3666,
#       'height': 4619,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/78d049bb5048d9a9f9512dd5e86a4716.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/68658/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '40019a30-f131-4267-921a-73e26abfb54b'},
#     {'label': 'notes', 'value': 'T6_155_recto'},
#     {'label': 'originalFileName', 'value': 'T6_155_recto.jpg'},
#     {'label': 'filename', 'value': '309.jpg'},
#     {'label': 'fileMD5', 'value': 'b5566f8fe39345f58bb3f81ebda1be1c'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/68658/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'frame',
#               'pictur'}): [[332.19059063494205,
#      388.6484886035323,
#      2988.0932566970587,
#      3951.403789617121]]},
#   'landmark_info': {},
#   'country': 'India'},
#  'T42_130_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/72720/canvas.json',
#    'label': 'T42_130_recto',
#    '@type': 'sc:Canvas',
#    'width': 3832,
#    'height': 3116,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/71680/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/188fa494bcd3aa96670b1e9cebaa637f.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3832,
#       'height': 3116,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/188fa494bcd3aa96670b1e9cebaa637f.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/72720/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '3afa9c36-557e-45eb-ae5b-c650310c205f'},
#     {'label': 'notes', 'value': 'T42_130_recto'},
#     {'label': 'originalFileName', 'value': 'T42_130_recto.jpg'},
#     {'label': 'filename', 'value': '257.jpg'},
#     {'label': 'fileMD5', 'value': '53b34c048bf157f09eccb408ed4606d7'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/72720/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'hat'}): [[1024.8686468601227,
#      1766.4439165592194,
#      599.7177519798279,
#      354.1568763256073],
#     [324.8602870106697,
#      2116.3699073791504,
#      609.7444173693657,
#      420.7285039424896]],
#    frozenset({'person'}): [[999.2436616420746,
#      1781.2512729167938,
#      646.5430607795715,
#      768.2129135131836],
#     [417.14975357055664,
#      2149.066963195801,
#      525.5283823013306,
#      389.0696680545807],
#     [409.52659398317337,
#      2111.769608736038,
#      536.9665905833244,
#      436.3346767425537],
#     [2007.2452845573425,
#      1993.6978151798248,
#      453.720591545105,
#      478.64687490463257],
#     [2797.4946036338806,
#      2069.1665604114532,
#      537.6139760017395,
#      484.91835474967957],
#     [1732.5168969631195,
#      2078.471165418625,
#      331.7122371196747,
#      415.2062511444092],
#     [3123.151253223419,
#      1985.4544603824615,
#      479.3421506881714,
#      504.15922594070435]],
#    frozenset({'cloth'}): [[400.64954805374146,
#      2203.7796676158905,
#      529.2692564725876,
#      334.83317041397095]],
#    'c gi quý hơn đốc-lập từ-do!\n': [[154, 618, 3292, 419]],
#    'c': [[168, 618, 318, 199]],
#    'gi': [[559, 645, 230, 199]],
#    'quý': [[922, 671, 354, 199]],
#    'hơn': [[1289, 696, 522, 199]],
#    'đốc-lập': [[1888, 737, 921, 200]],
#    'từ-do!': [[2816, 818, 629, 176]]},
#   'landmark_info': {},
#   'country': 'Vietnam'},
#  'Cina5_193_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/79634/canvas.json',
#    'label': 'Cina5_193_recto',
#    '@type': 'sc:Canvas',
#    'width': 2925,
#    'height': 3859,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/78594/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/1cfab0f2d54869ad090c49d99fd746fe.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2925,
#       'height': 3859,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/1cfab0f2d54869ad090c49d99fd746fe.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/79634/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '86d667b5-7b26-4677-bc64-a204b7facaf4'},
#     {'label': 'notes', 'value': 'Cina5_193_recto'},
#     {'label': 'originalFileName', 'value': 'Cina5_193_recto.jpg'},
#     {'label': 'filename', 'value': '385.jpg'},
#     {'label': 'fileMD5', 'value': 'aa82f342718231bb0d69f2f5193f9ba8'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/79634/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[968.6997748911381,
#      1820.6448010206223,
#      448.37814196944237,
#      1395.9396824240685],
#     [1454.8173755407333,
#      1870.7970092594624,
#      579.3503612279892,
#      1810.5224456489086],
#     [194.49622258543968,
#      2230.374377012253,
#      641.8957740068436,
#      1525.4290063977242],
#     [1459.9694900214672,
#      1848.297698110342,
#      568.8582770526409,
#      1889.2897008955479],
#     [221.16309832781553,
#      2163.80777156353,
#      622.5898588076234,
#      1582.7775577902794]],
#    frozenset({'cloth'}): [[208.61410852521658,
#      2420.3912803530693,
#      630.8484273031354,
#      1302.646562576294]],
#    frozenset({'hous'}): [[1517.8798913955688,
#      1162.8632925450802,
#      1038.7354239821434,
#      1074.3063976466656],
#     [398.2228484004736,
#      1027.462830454111,
#      1164.0688050538301,
#      2026.6586255729198]],
#    frozenset({'tablewar'}): [[782.2068817913532,
#      3233.50065690279,
#      624.6352359652519,
#      428.75797098875046]],
#    'v030\n': [[900, 2448, 80, 28]],
#    'v030': [[900, 2450, 79, 26]]},
#   'landmark_info': {},
#   'country': 'China'},
#  'F27_180_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/77026/canvas.json',
#    'label': 'F27_180_recto',
#    '@type': 'sc:Canvas',
#    'width': 3852,
#    'height': 3030,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/75986/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/1ad86c70f41299abd701eab312aae872.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3852,
#       'height': 3030,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/1ad86c70f41299abd701eab312aae872.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/77026/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '8b8a8817-e7f3-4163-bb6d-c43dfb063345'},
#     {'label': 'notes', 'value': 'F27_180_recto'},
#     {'label': 'originalFileName', 'value': 'F27_180_recto.jpg'},
#     {'label': 'filename', 'value': '359.jpg'},
#     {'label': 'fileMD5', 'value': 'bd9f140d34a7162b2e268317e09cbb94'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/77026/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[151.53705091774464,
#      240.23812003433704,
#      1388.977353259921,
#      2664.235492274165]],
#    frozenset({'glass'}): [[618.1120489239693,
#      389.6961562335491,
#      508.03849643468857,
#      225.07221892476082]],
#    frozenset({'outerwear'}): [[146.26653487980366,
#      711.2520079314709,
#      1359.9946235865355,
#      2037.0477671921253]],
#    frozenset({'pant'}): [[395.2563009560108,
#      1956.2507790327072,
#      1081.49876126647,
#      979.3519484996796]],
#    frozenset({'furnitur'}): [[1474.8449292182922,
#      2022.357639670372,
#      672.7748115062714,
#      884.4652444124222]],
#    '1986\n209\n1777\n1684\n1552\n421\n145\nhakue\n': [[2520, 1083, 1160, 808]],
#    '1986': [[2646, 1096, 231, 125]],
#    '209': [[2830, 1185, 176, 103]],
#    '1777': [[2637, 1294, 200, 98]],
#    '1684': [[2583, 1412, 212, 125]],
#    '1552': [[2568, 1564, 223, 121]],
#    '421': [[2562, 1704, 152, 141]],
#    '145': [[3526, 1601, 154, 98]],
#    'hakue': [[3193, 1386, 93, 37]]},
#   'landmark_info': {},
#   'country': 'Japan'},
#  'T42_203_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/72866/canvas.json',
#    'label': 'T42_203_recto',
#    '@type': 'sc:Canvas',
#    'width': 3628,
#    'height': 2794,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/71826/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/2b42ca4789a35cd39e6ddbf1b3b65757.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3628,
#       'height': 2794,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/2b42ca4789a35cd39e6ddbf1b3b65757.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/72866/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '9e153bfc-33bb-4f6a-beb6-0ef486cc267e'},
#     {'label': 'notes', 'value': 'T42_203_recto'},
#     {'label': 'originalFileName', 'value': 'T42_203_recto.jpg'},
#     {'label': 'filename', 'value': '403.jpg'},
#     {'label': 'fileMD5', 'value': '6e09049c2cbf4efa8e9e0e6aa802360a'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/72866/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'build'}): [[1087.1818233728409,
#      1286.9397666454315,
#      735.0601633787155,
#      228.2810332775116]],
#    '927\ncaution\nchú-ý\nsteady red_ stop\nđến đó ngưng lại\nflashing red_ stop\njf clear go\nđen chớp đó quan-sat hay đi\n': [[2498,
#      1473,
#      858,
#      1117]],
#    '927': [[3322, 1473, 34, 16]],
#    'caution': [[2800, 1984, 299, 83]],
#    'chú-ý': [[2828, 2072, 223, 91]],
#    'steady': [[2760, 2172, 191, 68]],
#    'red_': [[2988, 2181, 126, 68], [3019, 2340, 126, 60]],
#    'stop': [[3175, 2188, 131, 64], [3170, 2347, 127, 64]],
#    'đến': [[2731, 2233, 146, 76]],
#    'đó': [[2876, 2243, 99, 69], [2779, 2472, 65, 60]],
#    'ngưng': [[3005, 2250, 163, 73]],
#    'lại': [[3210, 2273, 81, 68]],
#    'flashing': [[2747, 2321, 239, 59]],
#    'jf': [[2821, 2394, 96, 75]],
#    'clear': [[2935, 2402, 163, 76]],
#    'go': [[3180, 2427, 77, 72]],
#    'đen': [[2506, 2435, 102, 75]],
#    'chớp': [[2629, 2447, 131, 70]],
#    'quan-sat': [[2882, 2473, 236, 75]],
#    'hay': [[3123, 2496, 108, 76]],
#    'đi': [[3236, 2509, 59, 75]]},
#   'landmark_info': {},
#   'country': 'Vietnam'},
#  'T6_163_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/68674/canvas.json',
#    'label': 'T6_163_recto',
#    '@type': 'sc:Canvas',
#    'width': 3106,
#    'height': 3986,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/67634/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/a527974e088bc05aae6e63760554baa3.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3106,
#       'height': 3986,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/a527974e088bc05aae6e63760554baa3.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/68674/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'eeabfa20-2bc8-443c-bab3-8ac111608bb4'},
#     {'label': 'notes', 'value': 'T6_163_recto'},
#     {'label': 'originalFileName', 'value': 'T6_163_recto.jpg'},
#     {'label': 'filename', 'value': '325.jpg'},
#     {'label': 'fileMD5', 'value': 'f0da82c49d2c2000e64d0153d54b96a1'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/68674/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[506.24996027350426,
#      1468.8252966403961,
#      1857.9395234882832,
#      2182.101511836052]],
#    frozenset({'outerwear'}): [[525.7538506984711,
#      1803.3617856502533,
#      1849.5309656858444,
#      1806.0847371816635]],
#    frozenset({'frame',
#               'pictur'}): [[178.65026514977217,
#      178.66788667440414,
#      2722.4409794285893,
#      3616.32256346941]],
#    frozenset({'cloth'}): [[496.72204795479774,
#      1661.1264725327492,
#      1876.6090701520443,
#      1996.609734237194]],
#    '1tot\n': [[1486, 3054, 37, 96]],
#    '1tot': [[1521, 3054, 3, 1]]},
#   'landmark_info': {},
#   'country': 'India'},
#  'Cina7_83_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/80514/canvas.json',
#    'label': 'Cina7_83_recto',
#    '@type': 'sc:Canvas',
#    'width': 3079,
#    'height': 3866,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/79474/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/b7353a5a2cd608678a54a7f4b750dfb0.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3079,
#       'height': 3866,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/b7353a5a2cd608678a54a7f4b750dfb0.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/80514/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '237fb4e3-f74f-4280-9133-e2d6fa1c3bf9'},
#     {'label': 'notes', 'value': 'Cina7_83_recto'},
#     {'label': 'originalFileName', 'value': 'Cina7_83_recto.jpg'},
#     {'label': 'filename', 'value': '165.jpg'},
#     {'label': 'fileMD5', 'value': 'f70259a57f998fb071acdc2a11ef9afb'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/80514/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'bicycl'}): [[1886.6612684130669,
#      2062.432944536209,
#      641.5531533956528,
#      1160.3275039196014],
#     [68.95793811418116,
#      2112.0155938863754,
#      646.561837753281,
#      1153.1156874895096],
#     [713.3444354087114,
#      2062.6479371786118,
#      869.6869658082724,
#      1180.6229937076569]],
#    frozenset({'bicycl',
#               'wheel'}): [[1912.8000397086143,
#      2424.1936670541763,
#      479.13134175539017,
#      665.1876964569092], [1303.3976777791977,
#      2821.880512714386,
#      289.60341066122055,
#      918.4964981079102], [698.9963553398848,
#      2553.6521894931793,
#      477.3661745339632,
#      566.9938971996307], [51.834300857037306,
#      2510.6700216531754,
#      317.5287639833987,
#      698.1011574268341]],
#    frozenset({'tire'}): [[1292.9004545509815,
#      2822.124539732933,
#      289.5598240196705,
#      930.1761519908905],
#     [1240.1442847549915,
#      2529.164919257164,
#      341.1566809117794,
#      553.3991266489029],
#     [965.316929101944,
#      2847.019904255867,
#      191.4395953118801,
#      884.6783628463745]],
#    '囍\n囍\n0402192\n11657228\n': [[326, 1250, 1497, 1436]],
#    '囍': [[855, 1250, 193, 189], [1656, 1292, 167, 173]],
#    '0402192': [[326, 2645, 143, 41]],
#    '11657228': [[951, 2636, 135, 41]]},
#   'landmark_info': {},
#   'country': 'China'},
#  'T10_79_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/77622/canvas.json',
#    'label': 'T10_79_recto',
#    '@type': 'sc:Canvas',
#    'width': 4673,
#    'height': 3651,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/76582/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/eb072885ca6f85408c1d2cac422f7b41.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 4673,
#       'height': 3651,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/eb072885ca6f85408c1d2cac422f7b41.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/77622/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '8fecd4fb-4aca-4236-9200-b380c5c8b113'},
#     {'label': 'notes', 'value': 'T10_79_recto'},
#     {'label': 'originalFileName', 'value': 'T10_79_recto.jpg'},
#     {'label': 'filename', 'value': '157.jpg'},
#     {'label': 'fileMD5', 'value': 'b9a23bcde111100539ccf9009b7ed897'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/77622/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[2672.512143969536,
#      1381.94653236866,
#      380.955870449543,
#      700.3299077153206],
#     [2940.193858206272,
#      1330.7422267198563,
#      767.5517455935478,
#      805.4918037056923],
#     [1761.151419967413,
#      1428.274159759283,
#      440.2863578796387,
#      659.7449636757374],
#     [3760.611351788044,
#      1332.1688120663166,
#      355.83279556035995,
#      537.5643647611141],
#     [3954.340457677841,
#      1403.8222192525864,
#      309.2660601735115,
#      622.3861851096153],
#     [745.0236884206533,
#      1433.7509156763554,
#      544.2131721228361,
#      589.3050952255726],
#     [1201.0994273126125,
#      1400.943913847208,
#      460.89177480340004,
#      465.8364239037037],
#     [660.5057850927114,
#      1476.4356418848038,
#      543.8090214580297,
#      577.4575057625771],
#     [1028.213605105877,
#      1396.1051008701324,
#      480.2541011571884,
#      526.0138218998909]],
#    frozenset({'cloth'}): [[2161.053907006979,
#      1500.2887016236782,
#      493.3071092069149,
#      643.2420119941235]]},
#   'landmark_info': {},
#   'country': None},
#  'T62_20_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/75980/canvas.json',
#    'label': 'T62_20_recto',
#    '@type': 'sc:Canvas',
#    'width': 3092,
#    'height': 3841,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/74940/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/cfc0b09ff0012272294f87838267fcde.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3092,
#       'height': 3841,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/cfc0b09ff0012272294f87838267fcde.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/75980/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '011f8244-59f6-4b83-8b17-a3dcc46ac501'},
#     {'label': 'notes', 'value': 'T62_20_recto'},
#     {'label': 'originalFileName', 'value': 'T62_20_recto.jpg'},
#     {'label': 'filename', 'value': '39.jpg'},
#     {'label': 'fileMD5', 'value': '2c7962e9d95cfcd48548f8e00b51614c'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/75980/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'build'}): [[356.35794949531555,
#      385.74420591443777,
#      2419.2473685741425,
#      2886.7639768496156]],
#    frozenset({'window'}): [[2488.8110361099243,
#      2421.426848232746,
#      249.00351405143738,
#      532.9179804325104],
#     [1804.955950975418,
#      1480.6370996236801,
#      350.3526134490967,
#      464.0800970196724],
#     [1289.866474032402,
#      1469.7001091241837,
#      346.7775171995163,
#      477.722259581089],
#     [776.8954975605011,
#      1460.8515224456787,
#      359.96585071086884,
#      455.6067453622818],
#     [679.5532575249672,
#      2337.9135895371437,
#      397.24182945489883,
#      749.5492397546768],
#     [2418.6563262939453,
#      1590.4822870492935,
#      310.265682220459,
#      447.15972197055817]],
#    frozenset({'door'}): [[1277.3836315870285,
#      2623.2302572727203,
#      342.58659064769745,
#      486.8274896144867]],
#    '6v0\n': [[2096, 2145, 124, 50]],
#    '6v0': [[2096, 2145, 124, 50]]},
#   'landmark_info': {},
#   'country': 'Cambodia'},
#  'T21_71_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/68878/canvas.json',
#    'label': 'T21_71_recto',
#    '@type': 'sc:Canvas',
#    'width': 2743,
#    'height': 2011,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/67838/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/a96f5da3578b9270600c8ad88e2e2325.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 2743,
#       'height': 2011,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/a96f5da3578b9270600c8ad88e2e2325.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/68878/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '234bcff1-1995-460d-a79b-1b6a61d7134a'},
#     {'label': 'notes', 'value': 'T21_71_recto'},
#     {'label': 'originalFileName', 'value': 'T21_71_recto.jpg'},
#     {'label': 'filename', 'value': '141.jpg'},
#     {'label': 'fileMD5', 'value': '0bddb963933e9c5bbeade64cf2b25cbd'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/68878/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'ducado'}): [[1610, 1436, 181, 104]],
#    frozenset({'hat'}): [[371.0089447647333,
#      792.0810125768185,
#      346.78062234818935,
#      171.28532207012177],
#     [790.06914716959,
#      435.6227864474058,
#      379.79940512776375,
#      195.6977650374174],
#     [158.1109273917973,
#      564.6496937274933,
#      335.99303330108523,
#      263.90334352850914],
#     [1949.34866553545,
#      506.2150557041168,
#      472.97183507680893,
#      229.44624850153923],
#     [1284.6446290016174,
#      489.1200677007437,
#      525.234983086586,
#      274.6061739772558]],
#    frozenset({'person'}): [[387.7237069904804,
#      785.6108828783035,
#      342.16927149891853,
#      579.2011776566505],
#     [674.4289147853851,
#      427.870761141181,
#      697.4683793783188,
#      1384.3020699173212],
#     [1839.655746936798,
#      513.6991229355335,
#      725.6134827136993,
#      1355.2860940396786],
#     [1605.0826454758644,
#      921.3621833622456,
#      260.4995703101158,
#      299.5069467127323]],
#    frozenset({'tie'}): [[2024.5948721766472,
#      1027.6613494157791,
#      366.7074179649353,
#      799.7622576355934]],
#    'coronel\nbilladas\ngotangogan\n': [[237, 1309, 2324, 356]],
#    'coronel': [[2492, 1309, 68, 22]],
#    'billadas': [[1647, 1452, 122, 20]],
#    'gotangogan': [[239, 1628, 166, 23]]},
#   'landmark_info': {},
#   'country': 'Philippines'},
#  'T36_12_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/72018/canvas.json',
#    'label': 'T36_12_recto',
#    '@type': 'sc:Canvas',
#    'width': 3792,
#    'height': 2597,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/70978/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/9cfa7ccd4ff4730a47922dc7e163e729.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3792,
#       'height': 2597,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/9cfa7ccd4ff4730a47922dc7e163e729.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/72018/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': 'b40c91e7-c3a8-466c-b123-4245b37aa4ba'},
#     {'label': 'notes', 'value': 'T36_12_recto'},
#     {'label': 'originalFileName', 'value': 'T36_12_recto.jpg'},
#     {'label': 'filename', 'value': '23.jpg'},
#     {'label': 'fileMD5', 'value': '5b37f88819bcd8d26493cc9816e4c7cc'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/72018/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[2332.5377283096313,
#      1769.5210375785828,
#      277.1652545928955,
#      592.8328092098236],
#     [1703.0852465629578,
#      1790.3450655937195,
#      327.76961946487427,
#      461.23516231775284]],
#    frozenset({'cloth'}): [[2335.9820594787598,
#      1791.1122210025787,
#      266.77485179901123,
#      568.7901648879051]]},
#   'landmark_info': {},
#   'country': None},
#  'T55_55_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/75018/canvas.json',
#    'label': 'T55_55_recto',
#    '@type': 'sc:Canvas',
#    'width': 3134,
#    'height': 3856,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/73978/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/8fe20406043209b5b85920d0b9b6ec58.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3134,
#       'height': 3856,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/8fe20406043209b5b85920d0b9b6ec58.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/75018/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '4175b16d-6deb-4543-a0a1-16f4c4c8ff74'},
#     {'label': 'notes', 'value': 'T55_55_recto'},
#     {'label': 'originalFileName', 'value': 'T55_55_recto.jpg'},
#     {'label': 'filename', 'value': '111.jpg'},
#     {'label': 'fileMD5', 'value': '9148baf531669311e2d2496294afe598'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/75018/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'sculptur'}): [[665.3721652925014,
#      1002.8934545516968,
#      1565.343402415514,
#      2118.4476795196533]]},
#   'landmark_info': {},
#   'country': 'Japan'},
#  'F26_105_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/65852/canvas.json',
#    'label': 'F26_105_recto',
#    '@type': 'sc:Canvas',
#    'width': 3845,
#    'height': 3118,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/64812/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/985e6354bcc12916edf0c1bf1c4bfb89.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3845,
#       'height': 3118,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/985e6354bcc12916edf0c1bf1c4bfb89.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/65852/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '07a747a6-40bc-4340-b5a9-21bd3389e2f2'},
#     {'label': 'notes', 'value': 'F26_105_recto'},
#     {'label': 'originalFileName', 'value': 'F26_105_recto.jpg'},
#     {'label': 'filename', 'value': '209.jpg'},
#     {'label': 'fileMD5', 'value': 'ca1e622e0466b221946c8e5e6c9a74bd'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/65852/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'wheel'}): [[2673.502230644226,
#      2124.92820584774,
#      789.8399662971497,
#      531.4700753688812]],
#    frozenset({'furnitur'}): [[2149.575300514698,
#      1693.925127029419,
#      377.4754998087883,
#      406.48071575164795]]},
#   'landmark_info': {},
#   'country': None},
#  'T35_49_recto': {'iiif': {'@id': 'http://dl.cini.it/oa/items/71148/canvas.json',
#    'label': 'T35_49_recto',
#    '@type': 'sc:Canvas',
#    'width': 3116,
#    'height': 3843,
#    'images': [{'@id': 'http://dl.cini.it/oa/files/70108/anno.json',
#      'motivation': 'sc:painting',
#      '@type': 'oa:Annotation',
#      'resource': {'@id': 'http://dl.cini.it/files/original/db45f739314a7654ea5a9f0219f77186.jpg',
#       '@type': 'dctypes:Image',
#       'format': 'image/jpeg',
#       'width': 3116,
#       'height': 3843,
#       'service': {'@id': 'http://dl.cini.it:8080/digilib/Scaler/IIIF/db45f739314a7654ea5a9f0219f77186.jpg',
#        '@context': 'http://iiif.io/api/image/2/context.json',
#        'profile': 'http://iiif.io/api/image/2/level2.json'}},
#      'on': 'http://dl.cini.it/oa/items/71148/canvas.json'}],
#    'metadata': [{'label': 'Identifier',
#      'value': '28d30979-1ba6-419d-a17d-1f856c6f97f6'},
#     {'label': 'notes', 'value': 'T35_49_recto'},
#     {'label': 'originalFileName', 'value': 'T35_49_recto.jpg'},
#     {'label': 'filename', 'value': '97.jpg'},
#     {'label': 'fileMD5', 'value': '21b546a1bd29331a19ace4a9724b7d54'}],
#    'otherContent': [{'@id': 'http://dl.cini.it/oa/items/71148/annolist.json',
#      '@type': 'sc:AnnotationList'}]},
#   'obj_boxes': {frozenset({'person'}): [[672.9025132060051,
#      1190.427624732256,
#      642.1686031222343,
#      1633.3404426276684],
#     [1251.3158692121506,
#      1185.4031793773174,
#      562.4424597024918,
#      1388.8727153241634],
#     [2416.0557115077972,
#      1107.907723903656,
#      479.6074604988098,
#      1148.909351170063],
#     [2787.1981630325317,
#      1033.4237287938595,
#      215.99859166145325,
#      1236.8410389125347]],
#    frozenset({'hat'}): [[1717.925800561905,
#      192.68009215593338,
#      975.3498616218567,
#      1420.5079380869865],
#     [1319.0360392332077,
#      1158.5907140672207,
#      383.7174493074417,
#      301.2903445959091]],
#    frozenset({'cloth'}): [[1159.1913089752197,
#      1675.2039105892181,
#      1763.7408301830292,
#      2012.9162728786469]],
#    'にしひら\n%3d\nfrance\n': [[1808, 2934, 420, 236]],
#    'にしひら': [[1808, 2943, 115, 33]],
#    '%3d': [[2088, 2976, 106, 86]],
#    'france': [[2046, 3111, 170, 59]]},
#   'landmark_info': {},
#   'country': 'Japan'}}

# %%
with open('tagged_images.json', 'w') as fp:
    json.dump(tagged_images, fp, indent=4)
    
with open('annotated_images.json', 'w') as fp:
    json.dump(annotated_images, fp, indent=4)

if len(failed_images) > 0:
    print("There are failed images")
    with open('failed_images.json', 'w') as fp:
        json.dump(failed_images, fp, indent=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f53765f80936> in <module>
#       3
#       4 with open('annotated_images.json', 'w') as fp:
# ----> 5     json.dump(annotated_images, fp, indent=4)
#       6
#       7 if len(failed_images) > 0:
#
# ~\anaconda3\envs\fdh\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~\anaconda3\envs\fdh\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# ~\anaconda3\envs\fdh\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~\anaconda3\envs\fdh\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~\anaconda3\envs\fdh\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     374                 continue
#     375             else:
# --> 376                 raise TypeError(f'keys must be str, int, float, bool or None, '
#     377                                 f'not {key.__class__.__name__}')
#     378             if first:
#
# TypeError: keys must be str, int, float, bool or None, not frozenset

# %% [markdown]
# ## Inserting the data into Mangodb
#
# # TODO: The insert the data into database.

# %%
# creating a client to work with mango db
mangoclient = pymongo.MongoClient(MANGO_CLIENT_URI)
# selecting the <terzani_photos> database
mango_db = mangoclient["terzani_photos"]

# %% [markdown]
# ### Storing the Image Tags

# %%
# creating a new collection named <sample_tagging>
mango_tag_collection = mango_db["sample_taggings"]
# inserting the dictionary into the db
for label, annotations in tagged_images.items():
    mango_tag_collection.insert_one(annotations)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-2e590d0712bb> in <module>
#       3 # inserting the dictionary into the db
#       4 for label, annotations in tagged_images.items():
# ----> 5     mango_tag_collection.insert_one(annotations)
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     690         .. versionadded:: 3.0
#     691         """
# --> 692         common.validate_is_document_type("document", document)
#     693         if not (isinstance(document, RawBSONDocument) or "_id" in document):
#     694             document["_id"] = ObjectId()
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\common.py in validate_is_document_type(option, value)
#     500     """Validate the type of method arguments that expect a MongoDB document."""
#     501     if not isinstance(value, (abc.MutableMapping, RawBSONDocument)):
# --> 502         raise TypeError("%s must be an instance of dict, bson.son.SON, "
#     503                         "bson.raw_bson.RawBSONDocument, or "
#     504                         "a type that inherits from "
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %% [markdown]
# ### Storing the Image information

# %%
# creating a new collection named <sample_annotations>
mango_box_collection = mango_db["sample_annotations"]
# inserting the dictionary into the db
for label, annotations in annotated_images.items():
    mango_box_collection.insert_one(annotations)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-36-63db5741dd37> in <module>
#       3 # inserting the dictionary into the db
#       4 for label, annotations in annotated_images.items():
# ----> 5     mango_box_collection.insert_one(annotations)
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     696         write_concern = self._write_concern_for(session)
#     697         return InsertOneResult(
# --> 698             self._insert(document,
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     611         """Internal insert helper."""
#     612         if isinstance(docs, abc.Mapping):
# --> 613             return self._insert_one(
#     614                 docs, ordered, check_keys, manipulate, write_concern, op_id,
#     615                 bypass_doc_val, session)
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600             _check_write_command_response(result)
#     601
# --> 602         self.__database.client._retryable_write(
#     603             acknowledged, _insert_command, session)
#     604
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1496         """Internal retryable write helper."""
#    1497         with self._tmp_session(session) as s:
# -> 1498             return self._retry_with_session(retryable, func, s, None)
#    1499
#    1500     def _handle_getlasterror(self, address, error_msg):
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382         retryable = (retryable and self.retry_writes
#    1383                      and session and not session.in_transaction)
# -> 1384         return self._retry_internal(retryable, func, session, bulk)
#    1385
#    1386     def _retry_internal(self, retryable, func, session, bulk):
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1414                             raise last_error
#    1415                         retryable = False
# -> 1416                     return func(session, sock_info, retryable)
#    1417             except ServerSelectionTimeoutError:
#    1418                 if is_retrying():
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     588                 command['bypassDocumentValidation'] = True
#     589
# --> 590             result = sock_info.command(
#     591                 self.__database.name,
#     592                 command,
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     697         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     698         except BaseException as error:
# --> 699             self._raise_connection_failure(error)
#     700
#     701     def send_message(self, message, max_doc_size):
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     681             self._raise_if_not_writable(unacknowledged)
#     682         try:
# --> 683             return command(self, dbname, spec, slave_ok,
#     684                            self.is_mongos, read_preference, codec_options,
#     685                            session, client, check, allowable_errors,
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     118         flags = _OpMsg.MORE_TO_COME if unacknowledged else 0
#     119         flags |= _OpMsg.EXHAUST_ALLOWED if exhaust_allowed else 0
# --> 120         request_id, msg, size, max_doc_size = message._op_msg(
#     121             flags, spec, dbname, read_preference, slave_ok, check_keys,
#     122             codec_options, ctx=compression_ctx)
#
# ~\anaconda3\envs\fdh\lib\site-packages\pymongo\message.py in _op_msg(flags, command, dbname, read_preference, slave_ok, check_keys, opts, ctx)
#     712             return _op_msg_compressed(
#     713                 flags, command, identifier, docs, check_keys, opts, ctx)
# --> 714         return _op_msg_uncompressed(
#     715             flags, command, identifier, docs, check_keys, opts)
#     716     finally:
#
# InvalidDocument: documents must have only string keys, key was frozenset({'person'})
