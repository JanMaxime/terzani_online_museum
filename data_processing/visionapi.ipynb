# %% [markdown]
# # Demo Notebook for using Google Vision API
#
# In this notebook we explore the google vision API and try its various methods

# %% [markdown]
# ## Installing the client library
#
# If the Google cloud vision library is not installed already, install it.
#
# If you have python environment use
#
# ```shell
# pip install --upgrade google-cloud-vision
# ```
#
# If you have conda environment use
#
# ```shell
# conda install -c conda-forge google-cloud-vision
# ```

# %% [markdown]
# ## Import the standard libraries

# %%
import os, io

# %% [markdown]
# ## Import Vison API related libraries

# %%
from google.cloud import vision
from google.cloud.vision import types

# %% [markdown]
# # Setup the service account credentials to use the API

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'F:\EPFL\1st Year\Sem 1\DH_405_Foundation_of_Digital_Humanities\Project\My Project-1c871315ad69.json'

# %% [markdown]
# # Creation of Client to access the API

# %%
client = vision.ImageAnnotatorClient()

# %% [markdown]
# In the next cell, we print to see the methods available with the Image Annotator client.
# Those of our interest are 'annotate_image', 'document_text_detection','face_detection', 'image_properties','label_detection', 'landmark_detection', 'logo_detection', 'object_localization', 'product_search', 'safe_search_detection', 'text_detection', 'transport', 'web_detection'

# %%
dir(client)
# Out:
# ['SERVICE_ADDRESS',
#  '_INTERFACE_NAME',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_client_info',
#  '_get_all_features',
#  '_inner_api_calls',
#  '_method_configs',
#  'annotate_image',
#  'async_batch_annotate_files',
#  'async_batch_annotate_images',
#  'batch_annotate_files',
#  'batch_annotate_images',
#  'crop_hints',
#  'document_text_detection',
#  'enums',
#  'face_detection',
#  'from_service_account_file',
#  'from_service_account_json',
#  'image_properties',
#  'label_detection',
#  'landmark_detection',
#  'logo_detection',
#  'object_localization',
#  'product_search',
#  'safe_search_detection',
#  'text_detection',
#  'transport',
#  'web_detection']

# %% [markdown]
# # Vision API Methods

# %% [markdown]
# Let's get an image from one the Terzani pictures.
# image url = http://dl.cini.it/files/original/cb46e00d902f9936224ca6ef81834a35.jpg

# %% [markdown]
# ### Displaying the image

# %%
from IPython.display import Image
from IPython.core.display import HTML
img_url = "http://dl.cini.it/files/original/cb46e00d902f9936224ca6ef81834a35.jpg"
Image(url= img_url)
# Out:
# <img src="http://dl.cini.it/files/original/cb46e00d902f9936224ca6ef81834a35.jpg"/>

# %% [markdown]
# ## Test with an image from URL

# %%
img_url = "http://dl.cini.it:8080/digilib/Scaler/IIIF/cb46e00d902f9936224ca6ef81834a35/full/max/0/default.jpg"
image = vision.types.Image()
image.source.image_uri = img_url

# %% [markdown]
# ### Text Detection

# %%
response = client.text_detection(image=image)
response
# Out:
# text_annotations {
#   locale: "en"
#   description: "CRUSH ALL DESTRUCTIVE ELEMENTS.\nshdevyy Fhogfnfenrs GhH91-114\n"
#   bounding_poly {
#     vertices {
#       x: 378
#       y: 617
#     }
#     vertices {
#       x: 1640
#       y: 617
#     }
#     vertices {
#       x: 1640
#       y: 693
#     }
#     vertices {
#       x: 378
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: "CRUSH"
#   bounding_poly {
#     vertices {
#       x: 1168
#       y: 620
#     }
#     vertices {
#       x: 1244
#       y: 620
#     }
#     vertices {
#       x: 1244
#       y: 639
#     }
#     vertices {
#       x: 1168
#       y: 639
#     }
#   }
# }
# text_annotations {
#   description: "ALL"
#   bounding_poly {
#     vertices {
#       x: 1264
#       y: 620
#     }
#     vertices {
#       x: 1306
#       y: 620
#     }
#     vertices {
#       x: 1306
#       y: 638
#     }
#     vertices {
#       x: 1264
#       y: 638
#     }
#   }
# }
# text_annotations {
#   description: "DESTRUCTIVE"
#   bounding_poly {
#     vertices {
#       x: 1327
#       y: 618
#     }
#     vertices {
#       x: 1487
#       y: 618
#     }
#     vertices {
#       x: 1487
#       y: 639
#     }
#     vertices {
#       x: 1327
#       y: 639
#     }
#   }
# }
# text_annotations {
#   description: "ELEMENTS."
#   bounding_poly {
#     vertices {
#       x: 1505
#       y: 617
#     }
#     vertices {
#       x: 1640
#       y: 617
#     }
#     vertices {
#       x: 1640
#       y: 638
#     }
#     vertices {
#       x: 1505
#       y: 638
#     }
#   }
# }
# text_annotations {
#   description: "shdevyy"
#   bounding_poly {
#     vertices {
#       x: 378
#       y: 671
#     }
#     vertices {
#       x: 427
#       y: 672
#     }
#     vertices {
#       x: 427
#       y: 687
#     }
#     vertices {
#       x: 378
#       y: 686
#     }
#   }
# }
# text_annotations {
#   description: "Fhogfnfenrs"
#   bounding_poly {
#     vertices {
#       x: 432
#       y: 671
#     }
#     vertices {
#       x: 496
#       y: 672
#     }
#     vertices {
#       x: 496
#       y: 689
#     }
#     vertices {
#       x: 432
#       y: 688
#     }
#   }
# }
# text_annotations {
#   description: "GhH91-114"
#   bounding_poly {
#     vertices {
#       x: 501
#       y: 672
#     }
#     vertices {
#       x: 586
#       y: 673
#     }
#     vertices {
#       x: 586
#       y: 693
#     }
#     vertices {
#       x: 501
#       y: 692
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "en"
#         confidence: 1.0
#       }
#     }
#     width: 1943
#     height: 1458
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 1168
#           y: 617
#         }
#         vertices {
#           x: 1640
#           y: 617
#         }
#         vertices {
#           x: 1640
#           y: 639
#         }
#         vertices {
#           x: 1168
#           y: 639
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 1168
#             y: 617
#           }
#           vertices {
#             x: 1640
#             y: 617
#           }
#           vertices {
#             x: 1640
#             y: 639
#           }
#           vertices {
#             x: 1168
#             y: 639
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1168
#               y: 620
#             }
#             vertices {
#               x: 1244
#               y: 620
#             }
#             vertices {
#               x: 1244
#               y: 639
#             }
#             vertices {
#               x: 1168
#               y: 639
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1168
#                 y: 620
#               }
#               vertices {
#                 x: 1193
#                 y: 620
#               }
#               vertices {
#                 x: 1193
#                 y: 639
#               }
#               vertices {
#                 x: 1168
#                 y: 639
#               }
#             }
#             text: "C"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1194
#                 y: 620
#               }
#               vertices {
#                 x: 1204
#                 y: 620
#               }
#               vertices {
#                 x: 1204
#                 y: 639
#               }
#               vertices {
#                 x: 1194
#                 y: 639
#               }
#             }
#             text: "R"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1205
#                 y: 620
#               }
#               vertices {
#                 x: 1225
#                 y: 620
#               }
#               vertices {
#                 x: 1225
#                 y: 639
#               }
#               vertices {
#                 x: 1205
#                 y: 639
#               }
#             }
#             text: "U"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1226
#                 y: 620
#               }
#               vertices {
#                 x: 1236
#                 y: 620
#               }
#               vertices {
#                 x: 1236
#                 y: 639
#               }
#               vertices {
#                 x: 1226
#                 y: 639
#               }
#             }
#             text: "S"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1237
#                 y: 620
#               }
#               vertices {
#                 x: 1244
#                 y: 620
#               }
#               vertices {
#                 x: 1244
#                 y: 639
#               }
#               vertices {
#                 x: 1237
#                 y: 639
#               }
#             }
#             text: "H"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1264
#               y: 620
#             }
#             vertices {
#               x: 1306
#               y: 620
#             }
#             vertices {
#               x: 1306
#               y: 638
#             }
#             vertices {
#               x: 1264
#               y: 638
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1264
#                 y: 620
#               }
#               vertices {
#                 x: 1275
#                 y: 620
#               }
#               vertices {
#                 x: 1275
#                 y: 638
#               }
#               vertices {
#                 x: 1264
#                 y: 638
#               }
#             }
#             text: "A"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1279
#                 y: 620
#               }
#               vertices {
#                 x: 1291
#                 y: 620
#               }
#               vertices {
#                 x: 1291
#                 y: 638
#               }
#               vertices {
#                 x: 1279
#                 y: 638
#               }
#             }
#             text: "L"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1294
#                 y: 620
#               }
#               vertices {
#                 x: 1306
#                 y: 620
#               }
#               vertices {
#                 x: 1306
#                 y: 638
#               }
#               vertices {
#                 x: 1294
#                 y: 638
#               }
#             }
#             text: "L"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1327
#               y: 618
#             }
#             vertices {
#               x: 1487
#               y: 618
#             }
#             vertices {
#               x: 1487
#               y: 639
#             }
#             vertices {
#               x: 1327
#               y: 639
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1327
#                 y: 618
#               }
#               vertices {
#                 x: 1348
#                 y: 618
#               }
#               vertices {
#                 x: 1348
#                 y: 639
#               }
#               vertices {
#                 x: 1327
#                 y: 639
#               }
#             }
#             text: "D"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1349
#                 y: 618
#               }
#               vertices {
#                 x: 1353
#                 y: 618
#               }
#               vertices {
#                 x: 1353
#                 y: 639
#               }
#               vertices {
#                 x: 1349
#                 y: 639
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1354
#                 y: 618
#               }
#               vertices {
#                 x: 1375
#                 y: 618
#               }
#               vertices {
#                 x: 1375
#                 y: 639
#               }
#               vertices {
#                 x: 1354
#                 y: 639
#               }
#             }
#             text: "S"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1376
#                 y: 618
#               }
#               vertices {
#                 x: 1391
#                 y: 618
#               }
#               vertices {
#                 x: 1391
#                 y: 639
#               }
#               vertices {
#                 x: 1376
#                 y: 639
#               }
#             }
#             text: "T"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1392
#                 y: 618
#               }
#               vertices {
#                 x: 1407
#                 y: 618
#               }
#               vertices {
#                 x: 1407
#                 y: 639
#               }
#               vertices {
#                 x: 1392
#                 y: 639
#               }
#             }
#             text: "R"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1408
#                 y: 618
#               }
#               vertices {
#                 x: 1423
#                 y: 618
#               }
#               vertices {
#                 x: 1423
#                 y: 639
#               }
#               vertices {
#                 x: 1408
#                 y: 639
#               }
#             }
#             text: "U"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1424
#                 y: 618
#               }
#               vertices {
#                 x: 1439
#                 y: 618
#               }
#               vertices {
#                 x: 1439
#                 y: 639
#               }
#               vertices {
#                 x: 1424
#                 y: 639
#               }
#             }
#             text: "C"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1440
#                 y: 618
#               }
#               vertices {
#                 x: 1449
#                 y: 618
#               }
#               vertices {
#                 x: 1449
#                 y: 639
#               }
#               vertices {
#                 x: 1440
#                 y: 639
#               }
#             }
#             text: "T"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1450
#                 y: 618
#               }
#               vertices {
#                 x: 1465
#                 y: 618
#               }
#               vertices {
#                 x: 1465
#                 y: 639
#               }
#               vertices {
#                 x: 1450
#                 y: 639
#               }
#             }
#             text: "I"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1466
#                 y: 618
#               }
#               vertices {
#                 x: 1476
#                 y: 618
#               }
#               vertices {
#                 x: 1476
#                 y: 639
#               }
#               vertices {
#                 x: 1466
#                 y: 639
#               }
#             }
#             text: "V"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1477
#                 y: 618
#               }
#               vertices {
#                 x: 1487
#                 y: 618
#               }
#               vertices {
#                 x: 1487
#                 y: 639
#               }
#               vertices {
#                 x: 1477
#                 y: 639
#               }
#             }
#             text: "E"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1505
#               y: 617
#             }
#             vertices {
#               x: 1640
#               y: 617
#             }
#             vertices {
#               x: 1640
#               y: 638
#             }
#             vertices {
#               x: 1505
#               y: 638
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1505
#                 y: 617
#               }
#               vertices {
#                 x: 1524
#                 y: 617
#               }
#               vertices {
#                 x: 1524
#                 y: 638
#               }
#               vertices {
#                 x: 1505
#                 y: 638
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1525
#                 y: 617
#               }
#               vertices {
#                 x: 1540
#                 y: 617
#               }
#               vertices {
#                 x: 1540
#                 y: 638
#               }
#               vertices {
#                 x: 1525
#                 y: 638
#               }
#             }
#             text: "L"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1541
#                 y: 617
#               }
#               vertices {
#                 x: 1551
#                 y: 617
#               }
#               vertices {
#                 x: 1551
#                 y: 638
#               }
#               vertices {
#                 x: 1541
#                 y: 638
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1552
#                 y: 617
#               }
#               vertices {
#                 x: 1577
#                 y: 617
#               }
#               vertices {
#                 x: 1577
#                 y: 638
#               }
#               vertices {
#                 x: 1552
#                 y: 638
#               }
#             }
#             text: "M"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1578
#                 y: 617
#               }
#               vertices {
#                 x: 1588
#                 y: 617
#               }
#               vertices {
#                 x: 1588
#                 y: 638
#               }
#               vertices {
#                 x: 1578
#                 y: 638
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1589
#                 y: 617
#               }
#               vertices {
#                 x: 1609
#                 y: 617
#               }
#               vertices {
#                 x: 1609
#                 y: 638
#               }
#               vertices {
#                 x: 1589
#                 y: 638
#               }
#             }
#             text: "N"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1610
#                 y: 617
#               }
#               vertices {
#                 x: 1620
#                 y: 617
#               }
#               vertices {
#                 x: 1620
#                 y: 638
#               }
#               vertices {
#                 x: 1610
#                 y: 638
#               }
#             }
#             text: "T"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1621
#                 y: 617
#               }
#               vertices {
#                 x: 1631
#                 y: 617
#               }
#               vertices {
#                 x: 1631
#                 y: 638
#               }
#               vertices {
#                 x: 1621
#                 y: 638
#               }
#             }
#             text: "S"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1632
#                 y: 617
#               }
#               vertices {
#                 x: 1640
#                 y: 617
#               }
#               vertices {
#                 x: 1640
#                 y: 638
#               }
#               vertices {
#                 x: 1632
#                 y: 638
#               }
#             }
#             text: "."
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 378
#           y: 670
#         }
#         vertices {
#           x: 586
#           y: 672
#         }
#         vertices {
#           x: 586
#           y: 693
#         }
#         vertices {
#           x: 378
#           y: 691
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 378
#             y: 670
#           }
#           vertices {
#             x: 586
#             y: 672
#           }
#           vertices {
#             x: 586
#             y: 693
#           }
#           vertices {
#             x: 378
#             y: 691
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 378
#               y: 671
#             }
#             vertices {
#               x: 427
#               y: 672
#             }
#             vertices {
#               x: 427
#               y: 687
#             }
#             vertices {
#               x: 378
#               y: 686
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 378
#                 y: 671
#               }
#               vertices {
#                 x: 397
#                 y: 671
#               }
#               vertices {
#                 x: 397
#                 y: 686
#               }
#               vertices {
#                 x: 378
#                 y: 686
#               }
#             }
#             text: "s"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 398
#                 y: 671
#               }
#               vertices {
#                 x: 401
#                 y: 671
#               }
#               vertices {
#                 x: 401
#                 y: 686
#               }
#               vertices {
#                 x: 398
#                 y: 686
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 402
#                 y: 671
#               }
#               vertices {
#                 x: 405
#                 y: 671
#               }
#               vertices {
#                 x: 405
#                 y: 686
#               }
#               vertices {
#                 x: 402
#                 y: 686
#               }
#             }
#             text: "d"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 406
#                 y: 671
#               }
#               vertices {
#                 x: 409
#                 y: 671
#               }
#               vertices {
#                 x: 409
#                 y: 686
#               }
#               vertices {
#                 x: 406
#                 y: 686
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 410
#                 y: 671
#               }
#               vertices {
#                 x: 413
#                 y: 671
#               }
#               vertices {
#                 x: 413
#                 y: 686
#               }
#               vertices {
#                 x: 410
#                 y: 686
#               }
#             }
#             text: "v"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 414
#                 y: 671
#               }
#               vertices {
#                 x: 424
#                 y: 671
#               }
#               vertices {
#                 x: 424
#                 y: 686
#               }
#               vertices {
#                 x: 414
#                 y: 686
#               }
#             }
#             text: "y"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 425
#                 y: 672
#               }
#               vertices {
#                 x: 427
#                 y: 672
#               }
#               vertices {
#                 x: 427
#                 y: 687
#               }
#               vertices {
#                 x: 425
#                 y: 687
#               }
#             }
#             text: "y"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 432
#               y: 671
#             }
#             vertices {
#               x: 496
#               y: 672
#             }
#             vertices {
#               x: 496
#               y: 689
#             }
#             vertices {
#               x: 432
#               y: 688
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 432
#                 y: 672
#               }
#               vertices {
#                 x: 443
#                 y: 672
#               }
#               vertices {
#                 x: 443
#                 y: 688
#               }
#               vertices {
#                 x: 432
#                 y: 688
#               }
#             }
#             text: "F"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 444
#                 y: 672
#               }
#               vertices {
#                 x: 447
#                 y: 672
#               }
#               vertices {
#                 x: 447
#                 y: 688
#               }
#               vertices {
#                 x: 444
#                 y: 688
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 448
#                 y: 672
#               }
#               vertices {
#                 x: 451
#                 y: 672
#               }
#               vertices {
#                 x: 451
#                 y: 688
#               }
#               vertices {
#                 x: 448
#                 y: 688
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 452
#                 y: 672
#               }
#               vertices {
#                 x: 455
#                 y: 672
#               }
#               vertices {
#                 x: 455
#                 y: 688
#               }
#               vertices {
#                 x: 452
#                 y: 688
#               }
#             }
#             text: "g"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 456
#                 y: 672
#               }
#               vertices {
#                 x: 463
#                 y: 672
#               }
#               vertices {
#                 x: 463
#                 y: 688
#               }
#               vertices {
#                 x: 456
#                 y: 688
#               }
#             }
#             text: "f"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 464
#                 y: 672
#               }
#               vertices {
#                 x: 474
#                 y: 672
#               }
#               vertices {
#                 x: 474
#                 y: 688
#               }
#               vertices {
#                 x: 464
#                 y: 688
#               }
#             }
#             text: "n"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 475
#                 y: 672
#               }
#               vertices {
#                 x: 482
#                 y: 672
#               }
#               vertices {
#                 x: 482
#                 y: 688
#               }
#               vertices {
#                 x: 475
#                 y: 688
#               }
#             }
#             text: "f"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 483
#                 y: 672
#               }
#               vertices {
#                 x: 486
#                 y: 672
#               }
#               vertices {
#                 x: 486
#                 y: 688
#               }
#               vertices {
#                 x: 483
#                 y: 688
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 487
#                 y: 672
#               }
#               vertices {
#                 x: 489
#                 y: 672
#               }
#               vertices {
#                 x: 489
#                 y: 688
#               }
#               vertices {
#                 x: 487
#                 y: 688
#               }
#             }
#             text: "n"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 490
#                 y: 672
#               }
#               vertices {
#                 x: 493
#                 y: 672
#               }
#               vertices {
#                 x: 493
#                 y: 688
#               }
#               vertices {
#                 x: 490
#                 y: 688
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 494
#                 y: 672
#               }
#               vertices {
#                 x: 496
#                 y: 672
#               }
#               vertices {
#                 x: 496
#                 y: 688
#               }
#               vertices {
#                 x: 494
#                 y: 688
#               }
#             }
#             text: "s"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 501
#               y: 672
#             }
#             vertices {
#               x: 586
#               y: 673
#             }
#             vertices {
#               x: 586
#               y: 693
#             }
#             vertices {
#               x: 501
#               y: 692
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 501
#                 y: 672
#               }
#               vertices {
#                 x: 509
#                 y: 672
#               }
#               vertices {
#                 x: 509
#                 y: 691
#               }
#               vertices {
#                 x: 501
#                 y: 691
#               }
#             }
#             text: "G"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 510
#                 y: 673
#               }
#               vertices {
#                 x: 512
#                 y: 673
#               }
#               vertices {
#                 x: 512
#                 y: 692
#               }
#               vertices {
#                 x: 510
#                 y: 692
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 513
#                 y: 673
#               }
#               vertices {
#                 x: 516
#                 y: 673
#               }
#               vertices {
#                 x: 516
#                 y: 692
#               }
#               vertices {
#                 x: 513
#                 y: 692
#               }
#             }
#             text: "H"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 517
#                 y: 673
#               }
#               vertices {
#                 x: 532
#                 y: 673
#               }
#               vertices {
#                 x: 532
#                 y: 692
#               }
#               vertices {
#                 x: 517
#                 y: 692
#               }
#             }
#             text: "9"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 533
#                 y: 673
#               }
#               vertices {
#                 x: 539
#                 y: 673
#               }
#               vertices {
#                 x: 539
#                 y: 692
#               }
#               vertices {
#                 x: 533
#                 y: 692
#               }
#             }
#             text: "1"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 540
#                 y: 673
#               }
#               vertices {
#                 x: 551
#                 y: 673
#               }
#               vertices {
#                 x: 551
#                 y: 692
#               }
#               vertices {
#                 x: 540
#                 y: 692
#               }
#             }
#             text: "-"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 552
#                 y: 673
#               }
#               vertices {
#                 x: 558
#                 y: 673
#               }
#               vertices {
#                 x: 558
#                 y: 692
#               }
#               vertices {
#                 x: 552
#                 y: 692
#               }
#             }
#             text: "1"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 559
#                 y: 673
#               }
#               vertices {
#                 x: 578
#                 y: 673
#               }
#               vertices {
#                 x: 578
#                 y: 692
#               }
#               vertices {
#                 x: 559
#                 y: 692
#               }
#             }
#             text: "1"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 579
#                 y: 673
#               }
#               vertices {
#                 x: 586
#                 y: 673
#               }
#               vertices {
#                 x: 586
#                 y: 692
#               }
#               vertices {
#                 x: 579
#                 y: 692
#               }
#             }
#             text: "4"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "CRUSH ALL DESTRUCTIVE ELEMENTS.\nshdevyy Fhogfnfenrs GhH91-114\n"
# }

# %%
for i in response.text_annotations:
    if i.locale == "en":
        if i.description is not None:
            print(i.description)
# Out:
# CRUSH ALL DESTRUCTIVE ELEMENTS.
# shdevyy Fhogfnfenrs GhH91-114

# %%
with io.open("./sample_data/T10_100.jpg", 'rb') as image_file:
    content = image_file.read()

# %%
type(content)
# Out:
# bytes

# %% [markdown]
# ### Handwriting detection

# %%
response = client.document_text_detection(image=image)
response
# Out:
# text_annotations {
#   locale: "en"
#   description: "\341\200\241\341\200\226\341\200\273\341\200\200\341\200\272\341\200\236\341\200\231\341\200\254\341\200\270\341\200\200\341\200\255\341\200\257\341\200\201\341\200\273\341\200\261\341\200\231\341\200\276\341\200\257\341\200\224\341\200\272\341\200\270\341\200\200\341\200\274\nCRUSH ALL DESTRUCTIVE ELEMENTS.\n"
#   bounding_poly {
#     vertices {
#       x: 1167
#       y: 540
#     }
#     vertices {
#       x: 1640
#       y: 540
#     }
#     vertices {
#       x: 1640
#       y: 645
#     }
#     vertices {
#       x: 1167
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "\341\200\241\341\200\226\341\200\273\341\200\200\341\200\272\341\200\236\341\200\231\341\200\254\341\200\270"
#   bounding_poly {
#     vertices {
#       x: 1167
#       y: 543
#     }
#     vertices {
#       x: 1383
#       y: 541
#     }
#     vertices {
#       x: 1383
#       y: 608
#     }
#     vertices {
#       x: 1167
#       y: 610
#     }
#   }
# }
# text_annotations {
#   description: "\341\200\200\341\200\255\341\200\257"
#   bounding_poly {
#     vertices {
#       x: 1421
#       y: 542
#     }
#     vertices {
#       x: 1438
#       y: 542
#     }
#     vertices {
#       x: 1438
#       y: 608
#     }
#     vertices {
#       x: 1421
#       y: 608
#     }
#   }
# }
# text_annotations {
#   description: "\341\200\201\341\200\273\341\200\261\341\200\231\341\200\276\341\200\257\341\200\224\341\200\272\341\200\270"
#   bounding_poly {
#     vertices {
#       x: 1483
#       y: 541
#     }
#     vertices {
#       x: 1565
#       y: 540
#     }
#     vertices {
#       x: 1565
#       y: 606
#     }
#     vertices {
#       x: 1483
#       y: 607
#     }
#   }
# }
# text_annotations {
#   description: "\341\200\200\341\200\274"
#   bounding_poly {
#     vertices {
#       x: 1619
#       y: 540
#     }
#     vertices {
#       x: 1636
#       y: 540
#     }
#     vertices {
#       x: 1636
#       y: 606
#     }
#     vertices {
#       x: 1619
#       y: 606
#     }
#   }
# }
# text_annotations {
#   description: "CRUSH"
#   bounding_poly {
#     vertices {
#       x: 1168
#       y: 613
#     }
#     vertices {
#       x: 1244
#       y: 613
#     }
#     vertices {
#       x: 1244
#       y: 645
#     }
#     vertices {
#       x: 1168
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "ALL"
#   bounding_poly {
#     vertices {
#       x: 1263
#       y: 613
#     }
#     vertices {
#       x: 1307
#       y: 613
#     }
#     vertices {
#       x: 1307
#       y: 645
#     }
#     vertices {
#       x: 1263
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "DESTRUCTIVE"
#   bounding_poly {
#     vertices {
#       x: 1327
#       y: 613
#     }
#     vertices {
#       x: 1487
#       y: 613
#     }
#     vertices {
#       x: 1487
#       y: 645
#     }
#     vertices {
#       x: 1327
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "ELEMENTS"
#   bounding_poly {
#     vertices {
#       x: 1505
#       y: 613
#     }
#     vertices {
#       x: 1631
#       y: 613
#     }
#     vertices {
#       x: 1631
#       y: 645
#     }
#     vertices {
#       x: 1505
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "."
#   bounding_poly {
#     vertices {
#       x: 1635
#       y: 613
#     }
#     vertices {
#       x: 1640
#       y: 613
#     }
#     vertices {
#       x: 1640
#       y: 645
#     }
#     vertices {
#       x: 1635
#       y: 645
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "en"
#         confidence: 0.55
#       }
#       detected_languages {
#         language_code: "my"
#         confidence: 0.45
#       }
#     }
#     width: 1943
#     height: 1458
#     blocks {
#       property {
#         detected_languages {
#           language_code: "my"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 1167
#           y: 543
#         }
#         vertices {
#           x: 1636
#           y: 540
#         }
#         vertices {
#           x: 1636
#           y: 607
#         }
#         vertices {
#           x: 1167
#           y: 610
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "my"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 1167
#             y: 543
#           }
#           vertices {
#             x: 1636
#             y: 540
#           }
#           vertices {
#             x: 1636
#             y: 607
#           }
#           vertices {
#             x: 1167
#             y: 610
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "my"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1167
#               y: 543
#             }
#             vertices {
#               x: 1383
#               y: 541
#             }
#             vertices {
#               x: 1383
#               y: 608
#             }
#             vertices {
#               x: 1167
#               y: 610
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1167
#                 y: 543
#               }
#               vertices {
#                 x: 1209
#                 y: 543
#               }
#               vertices {
#                 x: 1209
#                 y: 609
#               }
#               vertices {
#                 x: 1167
#                 y: 609
#               }
#             }
#             text: "\341\200\241"
#             confidence: 0.8
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1214
#                 y: 543
#               }
#               vertices {
#                 x: 1242
#                 y: 543
#               }
#               vertices {
#                 x: 1242
#                 y: 609
#               }
#               vertices {
#                 x: 1214
#                 y: 609
#               }
#             }
#             text: "\341\200\226"
#             confidence: 0.68
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1214
#                 y: 543
#               }
#               vertices {
#                 x: 1242
#                 y: 543
#               }
#               vertices {
#                 x: 1242
#                 y: 609
#               }
#               vertices {
#                 x: 1214
#                 y: 609
#               }
#             }
#             text: "\341\200\273"
#             confidence: 0.68
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1259
#                 y: 543
#               }
#               vertices {
#                 x: 1291
#                 y: 543
#               }
#               vertices {
#                 x: 1291
#                 y: 609
#               }
#               vertices {
#                 x: 1259
#                 y: 609
#               }
#             }
#             text: "\341\200\200"
#             confidence: 0.92
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1259
#                 y: 543
#               }
#               vertices {
#                 x: 1291
#                 y: 543
#               }
#               vertices {
#                 x: 1291
#                 y: 609
#               }
#               vertices {
#                 x: 1259
#                 y: 609
#               }
#             }
#             text: "\341\200\272"
#             confidence: 0.92
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1306
#                 y: 542
#               }
#               vertices {
#                 x: 1338
#                 y: 542
#               }
#               vertices {
#                 x: 1338
#                 y: 608
#               }
#               vertices {
#                 x: 1306
#                 y: 608
#               }
#             }
#             text: "\341\200\236"
#             confidence: 0.91
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1355
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 608
#               }
#               vertices {
#                 x: 1355
#                 y: 608
#               }
#             }
#             text: "\341\200\231"
#             confidence: 0.93
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1355
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 608
#               }
#               vertices {
#                 x: 1355
#                 y: 608
#               }
#             }
#             text: "\341\200\254"
#             confidence: 0.93
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1355
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 608
#               }
#               vertices {
#                 x: 1355
#                 y: 608
#               }
#             }
#             text: "\341\200\270"
#             confidence: 0.93
#           }
#           confidence: 0.85
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "my"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1421
#               y: 542
#             }
#             vertices {
#               x: 1438
#               y: 542
#             }
#             vertices {
#               x: 1438
#               y: 608
#             }
#             vertices {
#               x: 1421
#               y: 608
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1421
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 608
#               }
#               vertices {
#                 x: 1421
#                 y: 608
#               }
#             }
#             text: "\341\200\200"
#             confidence: 0.75
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1421
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 608
#               }
#               vertices {
#                 x: 1421
#                 y: 608
#               }
#             }
#             text: "\341\200\255"
#             confidence: 0.75
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1421
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 608
#               }
#               vertices {
#                 x: 1421
#                 y: 608
#               }
#             }
#             text: "\341\200\257"
#             confidence: 0.75
#           }
#           confidence: 0.75
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "my"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1483
#               y: 541
#             }
#             vertices {
#               x: 1565
#               y: 540
#             }
#             vertices {
#               x: 1565
#               y: 606
#             }
#             vertices {
#               x: 1483
#               y: 607
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1483
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 607
#               }
#               vertices {
#                 x: 1483
#                 y: 607
#               }
#             }
#             text: "\341\200\201"
#             confidence: 0.69
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1483
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 607
#               }
#               vertices {
#                 x: 1483
#                 y: 607
#               }
#             }
#             text: "\341\200\273"
#             confidence: 0.69
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1483
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 607
#               }
#               vertices {
#                 x: 1483
#                 y: 607
#               }
#             }
#             text: "\341\200\261"
#             confidence: 0.69
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1520
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 607
#               }
#               vertices {
#                 x: 1520
#                 y: 607
#               }
#             }
#             text: "\341\200\231"
#             confidence: 0.13
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1520
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 607
#               }
#               vertices {
#                 x: 1520
#                 y: 607
#               }
#             }
#             text: "\341\200\276"
#             confidence: 0.13
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1520
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 607
#               }
#               vertices {
#                 x: 1520
#                 y: 607
#               }
#             }
#             text: "\341\200\257"
#             confidence: 0.13
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1549
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 607
#               }
#               vertices {
#                 x: 1549
#                 y: 607
#               }
#             }
#             text: "\341\200\224"
#             confidence: 0.8
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1549
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 607
#               }
#               vertices {
#                 x: 1549
#                 y: 607
#               }
#             }
#             text: "\341\200\272"
#             confidence: 0.8
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1549
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 607
#               }
#               vertices {
#                 x: 1549
#                 y: 607
#               }
#             }
#             text: "\341\200\270"
#             confidence: 0.8
#           }
#           confidence: 0.54
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "my"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1619
#               y: 540
#             }
#             vertices {
#               x: 1636
#               y: 540
#             }
#             vertices {
#               x: 1636
#               y: 606
#             }
#             vertices {
#               x: 1619
#               y: 606
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1619
#                 y: 540
#               }
#               vertices {
#                 x: 1636
#                 y: 540
#               }
#               vertices {
#                 x: 1636
#                 y: 606
#               }
#               vertices {
#                 x: 1619
#                 y: 606
#               }
#             }
#             text: "\341\200\200"
#             confidence: 0.73
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1619
#                 y: 540
#               }
#               vertices {
#                 x: 1636
#                 y: 540
#               }
#               vertices {
#                 x: 1636
#                 y: 606
#               }
#               vertices {
#                 x: 1619
#                 y: 606
#               }
#             }
#             text: "\341\200\274"
#             confidence: 0.73
#           }
#           confidence: 0.73
#         }
#         confidence: 0.7
#       }
#       block_type: TEXT
#       confidence: 0.7
#     }
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 1168
#           y: 613
#         }
#         vertices {
#           x: 1640
#           y: 613
#         }
#         vertices {
#           x: 1640
#           y: 645
#         }
#         vertices {
#           x: 1168
#           y: 645
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 1168
#             y: 613
#           }
#           vertices {
#             x: 1640
#             y: 613
#           }
#           vertices {
#             x: 1640
#             y: 645
#           }
#           vertices {
#             x: 1168
#             y: 645
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1168
#               y: 613
#             }
#             vertices {
#               x: 1244
#               y: 613
#             }
#             vertices {
#               x: 1244
#               y: 645
#             }
#             vertices {
#               x: 1168
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1168
#                 y: 613
#               }
#               vertices {
#                 x: 1181
#                 y: 613
#               }
#               vertices {
#                 x: 1181
#                 y: 645
#               }
#               vertices {
#                 x: 1168
#                 y: 645
#               }
#             }
#             text: "C"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1184
#                 y: 613
#               }
#               vertices {
#                 x: 1194
#                 y: 613
#               }
#               vertices {
#                 x: 1194
#                 y: 645
#               }
#               vertices {
#                 x: 1184
#                 y: 645
#               }
#             }
#             text: "R"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1199
#                 y: 613
#               }
#               vertices {
#                 x: 1211
#                 y: 613
#               }
#               vertices {
#                 x: 1211
#                 y: 645
#               }
#               vertices {
#                 x: 1199
#                 y: 645
#               }
#             }
#             text: "U"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1217
#                 y: 613
#               }
#               vertices {
#                 x: 1227
#                 y: 613
#               }
#               vertices {
#                 x: 1227
#                 y: 645
#               }
#               vertices {
#                 x: 1217
#                 y: 645
#               }
#             }
#             text: "S"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1232
#                 y: 613
#               }
#               vertices {
#                 x: 1244
#                 y: 613
#               }
#               vertices {
#                 x: 1244
#                 y: 645
#               }
#               vertices {
#                 x: 1232
#                 y: 645
#               }
#             }
#             text: "H"
#             confidence: 0.99
#           }
#           confidence: 0.99
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1263
#               y: 613
#             }
#             vertices {
#               x: 1307
#               y: 613
#             }
#             vertices {
#               x: 1307
#               y: 645
#             }
#             vertices {
#               x: 1263
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1263
#                 y: 613
#               }
#               vertices {
#                 x: 1275
#                 y: 613
#               }
#               vertices {
#                 x: 1275
#                 y: 645
#               }
#               vertices {
#                 x: 1263
#                 y: 645
#               }
#             }
#             text: "A"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1279
#                 y: 613
#               }
#               vertices {
#                 x: 1292
#                 y: 613
#               }
#               vertices {
#                 x: 1292
#                 y: 645
#               }
#               vertices {
#                 x: 1279
#                 y: 645
#               }
#             }
#             text: "L"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1294
#                 y: 613
#               }
#               vertices {
#                 x: 1307
#                 y: 613
#               }
#               vertices {
#                 x: 1307
#                 y: 645
#               }
#               vertices {
#                 x: 1294
#                 y: 645
#               }
#             }
#             text: "L"
#             confidence: 0.99
#           }
#           confidence: 0.99
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1327
#               y: 613
#             }
#             vertices {
#               x: 1487
#               y: 613
#             }
#             vertices {
#               x: 1487
#               y: 645
#             }
#             vertices {
#               x: 1327
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1327
#                 y: 613
#               }
#               vertices {
#                 x: 1340
#                 y: 613
#               }
#               vertices {
#                 x: 1340
#                 y: 645
#               }
#               vertices {
#                 x: 1327
#                 y: 645
#               }
#             }
#             text: "D"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1345
#                 y: 613
#               }
#               vertices {
#                 x: 1356
#                 y: 613
#               }
#               vertices {
#                 x: 1356
#                 y: 645
#               }
#               vertices {
#                 x: 1345
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1361
#                 y: 613
#               }
#               vertices {
#                 x: 1372
#                 y: 613
#               }
#               vertices {
#                 x: 1372
#                 y: 645
#               }
#               vertices {
#                 x: 1361
#                 y: 645
#               }
#             }
#             text: "S"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1378
#                 y: 613
#               }
#               vertices {
#                 x: 1389
#                 y: 613
#               }
#               vertices {
#                 x: 1389
#                 y: 645
#               }
#               vertices {
#                 x: 1378
#                 y: 645
#               }
#             }
#             text: "T"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1392
#                 y: 613
#               }
#               vertices {
#                 x: 1402
#                 y: 613
#               }
#               vertices {
#                 x: 1402
#                 y: 645
#               }
#               vertices {
#                 x: 1392
#                 y: 645
#               }
#             }
#             text: "R"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1408
#                 y: 613
#               }
#               vertices {
#                 x: 1418
#                 y: 613
#               }
#               vertices {
#                 x: 1418
#                 y: 645
#               }
#               vertices {
#                 x: 1408
#                 y: 645
#               }
#             }
#             text: "U"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1420
#                 y: 613
#               }
#               vertices {
#                 x: 1432
#                 y: 613
#               }
#               vertices {
#                 x: 1432
#                 y: 645
#               }
#               vertices {
#                 x: 1420
#                 y: 645
#               }
#             }
#             text: "C"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1441
#                 y: 613
#               }
#               vertices {
#                 x: 1451
#                 y: 613
#               }
#               vertices {
#                 x: 1451
#                 y: 645
#               }
#               vertices {
#                 x: 1441
#                 y: 645
#               }
#             }
#             text: "T"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1453
#                 y: 613
#               }
#               vertices {
#                 x: 1459
#                 y: 613
#               }
#               vertices {
#                 x: 1459
#                 y: 645
#               }
#               vertices {
#                 x: 1453
#                 y: 645
#               }
#             }
#             text: "I"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1462
#                 y: 613
#               }
#               vertices {
#                 x: 1470
#                 y: 613
#               }
#               vertices {
#                 x: 1470
#                 y: 645
#               }
#               vertices {
#                 x: 1462
#                 y: 645
#               }
#             }
#             text: "V"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1475
#                 y: 613
#               }
#               vertices {
#                 x: 1487
#                 y: 613
#               }
#               vertices {
#                 x: 1487
#                 y: 645
#               }
#               vertices {
#                 x: 1475
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 0.99
#           }
#           confidence: 0.99
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1505
#               y: 613
#             }
#             vertices {
#               x: 1631
#               y: 613
#             }
#             vertices {
#               x: 1631
#               y: 645
#             }
#             vertices {
#               x: 1505
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1505
#                 y: 613
#               }
#               vertices {
#                 x: 1521
#                 y: 613
#               }
#               vertices {
#                 x: 1521
#                 y: 645
#               }
#               vertices {
#                 x: 1505
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1524
#                 y: 613
#               }
#               vertices {
#                 x: 1534
#                 y: 613
#               }
#               vertices {
#                 x: 1534
#                 y: 645
#               }
#               vertices {
#                 x: 1524
#                 y: 645
#               }
#             }
#             text: "L"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1539
#                 y: 613
#               }
#               vertices {
#                 x: 1550
#                 y: 613
#               }
#               vertices {
#                 x: 1550
#                 y: 645
#               }
#               vertices {
#                 x: 1539
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1556
#                 y: 613
#               }
#               vertices {
#                 x: 1567
#                 y: 613
#               }
#               vertices {
#                 x: 1567
#                 y: 645
#               }
#               vertices {
#                 x: 1556
#                 y: 645
#               }
#             }
#             text: "M"
#             confidence: 0.31
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1572
#                 y: 613
#               }
#               vertices {
#                 x: 1583
#                 y: 613
#               }
#               vertices {
#                 x: 1583
#                 y: 645
#               }
#               vertices {
#                 x: 1572
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1589
#                 y: 613
#               }
#               vertices {
#                 x: 1601
#                 y: 613
#               }
#               vertices {
#                 x: 1601
#                 y: 645
#               }
#               vertices {
#                 x: 1589
#                 y: 645
#               }
#             }
#             text: "N"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1609
#                 y: 613
#               }
#               vertices {
#                 x: 1620
#                 y: 613
#               }
#               vertices {
#                 x: 1620
#                 y: 645
#               }
#               vertices {
#                 x: 1609
#                 y: 645
#               }
#             }
#             text: "T"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1624
#                 y: 613
#               }
#               vertices {
#                 x: 1631
#                 y: 613
#               }
#               vertices {
#                 x: 1631
#                 y: 645
#               }
#               vertices {
#                 x: 1624
#                 y: 645
#               }
#             }
#             text: "S"
#             confidence: 1.0
#           }
#           confidence: 0.91
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1635
#               y: 613
#             }
#             vertices {
#               x: 1640
#               y: 613
#             }
#             vertices {
#               x: 1640
#               y: 645
#             }
#             vertices {
#               x: 1635
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1635
#                 y: 613
#               }
#               vertices {
#                 x: 1640
#                 y: 613
#               }
#               vertices {
#                 x: 1640
#                 y: 645
#               }
#               vertices {
#                 x: 1635
#                 y: 645
#               }
#             }
#             text: "."
#             confidence: 0.99
#           }
#           confidence: 0.99
#         }
#         confidence: 0.96
#       }
#       block_type: TEXT
#       confidence: 0.96
#     }
#   }
#   text: "\341\200\241\341\200\226\341\200\273\341\200\200\341\200\272\341\200\236\341\200\231\341\200\254\341\200\270\341\200\200\341\200\255\341\200\257\341\200\201\341\200\273\341\200\261\341\200\231\341\200\276\341\200\257\341\200\224\341\200\272\341\200\270\341\200\200\341\200\274\nCRUSH ALL DESTRUCTIVE ELEMENTS.\n"
# }

# %% [markdown]
# ### Face Detection

# %%
response = client.face_detection(image=image)
response
# Out:
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 1366
#       y: 844
#     }
#     vertices {
#       x: 1419
#       y: 844
#     }
#     vertices {
#       x: 1419
#       y: 907
#     }
#     vertices {
#       x: 1366
#       y: 907
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 1369
#       y: 856
#     }
#     vertices {
#       x: 1414
#       y: 856
#     }
#     vertices {
#       x: 1414
#       y: 904
#     }
#     vertices {
#       x: 1369
#       y: 904
#     }
#   }
#   landmarks {
#     type: LEFT_EYE
#     position {
#       x: 1383.7673
#       y: 876.0457
#       z: 0.00083225965
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE
#     position {
#       x: 1400.4681
#       y: 875.8691
#       z: -1.1441102
#     }
#   }
#   landmarks {
#     type: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 1378.968
#       y: 872.35834
#       z: 1.4936231
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 1388.3668
#       y: 872.18774
#       z: -3.4466605
#     }
#   }
#   landmarks {
#     type: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 1395.193
#       y: 872.2724
#       z: -3.958929
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 1405.0737
#       y: 872.139
#       z: -0.38946208
#     }
#   }
#   landmarks {
#     type: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 1391.2834
#       y: 876.1134
#       z: -3.699676
#     }
#   }
#   landmarks {
#     type: NOSE_TIP
#     position {
#       x: 1391.4618
#       y: 884.77155
#       z: -7.5455046
#     }
#   }
#   landmarks {
#     type: UPPER_LIP
#     position {
#       x: 1392.2816
#       y: 890.2574
#       z: -3.772831
#     }
#   }
#   landmarks {
#     type: LOWER_LIP
#     position {
#       x: 1392.4532
#       y: 895.9286
#       z: -2.3626642
#     }
#   }
#   landmarks {
#     type: MOUTH_LEFT
#     position {
#       x: 1386.6019
#       y: 892.9291
#       z: 0.780205
#     }
#   }
#   landmarks {
#     type: MOUTH_RIGHT
#     position {
#       x: 1398.4403
#       y: 893.28186
#       z: -0.104536474
#     }
#   }
#   landmarks {
#     type: MOUTH_CENTER
#     position {
#       x: 1392.2823
#       y: 892.9735
#       z: -2.492849
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_RIGHT
#     position {
#       x: 1396.4988
#       y: 886.36865
#       z: -2.2296746
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_LEFT
#     position {
#       x: 1388.3215
#       y: 885.9467
#       z: -1.5405288
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_CENTER
#     position {
#       x: 1392.2689
#       y: 887.09314
#       z: -4.0271754
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 1383.4316
#       y: 874.6032
#       z: -0.9302708
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 1386.7603
#       y: 876.3348
#       z: -0.20438242
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 1383.5748
#       y: 877.14307
#       z: -0.080521286
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 1380.7532
#       y: 876.0072
#       z: 1.6102331
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 1400.4513
#       y: 874.2683
#       z: -2.085199
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 1403.8564
#       y: 875.79193
#       z: -0.0037483573
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 1400.5906
#       y: 877.05743
#       z: -1.2464813
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 1397.0735
#       y: 876.0226
#       z: -0.88531375
#     }
#   }
#   landmarks {
#     type: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 1383.5952
#       y: 870.8246
#       z: -2.0162473
#     }
#   }
#   landmarks {
#     type: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 1399.9164
#       y: 870.7802
#       z: -3.2115884
#     }
#   }
#   landmarks {
#     type: LEFT_EAR_TRAGION
#     position {
#       x: 1373.6294
#       y: 878.6147
#       z: 19.886148
#     }
#   }
#   landmarks {
#     type: RIGHT_EAR_TRAGION
#     position {
#       x: 1412.7881
#       y: 880.31195
#       z: 17.223646
#     }
#   }
#   landmarks {
#     type: FOREHEAD_GLABELLA
#     position {
#       x: 1391.199
#       y: 872.4811
#       z: -4.219744
#     }
#   }
#   landmarks {
#     type: CHIN_GNATHION
#     position {
#       x: 1392.3892
#       y: 903.14813
#       z: 0.26630414
#     }
#   }
#   landmarks {
#     type: CHIN_LEFT_GONION
#     position {
#       x: 1379.2284
#       y: 893.00696
#       z: 14.272092
#     }
#   }
#   landmarks {
#     type: CHIN_RIGHT_GONION
#     position {
#       x: 1407.5604
#       y: 893.5872
#       z: 12.186606
#     }
#   }
#   landmarks {
#     type: 35
#     position {
#       x: 1381.7542
#       y: 886.1315
#       z: 2.2542636
#     }
#   }
#   landmarks {
#     type: 36
#     position {
#       x: 1403.7883
#       y: 886.0649
#       z: 0.69765604
#     }
#   }
#   roll_angle: -1.2771267
#   pan_angle: -4.0320983
#   tilt_angle: -4.5761514
#   detection_confidence: 0.40316778
#   landmarking_confidence: 0.7961469
#   joy_likelihood: VERY_UNLIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: VERY_UNLIKELY
#   blurred_likelihood: VERY_LIKELY
#   headwear_likelihood: VERY_UNLIKELY
# }
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 1516
#       y: 805
#     }
#     vertices {
#       x: 1562
#       y: 805
#     }
#     vertices {
#       x: 1562
#       y: 859
#     }
#     vertices {
#       x: 1516
#       y: 859
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 1517
#       y: 813
#     }
#     vertices {
#       x: 1557
#       y: 813
#     }
#     vertices {
#       x: 1557
#       y: 855
#     }
#     vertices {
#       x: 1517
#       y: 855
#     }
#   }
#   landmarks {
#     type: LEFT_EYE
#     position {
#       x: 1532.6692
#       y: 829.51025
#       z: 0.0015702248
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE
#     position {
#       x: 1546.6168
#       y: 829.83496
#       z: -0.32492423
#     }
#   }
#   landmarks {
#     type: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 1528.4674
#       y: 825.8735
#       z: 1.9662406
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 1536.475
#       y: 825.7418
#       z: -1.9696603
#     }
#   }
#   landmarks {
#     type: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 1542.4716
#       y: 825.9269
#       z: -2.1311212
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 1550.9932
#       y: 826.2847
#       z: 1.4299142
#     }
#   }
#   landmarks {
#     type: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 1539.3008
#       y: 829.0219
#       z: -2.81198
#     }
#   }
#   landmarks {
#     type: NOSE_TIP
#     position {
#       x: 1538.9033
#       y: 835.56396
#       z: -7.8922143
#     }
#   }
#   landmarks {
#     type: UPPER_LIP
#     position {
#       x: 1539.4279
#       y: 841.6299
#       z: -5.938119
#     }
#   }
#   landmarks {
#     type: LOWER_LIP
#     position {
#       x: 1539.8373
#       y: 845.6689
#       z: -5.7219973
#     }
#   }
#   landmarks {
#     type: MOUTH_LEFT
#     position {
#       x: 1533.3966
#       y: 843.7771
#       z: -2.550529
#     }
#   }
#   landmarks {
#     type: MOUTH_RIGHT
#     position {
#       x: 1545.0377
#       y: 843.92596
#       z: -2.8554244
#     }
#   }
#   landmarks {
#     type: MOUTH_CENTER
#     position {
#       x: 1539.3702
#       y: 843.4969
#       z: -5.278475
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_RIGHT
#     position {
#       x: 1543.3663
#       y: 838.0022
#       z: -3.4556847
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_LEFT
#     position {
#       x: 1536.0236
#       y: 837.9066
#       z: -3.258141
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_CENTER
#     position {
#       x: 1539.4791
#       y: 838.5124
#       z: -5.4357467
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 1532.5465
#       y: 828.2877
#       z: -0.5429008
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 1535.262
#       y: 829.54346
#       z: -0.0776639
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 1532.5515
#       y: 830.5109
#       z: -0.32260978
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 1529.9247
#       y: 829.7212
#       z: 1.242556
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 1546.6611
#       y: 828.4106
#       z: -0.8340409
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 1549.5468
#       y: 829.91174
#       z: 0.81858027
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 1546.6454
#       y: 830.8994
#       z: -0.6652491
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 1543.4469
#       y: 829.90814
#       z: -0.28506887
#     }
#   }
#   landmarks {
#     type: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 1532.4739
#       y: 824.52155
#       z: -0.63220143
#     }
#   }
#   landmarks {
#     type: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 1546.661
#       y: 824.8445
#       z: -0.97596717
#     }
#   }
#   landmarks {
#     type: LEFT_EAR_TRAGION
#     position {
#       x: 1522.5061
#       y: 836.84717
#       z: 15.498465
#     }
#   }
#   landmarks {
#     type: RIGHT_EAR_TRAGION
#     position {
#       x: 1557.033
#       y: 837.0436
#       z: 14.860805
#     }
#   }
#   landmarks {
#     type: FOREHEAD_GLABELLA
#     position {
#       x: 1539.316
#       y: 825.8563
#       z: -2.514116
#     }
#   }
#   landmarks {
#     type: CHIN_GNATHION
#     position {
#       x: 1539.4905
#       y: 852.65356
#       z: -5.0391097
#     }
#   }
#   landmarks {
#     type: CHIN_LEFT_GONION
#     position {
#       x: 1526.4175
#       y: 846.28564
#       z: 8.106747
#     }
#   }
#   landmarks {
#     type: CHIN_RIGHT_GONION
#     position {
#       x: 1552.5807
#       y: 847.5084
#       z: 7.541834
#     }
#   }
#   landmarks {
#     type: 35
#     position {
#       x: 1530.0499
#       y: 838.35046
#       z: -0.22986293
#     }
#   }
#   landmarks {
#     type: 36
#     position {
#       x: 1549.2396
#       y: 838.54736
#       z: -0.660513
#     }
#   }
#   roll_angle: 0.46718973
#   pan_angle: -1.1852219
#   tilt_angle: 9.115759
#   detection_confidence: 0.43665302
#   landmarking_confidence: 0.69702375
#   joy_likelihood: VERY_UNLIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: VERY_UNLIKELY
#   blurred_likelihood: VERY_LIKELY
#   headwear_likelihood: VERY_UNLIKELY
# }
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 146
#       y: 762
#     }
#     vertices {
#       x: 195
#       y: 762
#     }
#     vertices {
#       x: 195
#       y: 819
#     }
#     vertices {
#       x: 146
#       y: 819
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 151
#       y: 765
#     }
#     vertices {
#       x: 200
#       y: 765
#     }
#     vertices {
#       x: 200
#       y: 816
#     }
#     vertices {
#       x: 151
#       y: 816
#     }
#   }
#   landmarks {
#     type: LEFT_EYE
#     position {
#       x: 172.68607
#       y: 790.8337
#       z: 0.001957655
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE
#     position {
#       x: 184.18155
#       y: 790.76965
#       z: 7.932508
#     }
#   }
#   landmarks {
#     type: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 167.79338
#       y: 786.6496
#       z: -1.6024587
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 176.90242
#       y: 786.69946
#       z: -0.079720736
#     }
#   }
#   landmarks {
#     type: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 182.84816
#       y: 787.0171
#       z: 3.808085
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 188.5118
#       y: 788.349
#       z: 11.775462
#     }
#   }
#   landmarks {
#     type: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 179.80301
#       y: 789.892
#       z: 1.6177027
#     }
#   }
#   landmarks {
#     type: NOSE_TIP
#     position {
#       x: 182.48065
#       y: 798.24255
#       z: -1.8300424
#     }
#   }
#   landmarks {
#     type: UPPER_LIP
#     position {
#       x: 180.18642
#       y: 804.023
#       z: 0.5505489
#     }
#   }
#   landmarks {
#     type: LOWER_LIP
#     position {
#       x: 179.271
#       y: 807.57263
#       z: 1.2511115
#     }
#   }
#   landmarks {
#     type: MOUTH_LEFT
#     position {
#       x: 173.65514
#       y: 805.7639
#       z: 0.38682735
#     }
#   }
#   landmarks {
#     type: MOUTH_RIGHT
#     position {
#       x: 182.90477
#       y: 805.77954
#       z: 6.855801
#     }
#   }
#   landmarks {
#     type: MOUTH_CENTER
#     position {
#       x: 180.13878
#       y: 806.4021
#       z: 1.4331994
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_RIGHT
#     position {
#       x: 183.10162
#       y: 800.06024
#       z: 4.56192
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_LEFT
#     position {
#       x: 176.02602
#       y: 800.015
#       z: 0.06448352
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_CENTER
#     position {
#       x: 180.29868
#       y: 801.0589
#       z: 0.5745257
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 172.7856
#       y: 789.4053
#       z: -0.73714805
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 175.57271
#       y: 790.8863
#       z: 1.709262
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 172.55635
#       y: 792.0175
#       z: -0.2641549
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 169.58238
#       y: 790.66223
#       z: -0.61559486
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 184.68993
#       y: 789.4616
#       z: 7.39788
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 186.21153
#       y: 790.9017
#       z: 10.709253
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 184.34705
#       y: 791.8964
#       z: 7.8693256
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 181.7698
#       y: 790.74805
#       z: 6.2894287
#     }
#   }
#   landmarks {
#     type: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 172.69455
#       y: 785.3219
#       z: -1.5835867
#     }
#   }
#   landmarks {
#     type: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 185.94913
#       y: 786.4156
#       z: 7.1267214
#     }
#   }
#   landmarks {
#     type: LEFT_EAR_TRAGION
#     position {
#       x: 153.4831
#       y: 793.0909
#       z: 9.069161
#     }
#   }
#   landmarks {
#     type: RIGHT_EAR_TRAGION
#     position {
#       x: 183.38467
#       y: 795.8122
#       z: 27.28698
#     }
#   }
#   landmarks {
#     type: FOREHEAD_GLABELLA
#     position {
#       x: 179.85936
#       y: 786.5055
#       z: 1.4633702
#     }
#   }
#   landmarks {
#     type: CHIN_GNATHION
#     position {
#       x: 177.99641
#       y: 815.035
#       z: 2.7541642
#     }
#   }
#   landmarks {
#     type: CHIN_LEFT_GONION
#     position {
#       x: 159.97365
#       y: 806.84973
#       z: 5.726615
#     }
#   }
#   landmarks {
#     type: CHIN_RIGHT_GONION
#     position {
#       x: 181.55588
#       y: 807.92114
#       z: 20.628708
#     }
#   }
#   landmarks {
#     type: 35
#     position {
#       x: 169.8829
#       y: 800.2229
#       z: -0.5935483
#     }
#   }
#   landmarks {
#     type: 36
#     position {
#       x: 185.96106
#       y: 800.41895
#       z: 10.4070215
#     }
#   }
#   roll_angle: 1.7920079
#   pan_angle: 33.97388
#   tilt_angle: 0.4574975
#   detection_confidence: 0.3795814
#   landmarking_confidence: 0.20558155
#   joy_likelihood: VERY_UNLIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: LIKELY
#   blurred_likelihood: POSSIBLE
#   headwear_likelihood: VERY_UNLIKELY
# }

# %% [markdown]
# ### Image Properties

# %%
response = client.image_properties(image=image)
response
# Out:
# image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 90.0
#         green: 84.0
#         blue: 57.0
#       }
#       score: 0.1658262
#       pixel_fraction: 0.0960472
#     }
#     colors {
#       color {
#         red: 157.0
#         green: 150.0
#         blue: 126.0
#       }
#       score: 0.15258466
#       pixel_fraction: 0.1879646
#     }
#     colors {
#       color {
#         red: 193.0
#         green: 191.0
#         blue: 179.0
#       }
#       score: 0.071288146
#       pixel_fraction: 0.20306785
#     }
#     colors {
#       color {
#         red: 166.0
#         green: 108.0
#         blue: 63.0
#       }
#       score: 0.050707348
#       pixel_fraction: 0.0068436577
#     }
#     colors {
#       color {
#         red: 126.0
#         green: 120.0
#         blue: 93.0
#       }
#       score: 0.14381455
#       pixel_fraction: 0.1059587
#     }
#     colors {
#       color {
#         red: 61.0
#         green: 56.0
#         blue: 31.0
#       }
#       score: 0.1095238
#       pixel_fraction: 0.061297935
#     }
#     colors {
#       color {
#         red: 198.0
#         green: 140.0
#         blue: 94.0
#       }
#       score: 0.041776016
#       pixel_fraction: 0.0066076694
#     }
#     colors {
#       color {
#         red: 194.0
#         green: 188.0
#         blue: 166.0
#       }
#       score: 0.03585536
#       pixel_fraction: 0.02938053
#     }
#     colors {
#       color {
#         red: 77.0
#         green: 89.0
#         blue: 57.0
#       }
#       score: 0.0275175
#       pixel_fraction: 0.014277286
#     }
#     colors {
#       color {
#         red: 133.0
#         green: 80.0
#         blue: 37.0
#       }
#       score: 0.02192222
#       pixel_fraction: 0.00359882
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#         x: 680
#       }
#       vertices {
#         x: 1496
#       }
#       vertices {
#         x: 1496
#         y: 1457
#       }
#       vertices {
#         x: 680
#         y: 1457
#       }
#     }
#     confidence: 0.46875
#     importance_fraction: 0.58464855
#   }
# }

# %% [markdown]
# ### Label Detection

# %%
response = client.label_detection(image=image)
response
# Out:
# label_annotations {
#   mid: "/m/079bkr"
#   description: "Mode of transport"
#   score: 0.96869874
#   topicality: 0.96869874
# }
# label_annotations {
#   mid: "/m/018p4k"
#   description: "Cart"
#   score: 0.90895
#   topicality: 0.90895
# }
# label_annotations {
#   mid: "/m/07yv9"
#   description: "Vehicle"
#   score: 0.90143174
#   topicality: 0.90143174
# }
# label_annotations {
#   mid: "/m/01hffk"
#   description: "Carriage"
#   score: 0.89694226
#   topicality: 0.89694226
# }
# label_annotations {
#   mid: "/m/07bsy"
#   description: "Transport"
#   score: 0.86291295
#   topicality: 0.86291295
# }
# label_annotations {
#   mid: "/m/07_gml"
#   description: "Working animal"
#   score: 0.736109
#   topicality: 0.736109
# }
# label_annotations {
#   mid: "/m/02j091"
#   description: "Horse and buggy"
#   score: 0.71871597
#   topicality: 0.71871597
# }
# label_annotations {
#   mid: "/m/0464z4"
#   description: "Pack animal"
#   score: 0.70788527
#   topicality: 0.70788527
# }
# label_annotations {
#   mid: "/m/0242gd"
#   description: "Wagon"
#   score: 0.6617713
#   topicality: 0.6617713
# }
# label_annotations {
#   mid: "/m/03k3r"
#   description: "Horse"
#   score: 0.6272487
#   topicality: 0.6272487
# }

# %% [markdown]
# ### Landmark Detection

# %%
response = client.landmark_detection(image=image)
response

# %% [markdown]
# ### Logo Detection

# %%
response = client.logo_detection(image=image)
response
# Out:
# logo_annotations {
#   mid: "/m/03mb5kj"
#   description: "Browne Jacobson"
#   score: 0.6108932
#   bounding_poly {
#     vertices {
#       x: 1155
#       y: 535
#     }
#     vertices {
#       x: 1642
#       y: 535
#     }
#     vertices {
#       x: 1642
#       y: 621
#     }
#     vertices {
#       x: 1155
#       y: 621
#     }
#   }
# }

# %% [markdown]
# ### Object Detection

# %%
response = client.object_localization(image=image)
response
# Out:
# localized_object_annotations {
#   mid: "/m/083wq"
#   name: "Wheel"
#   score: 0.92690665
#   bounding_poly {
#     normalized_vertices {
#       x: 0.51806146
#       y: 0.5668511
#     }
#     normalized_vertices {
#       x: 0.61581224
#       y: 0.5668511
#     }
#     normalized_vertices {
#       x: 0.61581224
#       y: 0.71255636
#     }
#     normalized_vertices {
#       x: 0.51806146
#       y: 0.71255636
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/083wq"
#   name: "Wheel"
#   score: 0.91704434
#   bounding_poly {
#     normalized_vertices {
#       x: 0.4728733
#       y: 0.55629605
#     }
#     normalized_vertices {
#       x: 0.56723005
#       y: 0.55629605
#     }
#     normalized_vertices {
#       x: 0.56723005
#       y: 0.68358594
#     }
#     normalized_vertices {
#       x: 0.4728733
#       y: 0.68358594
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.91213554
#   bounding_poly {
#     normalized_vertices {
#       x: 0.6835687
#       y: 0.5708439
#     }
#     normalized_vertices {
#       x: 0.7492478
#       y: 0.5708439
#     }
#     normalized_vertices {
#       x: 0.7492478
#       y: 0.79503417
#     }
#     normalized_vertices {
#       x: 0.6835687
#       y: 0.79503417
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.90596837
#   bounding_poly {
#     normalized_vertices {
#       x: 0.058958557
#       y: 0.5172151
#     }
#     normalized_vertices {
#       x: 0.11600954
#       y: 0.5172151
#     }
#     normalized_vertices {
#       x: 0.11600954
#       y: 0.7466211
#     }
#     normalized_vertices {
#       x: 0.058958557
#       y: 0.7466211
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.89921266
#   bounding_poly {
#     normalized_vertices {
#       x: 0.7503992
#       y: 0.5531373
#     }
#     normalized_vertices {
#       x: 0.8143771
#       y: 0.5531373
#     }
#     normalized_vertices {
#       x: 0.8143771
#       y: 0.76852936
#     }
#     normalized_vertices {
#       x: 0.7503992
#       y: 0.76852936
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.89702296
#   bounding_poly {
#     normalized_vertices {
#       x: 0.6081823
#       y: 0.5821188
#     }
#     normalized_vertices {
#       x: 0.6802936
#       y: 0.5821188
#     }
#     normalized_vertices {
#       x: 0.6802936
#       y: 0.77460486
#     }
#     normalized_vertices {
#       x: 0.6081823
#       y: 0.77460486
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/03k3r"
#   name: "Horse"
#   score: 0.88190407
#   bounding_poly {
#     normalized_vertices {
#       x: 0.2720629
#       y: 0.4858913
#     }
#     normalized_vertices {
#       x: 0.47163764
#       y: 0.4858913
#     }
#     normalized_vertices {
#       x: 0.47163764
#       y: 0.70160955
#     }
#     normalized_vertices {
#       x: 0.2720629
#       y: 0.70160955
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/018p4k"
#   name: "Cart"
#   score: 0.86740184
#   bounding_poly {
#     normalized_vertices {
#       x: 0.2967279
#       y: 0.45067278
#     }
#     normalized_vertices {
#       x: 0.6583302
#       y: 0.45067278
#     }
#     normalized_vertices {
#       x: 0.6583302
#       y: 0.7092617
#     }
#     normalized_vertices {
#       x: 0.2967279
#       y: 0.7092617
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.7488101
#   bounding_poly {
#     normalized_vertices {
#       x: 0.52607185
#       y: 0.47454342
#     }
#     normalized_vertices {
#       x: 0.6090762
#       y: 0.47454342
#     }
#     normalized_vertices {
#       x: 0.6090762
#       y: 0.6645767
#     }
#     normalized_vertices {
#       x: 0.52607185
#       y: 0.6645767
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/0h9mv"
#   name: "Tire"
#   score: 0.6164075
#   bounding_poly {
#     normalized_vertices {
#       x: 0.51571643
#       y: 0.56225735
#     }
#     normalized_vertices {
#       x: 0.61457133
#       y: 0.56225735
#     }
#     normalized_vertices {
#       x: 0.61457133
#       y: 0.71344924
#     }
#     normalized_vertices {
#       x: 0.51571643
#       y: 0.71344924
#     }
#   }
# }

# %% [markdown]
# ### Web Detection

# %%
response = client.web_detection(image=image)
response
# Out:
# web_detection {
#   web_entities {
#     entity_id: "/m/03k3r"
#     score: 0.8618525
#     description: "Horse"
#   }
#   web_entities {
#     entity_id: "/m/02j091"
#     score: 0.61085624
#     description: "Horse and buggy"
#   }
#   web_entities {
#     entity_id: "/m/02z6033"
#     score: 0.5662589
#     description: "Horse harness"
#   }
#   web_entities {
#     entity_id: "/m/07bsy"
#     score: 0.53916574
#     description: "Transport"
#   }
#   web_entities {
#     entity_id: "/m/0464z4"
#     score: 0.5269144
#     description: "Pack animal"
#   }
#   web_entities {
#     entity_id: "/m/01c8br"
#     score: 0.41458538
#     description: "Street"
#   }
#   web_entities {
#     entity_id: "/m/07j7r"
#     score: 0.33523893
#     description: "Tree"
#   }
#   web_entities {
#     entity_id: "/m/06mq7"
#     description: "Science"
#   }
#   web_entities {
#     entity_id: "/m/01540"
#     description: "Biology"
#   }
#   visually_similar_images {
#     url: "https://images1.apartments.com/i2/W_AoNVPe9iQvXkYTvLLB9zAC6hzLM4P6OOAoq2yk0h0/117/carriage-homes-at-villebois-wilsonville-or.jpg"
#   }
#   visually_similar_images {
#     url: "https://images1.apartments.com/i2/HaEEXW2CuaEHlmQrKidyRjw6kQy_x2kX5s_jNgpVODE/117/pinetree-plaza-chula-vista-ca-building-photo.jpg"
#   }
#   visually_similar_images {
#     url: "https://ssl.cdn-redfin.com/photo/229/mbphoto/227/genMid.1918227_39_3.jpg"
#   }
#   visually_similar_images {
#     url: "https://c8.alamy.com/comp/KE1M5J/december-9-2015-tombstone-arizona-usa-christmas-tree-set-up-on-the-KE1M5J.jpg"
#   }
#   visually_similar_images {
#     url: "https://c8.alamy.com/comp/D206EM/man-and-woman-walk-past-a-bare-deciduous-tree-with-balls-of-evergreen-D206EM.jpg"
#   }
#   visually_similar_images {
#     url: "http://i972.photobucket.com/albums/ae202/Palmerum4/Ganza%20Spr%2014/Fri/DSC_0069.jpg"
#   }
#   visually_similar_images {
#     url: "https://farm2.staticflickr.com/1732/27990514627_b9a165774d_z.jpg"
#   }
#   visually_similar_images {
#     url: "https://02f0a56ef46d93f03c90-22ac5f107621879d5667e0d7ed595bdb.ssl.cf2.rackcdn.com/sites/12966/photos/287911/Coulter\'s_Tree_Service_-_Tulsa_-_Philcrest_Hills_-_Cottonwood_Before20170412-24848-l9u0i7_960x960.jpg"
#   }
#   visually_similar_images {
#     url: "http://gis.beverlyhills.org/GISDocs/CIP/CurrentFY/Picture/CIP_0089.jpg"
#   }
#   visually_similar_images {
#     url: "https://thumbs.dreamstime.com/b/deserted-market-square-mindelo-island-sao-vicente-cape-verde-tree-163279042.jpg"
#   }
#   best_guess_labels {
#     label: "horse and buggy"
#   }
# }

# %% [markdown]
# 1. How shall we deal with homonyms and synonyms in the search? (For this project we can deal with exact matches.)
# 2. In the text detection the API returns bounding boxes for individual letters as well. Should we consider them? (For this project we can only consider words and leave letters and symbols, we cannot do this explicitly, so for that we will use only text annotations by API and ignore full text annotations)
# 3. The API detects only a limited number of languages that too if they are very clear. Otherwise it returns ASCII characters. How shall we deal with them both while creating the database and while searching? (For this project we can only take English responses from the API because anyways other tags like labels and objects are only in English).
# 4. Some vertices are normalised, while some are not. How shall we deal with this?
