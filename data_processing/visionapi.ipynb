# %% [markdown]
# # Demo Notebook for using Google Vision API
#
# In this notebook we explore the google vision API and try its various methods

# %% [markdown]
# ## Installing the client library
#
# If the Google cloud vision library is not installed already, install it.
#
# If you have python environment use
#
# ```shell
# pip install --upgrade google-cloud-vision
# ```
#
# If you have conda environment use
#
# ```shell
# conda install -c conda-forge google-cloud-vision
# ```

# %% [markdown]
# ## Import the standard libraries

# %%
import os, io

# %% [markdown]
# ## Import Vison API related libraries

# %%
from google.cloud import vision
from google.cloud.vision import types

# %% [markdown]
# # Setup the service account credentials to use the API

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'F:\EPFL\1st Year\Sem 1\DH_405_Foundation_of_Digital_Humanities\Project\My Project-1c871315ad69.json'

# %% [markdown]
# # Creation of Client to access the API

# %%
client = vision.ImageAnnotatorClient()

# %% [markdown]
# In the next cell, we print to see the methods available with the Image Annotator client.
# Those of our interest are 'annotate_image', 'document_text_detection','face_detection', 'image_properties','label_detection', 'landmark_detection', 'logo_detection', 'object_localization', 'product_search', 'safe_search_detection', 'text_detection', 'transport', 'web_detection'

# %%
dir(client)
# Out:
# ['SERVICE_ADDRESS',
#  '_INTERFACE_NAME',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_client_info',
#  '_get_all_features',
#  '_inner_api_calls',
#  '_method_configs',
#  'annotate_image',
#  'async_batch_annotate_files',
#  'async_batch_annotate_images',
#  'batch_annotate_files',
#  'batch_annotate_images',
#  'crop_hints',
#  'document_text_detection',
#  'enums',
#  'face_detection',
#  'from_service_account_file',
#  'from_service_account_json',
#  'image_properties',
#  'label_detection',
#  'landmark_detection',
#  'logo_detection',
#  'object_localization',
#  'product_search',
#  'safe_search_detection',
#  'text_detection',
#  'transport',
#  'web_detection']

# %% [markdown]
# # Detecting Text

# %% [markdown]
# Let's get an image from one the Terzani pictures.
# image url = http://dl.cini.it/files/original/cb46e00d902f9936224ca6ef81834a35.jpg

# %% [markdown]
# ### Displaying the image

# %%
from IPython.display import Image
from IPython.core.display import HTML
img_url = "http://dl.cini.it/files/original/cb46e00d902f9936224ca6ef81834a35.jpg"
Image(url= img_url)
# Out:
# <img src="http://dl.cini.it/files/original/cb46e00d902f9936224ca6ef81834a35.jpg"/>

# %% [markdown]
# ## Test with an image from URL

# %%
img_url = "http://dl.cini.it:8080/digilib/Scaler/IIIF/cb46e00d902f9936224ca6ef81834a35/full/max/0/default.jpg"
image = vision.types.Image()
image.source.image_uri = img_url

# %% [markdown]
# ### Text Detection

# %%
response = client.text_detection(image=image)
response
# Out:
# text_annotations {
#   locale: "en"
#   description: "CRUSH ALL DESTRUCTIVE ELEMENTS.\nshdevyy Fhogfnfenrs GhH91-114\n"
#   bounding_poly {
#     vertices {
#       x: 378
#       y: 617
#     }
#     vertices {
#       x: 1640
#       y: 617
#     }
#     vertices {
#       x: 1640
#       y: 693
#     }
#     vertices {
#       x: 378
#       y: 693
#     }
#   }
# }
# text_annotations {
#   description: "CRUSH"
#   bounding_poly {
#     vertices {
#       x: 1168
#       y: 620
#     }
#     vertices {
#       x: 1244
#       y: 620
#     }
#     vertices {
#       x: 1244
#       y: 639
#     }
#     vertices {
#       x: 1168
#       y: 639
#     }
#   }
# }
# text_annotations {
#   description: "ALL"
#   bounding_poly {
#     vertices {
#       x: 1264
#       y: 620
#     }
#     vertices {
#       x: 1306
#       y: 620
#     }
#     vertices {
#       x: 1306
#       y: 638
#     }
#     vertices {
#       x: 1264
#       y: 638
#     }
#   }
# }
# text_annotations {
#   description: "DESTRUCTIVE"
#   bounding_poly {
#     vertices {
#       x: 1327
#       y: 618
#     }
#     vertices {
#       x: 1487
#       y: 618
#     }
#     vertices {
#       x: 1487
#       y: 639
#     }
#     vertices {
#       x: 1327
#       y: 639
#     }
#   }
# }
# text_annotations {
#   description: "ELEMENTS."
#   bounding_poly {
#     vertices {
#       x: 1505
#       y: 617
#     }
#     vertices {
#       x: 1640
#       y: 617
#     }
#     vertices {
#       x: 1640
#       y: 638
#     }
#     vertices {
#       x: 1505
#       y: 638
#     }
#   }
# }
# text_annotations {
#   description: "shdevyy"
#   bounding_poly {
#     vertices {
#       x: 378
#       y: 671
#     }
#     vertices {
#       x: 427
#       y: 672
#     }
#     vertices {
#       x: 427
#       y: 687
#     }
#     vertices {
#       x: 378
#       y: 686
#     }
#   }
# }
# text_annotations {
#   description: "Fhogfnfenrs"
#   bounding_poly {
#     vertices {
#       x: 432
#       y: 671
#     }
#     vertices {
#       x: 496
#       y: 672
#     }
#     vertices {
#       x: 496
#       y: 689
#     }
#     vertices {
#       x: 432
#       y: 688
#     }
#   }
# }
# text_annotations {
#   description: "GhH91-114"
#   bounding_poly {
#     vertices {
#       x: 501
#       y: 672
#     }
#     vertices {
#       x: 586
#       y: 673
#     }
#     vertices {
#       x: 586
#       y: 693
#     }
#     vertices {
#       x: 501
#       y: 692
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "en"
#         confidence: 1.0
#       }
#     }
#     width: 1943
#     height: 1458
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 1168
#           y: 617
#         }
#         vertices {
#           x: 1640
#           y: 617
#         }
#         vertices {
#           x: 1640
#           y: 639
#         }
#         vertices {
#           x: 1168
#           y: 639
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 1168
#             y: 617
#           }
#           vertices {
#             x: 1640
#             y: 617
#           }
#           vertices {
#             x: 1640
#             y: 639
#           }
#           vertices {
#             x: 1168
#             y: 639
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1168
#               y: 620
#             }
#             vertices {
#               x: 1244
#               y: 620
#             }
#             vertices {
#               x: 1244
#               y: 639
#             }
#             vertices {
#               x: 1168
#               y: 639
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1168
#                 y: 620
#               }
#               vertices {
#                 x: 1193
#                 y: 620
#               }
#               vertices {
#                 x: 1193
#                 y: 639
#               }
#               vertices {
#                 x: 1168
#                 y: 639
#               }
#             }
#             text: "C"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1194
#                 y: 620
#               }
#               vertices {
#                 x: 1204
#                 y: 620
#               }
#               vertices {
#                 x: 1204
#                 y: 639
#               }
#               vertices {
#                 x: 1194
#                 y: 639
#               }
#             }
#             text: "R"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1205
#                 y: 620
#               }
#               vertices {
#                 x: 1225
#                 y: 620
#               }
#               vertices {
#                 x: 1225
#                 y: 639
#               }
#               vertices {
#                 x: 1205
#                 y: 639
#               }
#             }
#             text: "U"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1226
#                 y: 620
#               }
#               vertices {
#                 x: 1236
#                 y: 620
#               }
#               vertices {
#                 x: 1236
#                 y: 639
#               }
#               vertices {
#                 x: 1226
#                 y: 639
#               }
#             }
#             text: "S"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1237
#                 y: 620
#               }
#               vertices {
#                 x: 1244
#                 y: 620
#               }
#               vertices {
#                 x: 1244
#                 y: 639
#               }
#               vertices {
#                 x: 1237
#                 y: 639
#               }
#             }
#             text: "H"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1264
#               y: 620
#             }
#             vertices {
#               x: 1306
#               y: 620
#             }
#             vertices {
#               x: 1306
#               y: 638
#             }
#             vertices {
#               x: 1264
#               y: 638
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1264
#                 y: 620
#               }
#               vertices {
#                 x: 1275
#                 y: 620
#               }
#               vertices {
#                 x: 1275
#                 y: 638
#               }
#               vertices {
#                 x: 1264
#                 y: 638
#               }
#             }
#             text: "A"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1279
#                 y: 620
#               }
#               vertices {
#                 x: 1291
#                 y: 620
#               }
#               vertices {
#                 x: 1291
#                 y: 638
#               }
#               vertices {
#                 x: 1279
#                 y: 638
#               }
#             }
#             text: "L"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1294
#                 y: 620
#               }
#               vertices {
#                 x: 1306
#                 y: 620
#               }
#               vertices {
#                 x: 1306
#                 y: 638
#               }
#               vertices {
#                 x: 1294
#                 y: 638
#               }
#             }
#             text: "L"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1327
#               y: 618
#             }
#             vertices {
#               x: 1487
#               y: 618
#             }
#             vertices {
#               x: 1487
#               y: 639
#             }
#             vertices {
#               x: 1327
#               y: 639
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1327
#                 y: 618
#               }
#               vertices {
#                 x: 1348
#                 y: 618
#               }
#               vertices {
#                 x: 1348
#                 y: 639
#               }
#               vertices {
#                 x: 1327
#                 y: 639
#               }
#             }
#             text: "D"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1349
#                 y: 618
#               }
#               vertices {
#                 x: 1353
#                 y: 618
#               }
#               vertices {
#                 x: 1353
#                 y: 639
#               }
#               vertices {
#                 x: 1349
#                 y: 639
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1354
#                 y: 618
#               }
#               vertices {
#                 x: 1375
#                 y: 618
#               }
#               vertices {
#                 x: 1375
#                 y: 639
#               }
#               vertices {
#                 x: 1354
#                 y: 639
#               }
#             }
#             text: "S"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1376
#                 y: 618
#               }
#               vertices {
#                 x: 1391
#                 y: 618
#               }
#               vertices {
#                 x: 1391
#                 y: 639
#               }
#               vertices {
#                 x: 1376
#                 y: 639
#               }
#             }
#             text: "T"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1392
#                 y: 618
#               }
#               vertices {
#                 x: 1407
#                 y: 618
#               }
#               vertices {
#                 x: 1407
#                 y: 639
#               }
#               vertices {
#                 x: 1392
#                 y: 639
#               }
#             }
#             text: "R"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1408
#                 y: 618
#               }
#               vertices {
#                 x: 1423
#                 y: 618
#               }
#               vertices {
#                 x: 1423
#                 y: 639
#               }
#               vertices {
#                 x: 1408
#                 y: 639
#               }
#             }
#             text: "U"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1424
#                 y: 618
#               }
#               vertices {
#                 x: 1439
#                 y: 618
#               }
#               vertices {
#                 x: 1439
#                 y: 639
#               }
#               vertices {
#                 x: 1424
#                 y: 639
#               }
#             }
#             text: "C"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1440
#                 y: 618
#               }
#               vertices {
#                 x: 1449
#                 y: 618
#               }
#               vertices {
#                 x: 1449
#                 y: 639
#               }
#               vertices {
#                 x: 1440
#                 y: 639
#               }
#             }
#             text: "T"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1450
#                 y: 618
#               }
#               vertices {
#                 x: 1465
#                 y: 618
#               }
#               vertices {
#                 x: 1465
#                 y: 639
#               }
#               vertices {
#                 x: 1450
#                 y: 639
#               }
#             }
#             text: "I"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1466
#                 y: 618
#               }
#               vertices {
#                 x: 1476
#                 y: 618
#               }
#               vertices {
#                 x: 1476
#                 y: 639
#               }
#               vertices {
#                 x: 1466
#                 y: 639
#               }
#             }
#             text: "V"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1477
#                 y: 618
#               }
#               vertices {
#                 x: 1487
#                 y: 618
#               }
#               vertices {
#                 x: 1487
#                 y: 639
#               }
#               vertices {
#                 x: 1477
#                 y: 639
#               }
#             }
#             text: "E"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1505
#               y: 617
#             }
#             vertices {
#               x: 1640
#               y: 617
#             }
#             vertices {
#               x: 1640
#               y: 638
#             }
#             vertices {
#               x: 1505
#               y: 638
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1505
#                 y: 617
#               }
#               vertices {
#                 x: 1524
#                 y: 617
#               }
#               vertices {
#                 x: 1524
#                 y: 638
#               }
#               vertices {
#                 x: 1505
#                 y: 638
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1525
#                 y: 617
#               }
#               vertices {
#                 x: 1540
#                 y: 617
#               }
#               vertices {
#                 x: 1540
#                 y: 638
#               }
#               vertices {
#                 x: 1525
#                 y: 638
#               }
#             }
#             text: "L"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1541
#                 y: 617
#               }
#               vertices {
#                 x: 1551
#                 y: 617
#               }
#               vertices {
#                 x: 1551
#                 y: 638
#               }
#               vertices {
#                 x: 1541
#                 y: 638
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1552
#                 y: 617
#               }
#               vertices {
#                 x: 1577
#                 y: 617
#               }
#               vertices {
#                 x: 1577
#                 y: 638
#               }
#               vertices {
#                 x: 1552
#                 y: 638
#               }
#             }
#             text: "M"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1578
#                 y: 617
#               }
#               vertices {
#                 x: 1588
#                 y: 617
#               }
#               vertices {
#                 x: 1588
#                 y: 638
#               }
#               vertices {
#                 x: 1578
#                 y: 638
#               }
#             }
#             text: "E"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1589
#                 y: 617
#               }
#               vertices {
#                 x: 1609
#                 y: 617
#               }
#               vertices {
#                 x: 1609
#                 y: 638
#               }
#               vertices {
#                 x: 1589
#                 y: 638
#               }
#             }
#             text: "N"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1610
#                 y: 617
#               }
#               vertices {
#                 x: 1620
#                 y: 617
#               }
#               vertices {
#                 x: 1620
#                 y: 638
#               }
#               vertices {
#                 x: 1610
#                 y: 638
#               }
#             }
#             text: "T"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1621
#                 y: 617
#               }
#               vertices {
#                 x: 1631
#                 y: 617
#               }
#               vertices {
#                 x: 1631
#                 y: 638
#               }
#               vertices {
#                 x: 1621
#                 y: 638
#               }
#             }
#             text: "S"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1632
#                 y: 617
#               }
#               vertices {
#                 x: 1640
#                 y: 617
#               }
#               vertices {
#                 x: 1640
#                 y: 638
#               }
#               vertices {
#                 x: 1632
#                 y: 638
#               }
#             }
#             text: "."
#           }
#         }
#       }
#       block_type: TEXT
#     }
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 378
#           y: 670
#         }
#         vertices {
#           x: 586
#           y: 672
#         }
#         vertices {
#           x: 586
#           y: 693
#         }
#         vertices {
#           x: 378
#           y: 691
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 378
#             y: 670
#           }
#           vertices {
#             x: 586
#             y: 672
#           }
#           vertices {
#             x: 586
#             y: 693
#           }
#           vertices {
#             x: 378
#             y: 691
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 378
#               y: 671
#             }
#             vertices {
#               x: 427
#               y: 672
#             }
#             vertices {
#               x: 427
#               y: 687
#             }
#             vertices {
#               x: 378
#               y: 686
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 378
#                 y: 671
#               }
#               vertices {
#                 x: 397
#                 y: 671
#               }
#               vertices {
#                 x: 397
#                 y: 686
#               }
#               vertices {
#                 x: 378
#                 y: 686
#               }
#             }
#             text: "s"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 398
#                 y: 671
#               }
#               vertices {
#                 x: 401
#                 y: 671
#               }
#               vertices {
#                 x: 401
#                 y: 686
#               }
#               vertices {
#                 x: 398
#                 y: 686
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 402
#                 y: 671
#               }
#               vertices {
#                 x: 405
#                 y: 671
#               }
#               vertices {
#                 x: 405
#                 y: 686
#               }
#               vertices {
#                 x: 402
#                 y: 686
#               }
#             }
#             text: "d"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 406
#                 y: 671
#               }
#               vertices {
#                 x: 409
#                 y: 671
#               }
#               vertices {
#                 x: 409
#                 y: 686
#               }
#               vertices {
#                 x: 406
#                 y: 686
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 410
#                 y: 671
#               }
#               vertices {
#                 x: 413
#                 y: 671
#               }
#               vertices {
#                 x: 413
#                 y: 686
#               }
#               vertices {
#                 x: 410
#                 y: 686
#               }
#             }
#             text: "v"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 414
#                 y: 671
#               }
#               vertices {
#                 x: 424
#                 y: 671
#               }
#               vertices {
#                 x: 424
#                 y: 686
#               }
#               vertices {
#                 x: 414
#                 y: 686
#               }
#             }
#             text: "y"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 425
#                 y: 672
#               }
#               vertices {
#                 x: 427
#                 y: 672
#               }
#               vertices {
#                 x: 427
#                 y: 687
#               }
#               vertices {
#                 x: 425
#                 y: 687
#               }
#             }
#             text: "y"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 432
#               y: 671
#             }
#             vertices {
#               x: 496
#               y: 672
#             }
#             vertices {
#               x: 496
#               y: 689
#             }
#             vertices {
#               x: 432
#               y: 688
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 432
#                 y: 672
#               }
#               vertices {
#                 x: 443
#                 y: 672
#               }
#               vertices {
#                 x: 443
#                 y: 688
#               }
#               vertices {
#                 x: 432
#                 y: 688
#               }
#             }
#             text: "F"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 444
#                 y: 672
#               }
#               vertices {
#                 x: 447
#                 y: 672
#               }
#               vertices {
#                 x: 447
#                 y: 688
#               }
#               vertices {
#                 x: 444
#                 y: 688
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 448
#                 y: 672
#               }
#               vertices {
#                 x: 451
#                 y: 672
#               }
#               vertices {
#                 x: 451
#                 y: 688
#               }
#               vertices {
#                 x: 448
#                 y: 688
#               }
#             }
#             text: "o"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 452
#                 y: 672
#               }
#               vertices {
#                 x: 455
#                 y: 672
#               }
#               vertices {
#                 x: 455
#                 y: 688
#               }
#               vertices {
#                 x: 452
#                 y: 688
#               }
#             }
#             text: "g"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 456
#                 y: 672
#               }
#               vertices {
#                 x: 463
#                 y: 672
#               }
#               vertices {
#                 x: 463
#                 y: 688
#               }
#               vertices {
#                 x: 456
#                 y: 688
#               }
#             }
#             text: "f"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 464
#                 y: 672
#               }
#               vertices {
#                 x: 474
#                 y: 672
#               }
#               vertices {
#                 x: 474
#                 y: 688
#               }
#               vertices {
#                 x: 464
#                 y: 688
#               }
#             }
#             text: "n"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 475
#                 y: 672
#               }
#               vertices {
#                 x: 482
#                 y: 672
#               }
#               vertices {
#                 x: 482
#                 y: 688
#               }
#               vertices {
#                 x: 475
#                 y: 688
#               }
#             }
#             text: "f"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 483
#                 y: 672
#               }
#               vertices {
#                 x: 486
#                 y: 672
#               }
#               vertices {
#                 x: 486
#                 y: 688
#               }
#               vertices {
#                 x: 483
#                 y: 688
#               }
#             }
#             text: "e"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 487
#                 y: 672
#               }
#               vertices {
#                 x: 489
#                 y: 672
#               }
#               vertices {
#                 x: 489
#                 y: 688
#               }
#               vertices {
#                 x: 487
#                 y: 688
#               }
#             }
#             text: "n"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 490
#                 y: 672
#               }
#               vertices {
#                 x: 493
#                 y: 672
#               }
#               vertices {
#                 x: 493
#                 y: 688
#               }
#               vertices {
#                 x: 490
#                 y: 688
#               }
#             }
#             text: "r"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 494
#                 y: 672
#               }
#               vertices {
#                 x: 496
#                 y: 672
#               }
#               vertices {
#                 x: 496
#                 y: 688
#               }
#               vertices {
#                 x: 494
#                 y: 688
#               }
#             }
#             text: "s"
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 501
#               y: 672
#             }
#             vertices {
#               x: 586
#               y: 673
#             }
#             vertices {
#               x: 586
#               y: 693
#             }
#             vertices {
#               x: 501
#               y: 692
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 501
#                 y: 672
#               }
#               vertices {
#                 x: 509
#                 y: 672
#               }
#               vertices {
#                 x: 509
#                 y: 691
#               }
#               vertices {
#                 x: 501
#                 y: 691
#               }
#             }
#             text: "G"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 510
#                 y: 673
#               }
#               vertices {
#                 x: 512
#                 y: 673
#               }
#               vertices {
#                 x: 512
#                 y: 692
#               }
#               vertices {
#                 x: 510
#                 y: 692
#               }
#             }
#             text: "h"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 513
#                 y: 673
#               }
#               vertices {
#                 x: 516
#                 y: 673
#               }
#               vertices {
#                 x: 516
#                 y: 692
#               }
#               vertices {
#                 x: 513
#                 y: 692
#               }
#             }
#             text: "H"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 517
#                 y: 673
#               }
#               vertices {
#                 x: 532
#                 y: 673
#               }
#               vertices {
#                 x: 532
#                 y: 692
#               }
#               vertices {
#                 x: 517
#                 y: 692
#               }
#             }
#             text: "9"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 533
#                 y: 673
#               }
#               vertices {
#                 x: 539
#                 y: 673
#               }
#               vertices {
#                 x: 539
#                 y: 692
#               }
#               vertices {
#                 x: 533
#                 y: 692
#               }
#             }
#             text: "1"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 540
#                 y: 673
#               }
#               vertices {
#                 x: 551
#                 y: 673
#               }
#               vertices {
#                 x: 551
#                 y: 692
#               }
#               vertices {
#                 x: 540
#                 y: 692
#               }
#             }
#             text: "-"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 552
#                 y: 673
#               }
#               vertices {
#                 x: 558
#                 y: 673
#               }
#               vertices {
#                 x: 558
#                 y: 692
#               }
#               vertices {
#                 x: 552
#                 y: 692
#               }
#             }
#             text: "1"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 559
#                 y: 673
#               }
#               vertices {
#                 x: 578
#                 y: 673
#               }
#               vertices {
#                 x: 578
#                 y: 692
#               }
#               vertices {
#                 x: 559
#                 y: 692
#               }
#             }
#             text: "1"
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 579
#                 y: 673
#               }
#               vertices {
#                 x: 586
#                 y: 673
#               }
#               vertices {
#                 x: 586
#                 y: 692
#               }
#               vertices {
#                 x: 579
#                 y: 692
#               }
#             }
#             text: "4"
#           }
#         }
#       }
#       block_type: TEXT
#     }
#   }
#   text: "CRUSH ALL DESTRUCTIVE ELEMENTS.\nshdevyy Fhogfnfenrs GhH91-114\n"
# }

# %% [markdown]
# ### Handwriting detection

# %%
response = client.document_text_detection(image=image)
response
# Out:
# text_annotations {
#   locale: "en"
#   description: "\341\200\241\341\200\226\341\200\273\341\200\200\341\200\272\341\200\236\341\200\231\341\200\254\341\200\270\341\200\200\341\200\255\341\200\257\341\200\201\341\200\273\341\200\261\341\200\231\341\200\276\341\200\257\341\200\224\341\200\272\341\200\270\341\200\200\341\200\274\nCRUSH ALL DESTRUCTIVE ELEMENTS.\n"
#   bounding_poly {
#     vertices {
#       x: 1167
#       y: 540
#     }
#     vertices {
#       x: 1640
#       y: 540
#     }
#     vertices {
#       x: 1640
#       y: 645
#     }
#     vertices {
#       x: 1167
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "\341\200\241\341\200\226\341\200\273\341\200\200\341\200\272\341\200\236\341\200\231\341\200\254\341\200\270"
#   bounding_poly {
#     vertices {
#       x: 1167
#       y: 543
#     }
#     vertices {
#       x: 1383
#       y: 541
#     }
#     vertices {
#       x: 1383
#       y: 608
#     }
#     vertices {
#       x: 1167
#       y: 610
#     }
#   }
# }
# text_annotations {
#   description: "\341\200\200\341\200\255\341\200\257"
#   bounding_poly {
#     vertices {
#       x: 1421
#       y: 542
#     }
#     vertices {
#       x: 1438
#       y: 542
#     }
#     vertices {
#       x: 1438
#       y: 608
#     }
#     vertices {
#       x: 1421
#       y: 608
#     }
#   }
# }
# text_annotations {
#   description: "\341\200\201\341\200\273\341\200\261\341\200\231\341\200\276\341\200\257\341\200\224\341\200\272\341\200\270"
#   bounding_poly {
#     vertices {
#       x: 1483
#       y: 541
#     }
#     vertices {
#       x: 1565
#       y: 540
#     }
#     vertices {
#       x: 1565
#       y: 606
#     }
#     vertices {
#       x: 1483
#       y: 607
#     }
#   }
# }
# text_annotations {
#   description: "\341\200\200\341\200\274"
#   bounding_poly {
#     vertices {
#       x: 1619
#       y: 540
#     }
#     vertices {
#       x: 1636
#       y: 540
#     }
#     vertices {
#       x: 1636
#       y: 606
#     }
#     vertices {
#       x: 1619
#       y: 606
#     }
#   }
# }
# text_annotations {
#   description: "CRUSH"
#   bounding_poly {
#     vertices {
#       x: 1168
#       y: 613
#     }
#     vertices {
#       x: 1244
#       y: 613
#     }
#     vertices {
#       x: 1244
#       y: 645
#     }
#     vertices {
#       x: 1168
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "ALL"
#   bounding_poly {
#     vertices {
#       x: 1263
#       y: 613
#     }
#     vertices {
#       x: 1307
#       y: 613
#     }
#     vertices {
#       x: 1307
#       y: 645
#     }
#     vertices {
#       x: 1263
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "DESTRUCTIVE"
#   bounding_poly {
#     vertices {
#       x: 1327
#       y: 613
#     }
#     vertices {
#       x: 1487
#       y: 613
#     }
#     vertices {
#       x: 1487
#       y: 645
#     }
#     vertices {
#       x: 1327
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "ELEMENTS"
#   bounding_poly {
#     vertices {
#       x: 1505
#       y: 613
#     }
#     vertices {
#       x: 1631
#       y: 613
#     }
#     vertices {
#       x: 1631
#       y: 645
#     }
#     vertices {
#       x: 1505
#       y: 645
#     }
#   }
# }
# text_annotations {
#   description: "."
#   bounding_poly {
#     vertices {
#       x: 1635
#       y: 613
#     }
#     vertices {
#       x: 1640
#       y: 613
#     }
#     vertices {
#       x: 1640
#       y: 645
#     }
#     vertices {
#       x: 1635
#       y: 645
#     }
#   }
# }
# full_text_annotation {
#   pages {
#     property {
#       detected_languages {
#         language_code: "en"
#         confidence: 0.55
#       }
#       detected_languages {
#         language_code: "my"
#         confidence: 0.45
#       }
#     }
#     width: 1943
#     height: 1458
#     blocks {
#       property {
#         detected_languages {
#           language_code: "my"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 1167
#           y: 543
#         }
#         vertices {
#           x: 1636
#           y: 540
#         }
#         vertices {
#           x: 1636
#           y: 607
#         }
#         vertices {
#           x: 1167
#           y: 610
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "my"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 1167
#             y: 543
#           }
#           vertices {
#             x: 1636
#             y: 540
#           }
#           vertices {
#             x: 1636
#             y: 607
#           }
#           vertices {
#             x: 1167
#             y: 610
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "my"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1167
#               y: 543
#             }
#             vertices {
#               x: 1383
#               y: 541
#             }
#             vertices {
#               x: 1383
#               y: 608
#             }
#             vertices {
#               x: 1167
#               y: 610
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1167
#                 y: 543
#               }
#               vertices {
#                 x: 1209
#                 y: 543
#               }
#               vertices {
#                 x: 1209
#                 y: 609
#               }
#               vertices {
#                 x: 1167
#                 y: 609
#               }
#             }
#             text: "\341\200\241"
#             confidence: 0.8
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1214
#                 y: 543
#               }
#               vertices {
#                 x: 1242
#                 y: 543
#               }
#               vertices {
#                 x: 1242
#                 y: 609
#               }
#               vertices {
#                 x: 1214
#                 y: 609
#               }
#             }
#             text: "\341\200\226"
#             confidence: 0.68
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1214
#                 y: 543
#               }
#               vertices {
#                 x: 1242
#                 y: 543
#               }
#               vertices {
#                 x: 1242
#                 y: 609
#               }
#               vertices {
#                 x: 1214
#                 y: 609
#               }
#             }
#             text: "\341\200\273"
#             confidence: 0.68
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1259
#                 y: 543
#               }
#               vertices {
#                 x: 1291
#                 y: 543
#               }
#               vertices {
#                 x: 1291
#                 y: 609
#               }
#               vertices {
#                 x: 1259
#                 y: 609
#               }
#             }
#             text: "\341\200\200"
#             confidence: 0.92
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1259
#                 y: 543
#               }
#               vertices {
#                 x: 1291
#                 y: 543
#               }
#               vertices {
#                 x: 1291
#                 y: 609
#               }
#               vertices {
#                 x: 1259
#                 y: 609
#               }
#             }
#             text: "\341\200\272"
#             confidence: 0.92
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1306
#                 y: 542
#               }
#               vertices {
#                 x: 1338
#                 y: 542
#               }
#               vertices {
#                 x: 1338
#                 y: 608
#               }
#               vertices {
#                 x: 1306
#                 y: 608
#               }
#             }
#             text: "\341\200\236"
#             confidence: 0.91
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1355
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 608
#               }
#               vertices {
#                 x: 1355
#                 y: 608
#               }
#             }
#             text: "\341\200\231"
#             confidence: 0.93
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1355
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 608
#               }
#               vertices {
#                 x: 1355
#                 y: 608
#               }
#             }
#             text: "\341\200\254"
#             confidence: 0.93
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1355
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 542
#               }
#               vertices {
#                 x: 1383
#                 y: 608
#               }
#               vertices {
#                 x: 1355
#                 y: 608
#               }
#             }
#             text: "\341\200\270"
#             confidence: 0.93
#           }
#           confidence: 0.85
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "my"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1421
#               y: 542
#             }
#             vertices {
#               x: 1438
#               y: 542
#             }
#             vertices {
#               x: 1438
#               y: 608
#             }
#             vertices {
#               x: 1421
#               y: 608
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1421
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 608
#               }
#               vertices {
#                 x: 1421
#                 y: 608
#               }
#             }
#             text: "\341\200\200"
#             confidence: 0.75
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1421
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 608
#               }
#               vertices {
#                 x: 1421
#                 y: 608
#               }
#             }
#             text: "\341\200\255"
#             confidence: 0.75
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1421
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 542
#               }
#               vertices {
#                 x: 1438
#                 y: 608
#               }
#               vertices {
#                 x: 1421
#                 y: 608
#               }
#             }
#             text: "\341\200\257"
#             confidence: 0.75
#           }
#           confidence: 0.75
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "my"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1483
#               y: 541
#             }
#             vertices {
#               x: 1565
#               y: 540
#             }
#             vertices {
#               x: 1565
#               y: 606
#             }
#             vertices {
#               x: 1483
#               y: 607
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1483
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 607
#               }
#               vertices {
#                 x: 1483
#                 y: 607
#               }
#             }
#             text: "\341\200\201"
#             confidence: 0.69
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1483
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 607
#               }
#               vertices {
#                 x: 1483
#                 y: 607
#               }
#             }
#             text: "\341\200\273"
#             confidence: 0.69
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1483
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 541
#               }
#               vertices {
#                 x: 1510
#                 y: 607
#               }
#               vertices {
#                 x: 1483
#                 y: 607
#               }
#             }
#             text: "\341\200\261"
#             confidence: 0.69
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1520
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 607
#               }
#               vertices {
#                 x: 1520
#                 y: 607
#               }
#             }
#             text: "\341\200\231"
#             confidence: 0.13
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1520
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 607
#               }
#               vertices {
#                 x: 1520
#                 y: 607
#               }
#             }
#             text: "\341\200\276"
#             confidence: 0.13
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1520
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 541
#               }
#               vertices {
#                 x: 1540
#                 y: 607
#               }
#               vertices {
#                 x: 1520
#                 y: 607
#               }
#             }
#             text: "\341\200\257"
#             confidence: 0.13
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1549
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 607
#               }
#               vertices {
#                 x: 1549
#                 y: 607
#               }
#             }
#             text: "\341\200\224"
#             confidence: 0.8
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1549
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 607
#               }
#               vertices {
#                 x: 1549
#                 y: 607
#               }
#             }
#             text: "\341\200\272"
#             confidence: 0.8
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1549
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 541
#               }
#               vertices {
#                 x: 1565
#                 y: 607
#               }
#               vertices {
#                 x: 1549
#                 y: 607
#               }
#             }
#             text: "\341\200\270"
#             confidence: 0.8
#           }
#           confidence: 0.54
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "my"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1619
#               y: 540
#             }
#             vertices {
#               x: 1636
#               y: 540
#             }
#             vertices {
#               x: 1636
#               y: 606
#             }
#             vertices {
#               x: 1619
#               y: 606
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1619
#                 y: 540
#               }
#               vertices {
#                 x: 1636
#                 y: 540
#               }
#               vertices {
#                 x: 1636
#                 y: 606
#               }
#               vertices {
#                 x: 1619
#                 y: 606
#               }
#             }
#             text: "\341\200\200"
#             confidence: 0.73
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "my"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1619
#                 y: 540
#               }
#               vertices {
#                 x: 1636
#                 y: 540
#               }
#               vertices {
#                 x: 1636
#                 y: 606
#               }
#               vertices {
#                 x: 1619
#                 y: 606
#               }
#             }
#             text: "\341\200\274"
#             confidence: 0.73
#           }
#           confidence: 0.73
#         }
#         confidence: 0.7
#       }
#       block_type: TEXT
#       confidence: 0.7
#     }
#     blocks {
#       property {
#         detected_languages {
#           language_code: "en"
#           confidence: 1.0
#         }
#       }
#       bounding_box {
#         vertices {
#           x: 1168
#           y: 613
#         }
#         vertices {
#           x: 1640
#           y: 613
#         }
#         vertices {
#           x: 1640
#           y: 645
#         }
#         vertices {
#           x: 1168
#           y: 645
#         }
#       }
#       paragraphs {
#         property {
#           detected_languages {
#             language_code: "en"
#             confidence: 1.0
#           }
#         }
#         bounding_box {
#           vertices {
#             x: 1168
#             y: 613
#           }
#           vertices {
#             x: 1640
#             y: 613
#           }
#           vertices {
#             x: 1640
#             y: 645
#           }
#           vertices {
#             x: 1168
#             y: 645
#           }
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1168
#               y: 613
#             }
#             vertices {
#               x: 1244
#               y: 613
#             }
#             vertices {
#               x: 1244
#               y: 645
#             }
#             vertices {
#               x: 1168
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1168
#                 y: 613
#               }
#               vertices {
#                 x: 1181
#                 y: 613
#               }
#               vertices {
#                 x: 1181
#                 y: 645
#               }
#               vertices {
#                 x: 1168
#                 y: 645
#               }
#             }
#             text: "C"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1184
#                 y: 613
#               }
#               vertices {
#                 x: 1194
#                 y: 613
#               }
#               vertices {
#                 x: 1194
#                 y: 645
#               }
#               vertices {
#                 x: 1184
#                 y: 645
#               }
#             }
#             text: "R"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1199
#                 y: 613
#               }
#               vertices {
#                 x: 1211
#                 y: 613
#               }
#               vertices {
#                 x: 1211
#                 y: 645
#               }
#               vertices {
#                 x: 1199
#                 y: 645
#               }
#             }
#             text: "U"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1217
#                 y: 613
#               }
#               vertices {
#                 x: 1227
#                 y: 613
#               }
#               vertices {
#                 x: 1227
#                 y: 645
#               }
#               vertices {
#                 x: 1217
#                 y: 645
#               }
#             }
#             text: "S"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1232
#                 y: 613
#               }
#               vertices {
#                 x: 1244
#                 y: 613
#               }
#               vertices {
#                 x: 1244
#                 y: 645
#               }
#               vertices {
#                 x: 1232
#                 y: 645
#               }
#             }
#             text: "H"
#             confidence: 0.99
#           }
#           confidence: 0.99
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1263
#               y: 613
#             }
#             vertices {
#               x: 1307
#               y: 613
#             }
#             vertices {
#               x: 1307
#               y: 645
#             }
#             vertices {
#               x: 1263
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1263
#                 y: 613
#               }
#               vertices {
#                 x: 1275
#                 y: 613
#               }
#               vertices {
#                 x: 1275
#                 y: 645
#               }
#               vertices {
#                 x: 1263
#                 y: 645
#               }
#             }
#             text: "A"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1279
#                 y: 613
#               }
#               vertices {
#                 x: 1292
#                 y: 613
#               }
#               vertices {
#                 x: 1292
#                 y: 645
#               }
#               vertices {
#                 x: 1279
#                 y: 645
#               }
#             }
#             text: "L"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1294
#                 y: 613
#               }
#               vertices {
#                 x: 1307
#                 y: 613
#               }
#               vertices {
#                 x: 1307
#                 y: 645
#               }
#               vertices {
#                 x: 1294
#                 y: 645
#               }
#             }
#             text: "L"
#             confidence: 0.99
#           }
#           confidence: 0.99
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1327
#               y: 613
#             }
#             vertices {
#               x: 1487
#               y: 613
#             }
#             vertices {
#               x: 1487
#               y: 645
#             }
#             vertices {
#               x: 1327
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1327
#                 y: 613
#               }
#               vertices {
#                 x: 1340
#                 y: 613
#               }
#               vertices {
#                 x: 1340
#                 y: 645
#               }
#               vertices {
#                 x: 1327
#                 y: 645
#               }
#             }
#             text: "D"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1345
#                 y: 613
#               }
#               vertices {
#                 x: 1356
#                 y: 613
#               }
#               vertices {
#                 x: 1356
#                 y: 645
#               }
#               vertices {
#                 x: 1345
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1361
#                 y: 613
#               }
#               vertices {
#                 x: 1372
#                 y: 613
#               }
#               vertices {
#                 x: 1372
#                 y: 645
#               }
#               vertices {
#                 x: 1361
#                 y: 645
#               }
#             }
#             text: "S"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1378
#                 y: 613
#               }
#               vertices {
#                 x: 1389
#                 y: 613
#               }
#               vertices {
#                 x: 1389
#                 y: 645
#               }
#               vertices {
#                 x: 1378
#                 y: 645
#               }
#             }
#             text: "T"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1392
#                 y: 613
#               }
#               vertices {
#                 x: 1402
#                 y: 613
#               }
#               vertices {
#                 x: 1402
#                 y: 645
#               }
#               vertices {
#                 x: 1392
#                 y: 645
#               }
#             }
#             text: "R"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1408
#                 y: 613
#               }
#               vertices {
#                 x: 1418
#                 y: 613
#               }
#               vertices {
#                 x: 1418
#                 y: 645
#               }
#               vertices {
#                 x: 1408
#                 y: 645
#               }
#             }
#             text: "U"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1420
#                 y: 613
#               }
#               vertices {
#                 x: 1432
#                 y: 613
#               }
#               vertices {
#                 x: 1432
#                 y: 645
#               }
#               vertices {
#                 x: 1420
#                 y: 645
#               }
#             }
#             text: "C"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1441
#                 y: 613
#               }
#               vertices {
#                 x: 1451
#                 y: 613
#               }
#               vertices {
#                 x: 1451
#                 y: 645
#               }
#               vertices {
#                 x: 1441
#                 y: 645
#               }
#             }
#             text: "T"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1453
#                 y: 613
#               }
#               vertices {
#                 x: 1459
#                 y: 613
#               }
#               vertices {
#                 x: 1459
#                 y: 645
#               }
#               vertices {
#                 x: 1453
#                 y: 645
#               }
#             }
#             text: "I"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1462
#                 y: 613
#               }
#               vertices {
#                 x: 1470
#                 y: 613
#               }
#               vertices {
#                 x: 1470
#                 y: 645
#               }
#               vertices {
#                 x: 1462
#                 y: 645
#               }
#             }
#             text: "V"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: SPACE
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1475
#                 y: 613
#               }
#               vertices {
#                 x: 1487
#                 y: 613
#               }
#               vertices {
#                 x: 1487
#                 y: 645
#               }
#               vertices {
#                 x: 1475
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 0.99
#           }
#           confidence: 0.99
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1505
#               y: 613
#             }
#             vertices {
#               x: 1631
#               y: 613
#             }
#             vertices {
#               x: 1631
#               y: 645
#             }
#             vertices {
#               x: 1505
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1505
#                 y: 613
#               }
#               vertices {
#                 x: 1521
#                 y: 613
#               }
#               vertices {
#                 x: 1521
#                 y: 645
#               }
#               vertices {
#                 x: 1505
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1524
#                 y: 613
#               }
#               vertices {
#                 x: 1534
#                 y: 613
#               }
#               vertices {
#                 x: 1534
#                 y: 645
#               }
#               vertices {
#                 x: 1524
#                 y: 645
#               }
#             }
#             text: "L"
#             confidence: 0.99
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1539
#                 y: 613
#               }
#               vertices {
#                 x: 1550
#                 y: 613
#               }
#               vertices {
#                 x: 1550
#                 y: 645
#               }
#               vertices {
#                 x: 1539
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1556
#                 y: 613
#               }
#               vertices {
#                 x: 1567
#                 y: 613
#               }
#               vertices {
#                 x: 1567
#                 y: 645
#               }
#               vertices {
#                 x: 1556
#                 y: 645
#               }
#             }
#             text: "M"
#             confidence: 0.31
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1572
#                 y: 613
#               }
#               vertices {
#                 x: 1583
#                 y: 613
#               }
#               vertices {
#                 x: 1583
#                 y: 645
#               }
#               vertices {
#                 x: 1572
#                 y: 645
#               }
#             }
#             text: "E"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1589
#                 y: 613
#               }
#               vertices {
#                 x: 1601
#                 y: 613
#               }
#               vertices {
#                 x: 1601
#                 y: 645
#               }
#               vertices {
#                 x: 1589
#                 y: 645
#               }
#             }
#             text: "N"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1609
#                 y: 613
#               }
#               vertices {
#                 x: 1620
#                 y: 613
#               }
#               vertices {
#                 x: 1620
#                 y: 645
#               }
#               vertices {
#                 x: 1609
#                 y: 645
#               }
#             }
#             text: "T"
#             confidence: 1.0
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1624
#                 y: 613
#               }
#               vertices {
#                 x: 1631
#                 y: 613
#               }
#               vertices {
#                 x: 1631
#                 y: 645
#               }
#               vertices {
#                 x: 1624
#                 y: 645
#               }
#             }
#             text: "S"
#             confidence: 1.0
#           }
#           confidence: 0.91
#         }
#         words {
#           property {
#             detected_languages {
#               language_code: "en"
#             }
#           }
#           bounding_box {
#             vertices {
#               x: 1635
#               y: 613
#             }
#             vertices {
#               x: 1640
#               y: 613
#             }
#             vertices {
#               x: 1640
#               y: 645
#             }
#             vertices {
#               x: 1635
#               y: 645
#             }
#           }
#           symbols {
#             property {
#               detected_languages {
#                 language_code: "en"
#               }
#               detected_break {
#                 type: LINE_BREAK
#               }
#             }
#             bounding_box {
#               vertices {
#                 x: 1635
#                 y: 613
#               }
#               vertices {
#                 x: 1640
#                 y: 613
#               }
#               vertices {
#                 x: 1640
#                 y: 645
#               }
#               vertices {
#                 x: 1635
#                 y: 645
#               }
#             }
#             text: "."
#             confidence: 0.99
#           }
#           confidence: 0.99
#         }
#         confidence: 0.96
#       }
#       block_type: TEXT
#       confidence: 0.96
#     }
#   }
#   text: "\341\200\241\341\200\226\341\200\273\341\200\200\341\200\272\341\200\236\341\200\231\341\200\254\341\200\270\341\200\200\341\200\255\341\200\257\341\200\201\341\200\273\341\200\261\341\200\231\341\200\276\341\200\257\341\200\224\341\200\272\341\200\270\341\200\200\341\200\274\nCRUSH ALL DESTRUCTIVE ELEMENTS.\n"
# }

# %% [markdown]
# ### Face Detection

# %%
response = client.face_detection(image=image)
response
# Out:
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 1366
#       y: 844
#     }
#     vertices {
#       x: 1419
#       y: 844
#     }
#     vertices {
#       x: 1419
#       y: 907
#     }
#     vertices {
#       x: 1366
#       y: 907
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 1369
#       y: 856
#     }
#     vertices {
#       x: 1414
#       y: 856
#     }
#     vertices {
#       x: 1414
#       y: 904
#     }
#     vertices {
#       x: 1369
#       y: 904
#     }
#   }
#   landmarks {
#     type: LEFT_EYE
#     position {
#       x: 1383.7682
#       y: 876.0541
#       z: 0.00077164173
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE
#     position {
#       x: 1400.4846
#       y: 875.84973
#       z: -1.1280377
#     }
#   }
#   landmarks {
#     type: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 1378.9817
#       y: 872.3959
#       z: 1.5049982
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 1388.3671
#       y: 872.22034
#       z: -3.4152558
#     }
#   }
#   landmarks {
#     type: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 1395.211
#       y: 872.258
#       z: -3.9202738
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 1405.0896
#       y: 872.1618
#       z: -0.35125458
#     }
#   }
#   landmarks {
#     type: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 1391.2891
#       y: 876.08795
#       z: -3.6846552
#     }
#   }
#   landmarks {
#     type: NOSE_TIP
#     position {
#       x: 1391.4567
#       y: 884.6634
#       z: -7.565708
#     }
#   }
#   landmarks {
#     type: UPPER_LIP
#     position {
#       x: 1392.295
#       y: 890.22314
#       z: -3.8348942
#     }
#   }
#   landmarks {
#     type: LOWER_LIP
#     position {
#       x: 1392.5277
#       y: 895.89417
#       z: -2.4562943
#     }
#   }
#   landmarks {
#     type: MOUTH_LEFT
#     position {
#       x: 1386.5073
#       y: 892.99146
#       z: 0.6961414
#     }
#   }
#   landmarks {
#     type: MOUTH_RIGHT
#     position {
#       x: 1398.5569
#       y: 893.19226
#       z: -0.17456532
#     }
#   }
#   landmarks {
#     type: MOUTH_CENTER
#     position {
#       x: 1392.2614
#       y: 892.99286
#       z: -2.5690436
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_RIGHT
#     position {
#       x: 1396.5378
#       y: 886.28156
#       z: -2.2674916
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_LEFT
#     position {
#       x: 1388.2273
#       y: 885.868
#       z: -1.5862389
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_CENTER
#     position {
#       x: 1392.2805
#       y: 887.01917
#       z: -4.0705776
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 1383.4221
#       y: 874.6046
#       z: -0.91995823
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 1386.7539
#       y: 876.3487
#       z: -0.20254713
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 1383.5706
#       y: 877.1526
#       z: -0.087403536
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 1380.7445
#       y: 876.0298
#       z: 1.6036997
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 1400.4587
#       y: 874.24347
#       z: -2.0572548
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 1403.8647
#       y: 875.75916
#       z: 0.013937056
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 1400.6036
#       y: 877.0367
#       z: -1.2365999
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 1397.114
#       y: 876.0208
#       z: -0.87408185
#     }
#   }
#   landmarks {
#     type: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 1383.6027
#       y: 870.8637
#       z: -1.9852219
#     }
#   }
#   landmarks {
#     type: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 1399.9415
#       y: 870.7638
#       z: -3.1613727
#     }
#   }
#   landmarks {
#     type: LEFT_EAR_TRAGION
#     position {
#       x: 1373.631
#       y: 878.7644
#       z: 19.81733
#     }
#   }
#   landmarks {
#     type: RIGHT_EAR_TRAGION
#     position {
#       x: 1412.7535
#       y: 880.2934
#       z: 17.195759
#     }
#   }
#   landmarks {
#     type: FOREHEAD_GLABELLA
#     position {
#       x: 1391.1918
#       y: 872.47424
#       z: -4.18414
#     }
#   }
#   landmarks {
#     type: CHIN_GNATHION
#     position {
#       x: 1392.3989
#       y: 903.12366
#       z: 0.12997073
#     }
#   }
#   landmarks {
#     type: CHIN_LEFT_GONION
#     position {
#       x: 1379.2848
#       y: 892.9881
#       z: 14.150047
#     }
#   }
#   landmarks {
#     type: CHIN_RIGHT_GONION
#     position {
#       x: 1407.5853
#       y: 893.5292
#       z: 12.083894
#     }
#   }
#   landmarks {
#     type: 35
#     position {
#       x: 1381.7098
#       y: 886.184
#       z: 2.194952
#     }
#   }
#   landmarks {
#     type: 36
#     position {
#       x: 1403.8212
#       y: 886.02734
#       z: 0.6619288
#     }
#   }
#   roll_angle: -1.3263663
#   pan_angle: -3.9765892
#   tilt_angle: -4.2749214
#   detection_confidence: 0.40316796
#   landmarking_confidence: 0.77891207
#   joy_likelihood: VERY_UNLIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: VERY_UNLIKELY
#   blurred_likelihood: VERY_LIKELY
#   headwear_likelihood: VERY_UNLIKELY
# }
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 1516
#       y: 805
#     }
#     vertices {
#       x: 1562
#       y: 805
#     }
#     vertices {
#       x: 1562
#       y: 859
#     }
#     vertices {
#       x: 1516
#       y: 859
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 1517
#       y: 813
#     }
#     vertices {
#       x: 1557
#       y: 813
#     }
#     vertices {
#       x: 1557
#       y: 855
#     }
#     vertices {
#       x: 1517
#       y: 855
#     }
#   }
#   landmarks {
#     type: LEFT_EYE
#     position {
#       x: 1532.6411
#       y: 829.51685
#       z: 0.00067162514
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE
#     position {
#       x: 1546.5918
#       y: 829.8376
#       z: -0.32256925
#     }
#   }
#   landmarks {
#     type: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 1528.44
#       y: 825.9397
#       z: 1.9726329
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 1536.4353
#       y: 825.76935
#       z: -1.9543982
#     }
#   }
#   landmarks {
#     type: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 1542.4615
#       y: 825.88763
#       z: -2.1039538
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 1551.0225
#       y: 826.31665
#       z: 1.4436382
#     }
#   }
#   landmarks {
#     type: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 1539.2798
#       y: 829.0503
#       z: -2.8134885
#     }
#   }
#   landmarks {
#     type: NOSE_TIP
#     position {
#       x: 1538.8359
#       y: 835.55853
#       z: -7.9250784
#     }
#   }
#   landmarks {
#     type: UPPER_LIP
#     position {
#       x: 1539.447
#       y: 841.6058
#       z: -5.996003
#     }
#   }
#   landmarks {
#     type: LOWER_LIP
#     position {
#       x: 1539.7925
#       y: 845.6588
#       z: -5.802371
#     }
#   }
#   landmarks {
#     type: MOUTH_LEFT
#     position {
#       x: 1533.5277
#       y: 843.8268
#       z: -2.644689
#     }
#   }
#   landmarks {
#     type: MOUTH_RIGHT
#     position {
#       x: 1545.1292
#       y: 843.93536
#       z: -2.9187143
#     }
#   }
#   landmarks {
#     type: MOUTH_CENTER
#     position {
#       x: 1539.5067
#       y: 843.5105
#       z: -5.3522005
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_RIGHT
#     position {
#       x: 1543.3221
#       y: 837.9706
#       z: -3.4884386
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_LEFT
#     position {
#       x: 1536.0626
#       y: 837.8996
#       z: -3.2970989
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_CENTER
#     position {
#       x: 1539.4825
#       y: 838.49054
#       z: -5.4784446
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 1532.5259
#       y: 828.2914
#       z: -0.53611803
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 1535.2599
#       y: 829.5651
#       z: -0.08035815
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 1532.5299
#       y: 830.5117
#       z: -0.3288169
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 1529.888
#       y: 829.7331
#       z: 1.2383491
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 1546.6414
#       y: 828.4221
#       z: -0.8263265
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 1549.5339
#       y: 829.9242
#       z: 0.82011425
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 1546.6184
#       y: 830.91016
#       z: -0.6687218
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 1543.4149
#       y: 829.9089
#       z: -0.28464413
#     }
#   }
#   landmarks {
#     type: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 1532.4243
#       y: 824.5804
#       z: -0.61506224
#     }
#   }
#   landmarks {
#     type: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 1546.684
#       y: 824.8599
#       z: -0.9498899
#     }
#   }
#   landmarks {
#     type: LEFT_EAR_TRAGION
#     position {
#       x: 1522.499
#       y: 836.77014
#       z: 15.486395
#     }
#   }
#   landmarks {
#     type: RIGHT_EAR_TRAGION
#     position {
#       x: 1557.0011
#       y: 837.3283
#       z: 14.786243
#     }
#   }
#   landmarks {
#     type: FOREHEAD_GLABELLA
#     position {
#       x: 1539.3063
#       y: 825.88214
#       z: -2.4992313
#     }
#   }
#   landmarks {
#     type: CHIN_GNATHION
#     position {
#       x: 1539.4486
#       y: 852.63403
#       z: -5.1523495
#     }
#   }
#   landmarks {
#     type: CHIN_LEFT_GONION
#     position {
#       x: 1526.3671
#       y: 846.3972
#       z: 8.00368
#     }
#   }
#   landmarks {
#     type: CHIN_RIGHT_GONION
#     position {
#       x: 1552.6005
#       y: 847.4382
#       z: 7.460793
#     }
#   }
#   landmarks {
#     type: 35
#     position {
#       x: 1530.1086
#       y: 838.36743
#       z: -0.28299093
#     }
#   }
#   landmarks {
#     type: 36
#     position {
#       x: 1549.3062
#       y: 838.55273
#       z: -0.6997877
#     }
#   }
#   roll_angle: 0.35084662
#   pan_angle: -1.158197
#   tilt_angle: 9.400918
#   detection_confidence: 0.4366529
#   landmarking_confidence: 0.7010366
#   joy_likelihood: VERY_UNLIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: VERY_UNLIKELY
#   blurred_likelihood: VERY_LIKELY
#   headwear_likelihood: VERY_UNLIKELY
# }
# face_annotations {
#   bounding_poly {
#     vertices {
#       x: 146
#       y: 762
#     }
#     vertices {
#       x: 195
#       y: 762
#     }
#     vertices {
#       x: 195
#       y: 819
#     }
#     vertices {
#       x: 146
#       y: 819
#     }
#   }
#   fd_bounding_poly {
#     vertices {
#       x: 151
#       y: 765
#     }
#     vertices {
#       x: 200
#       y: 765
#     }
#     vertices {
#       x: 200
#       y: 816
#     }
#     vertices {
#       x: 151
#       y: 816
#     }
#   }
#   landmarks {
#     type: LEFT_EYE
#     position {
#       x: 172.68298
#       y: 790.83374
#       z: -0.0009279251
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE
#     position {
#       x: 184.18222
#       y: 790.7734
#       z: 7.9461684
#     }
#   }
#   landmarks {
#     type: LEFT_OF_LEFT_EYEBROW
#     position {
#       x: 167.78745
#       y: 786.6487
#       z: -1.6150162
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_LEFT_EYEBROW
#     position {
#       x: 176.90079
#       y: 786.6984
#       z: -0.08649421
#     }
#   }
#   landmarks {
#     type: LEFT_OF_RIGHT_EYEBROW
#     position {
#       x: 182.85054
#       y: 787.0159
#       z: 3.8100176
#     }
#   }
#   landmarks {
#     type: RIGHT_OF_RIGHT_EYEBROW
#     position {
#       x: 188.51668
#       y: 788.34796
#       z: 11.795968
#     }
#   }
#   landmarks {
#     type: MIDPOINT_BETWEEN_EYES
#     position {
#       x: 179.8028
#       y: 789.8923
#       z: 1.6174535
#     }
#   }
#   landmarks {
#     type: NOSE_TIP
#     position {
#       x: 182.48132
#       y: 798.24426
#       z: -1.828584
#     }
#   }
#   landmarks {
#     type: UPPER_LIP
#     position {
#       x: 180.1828
#       y: 804.02966
#       z: 0.55962324
#     }
#   }
#   landmarks {
#     type: LOWER_LIP
#     position {
#       x: 179.26735
#       y: 807.5792
#       z: 1.2649071
#     }
#   }
#   landmarks {
#     type: MOUTH_LEFT
#     position {
#       x: 173.62622
#       y: 805.75934
#       z: 0.39130926
#     }
#   }
#   landmarks {
#     type: MOUTH_RIGHT
#     position {
#       x: 182.90591
#       y: 805.78827
#       z: 6.8868656
#     }
#   }
#   landmarks {
#     type: MOUTH_CENTER
#     position {
#       x: 180.1107
#       y: 806.56665
#       z: 1.4365989
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_RIGHT
#     position {
#       x: 183.10135
#       y: 800.0639
#       z: 4.578239
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_LEFT
#     position {
#       x: 176.02132
#       y: 800.01874
#       z: 0.069965124
#     }
#   }
#   landmarks {
#     type: NOSE_BOTTOM_CENTER
#     position {
#       x: 180.29584
#       y: 801.06305
#       z: 0.58179176
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_TOP_BOUNDARY
#     position {
#       x: 172.78256
#       y: 789.40497
#       z: -0.74369836
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_RIGHT_CORNER
#     position {
#       x: 175.57039
#       y: 790.8869
#       z: 1.7098588
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 172.55269
#       y: 792.01764
#       z: -0.26710773
#     }
#   }
#   landmarks {
#     type: LEFT_EYE_LEFT_CORNER
#     position {
#       x: 169.57805
#       y: 790.6622
#       z: -0.6205716
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_TOP_BOUNDARY
#     position {
#       x: 184.67992
#       y: 789.45996
#       z: 7.4078436
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_RIGHT_CORNER
#     position {
#       x: 186.19325
#       y: 790.9063
#       z: 10.725656
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_BOTTOM_BOUNDARY
#     position {
#       x: 184.33893
#       y: 791.89606
#       z: 7.8833036
#     }
#   }
#   landmarks {
#     type: RIGHT_EYE_LEFT_CORNER
#     position {
#       x: 181.75807
#       y: 790.75415
#       z: 6.2973967
#     }
#   }
#   landmarks {
#     type: LEFT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 172.69092
#       y: 785.3206
#       z: -1.5950537
#     }
#   }
#   landmarks {
#     type: RIGHT_EYEBROW_UPPER_MIDPOINT
#     position {
#       x: 185.95352
#       y: 786.41394
#       z: 7.135001
#     }
#   }
#   landmarks {
#     type: LEFT_EAR_TRAGION
#     position {
#       x: 153.47137
#       y: 793.09045
#       z: 9.083619
#     }
#   }
#   landmarks {
#     type: RIGHT_EAR_TRAGION
#     position {
#       x: 183.3846
#       y: 795.81165
#       z: 27.343372
#     }
#   }
#   landmarks {
#     type: FOREHEAD_GLABELLA
#     position {
#       x: 179.85953
#       y: 786.5052
#       z: 1.4598639
#     }
#   }
#   landmarks {
#     type: CHIN_GNATHION
#     position {
#       x: 177.99316
#       y: 815.0455
#       z: 2.778276
#     }
#   }
#   landmarks {
#     type: CHIN_LEFT_GONION
#     position {
#       x: 159.96477
#       y: 806.85333
#       z: 5.7373614
#     }
#   }
#   landmarks {
#     type: CHIN_RIGHT_GONION
#     position {
#       x: 181.55435
#       y: 807.9241
#       z: 20.68323
#     }
#   }
#   landmarks {
#     type: 35
#     position {
#       x: 169.86241
#       y: 800.2707
#       z: -0.5950663
#     }
#   }
#   landmarks {
#     type: 36
#     position {
#       x: 185.93846
#       y: 800.47485
#       z: 10.430583
#     }
#   }
#   roll_angle: 1.8173918
#   pan_angle: 33.993626
#   tilt_angle: 0.41485512
#   detection_confidence: 0.3795815
#   landmarking_confidence: 0.20596503
#   joy_likelihood: VERY_UNLIKELY
#   sorrow_likelihood: VERY_UNLIKELY
#   anger_likelihood: VERY_UNLIKELY
#   surprise_likelihood: VERY_UNLIKELY
#   under_exposed_likelihood: LIKELY
#   blurred_likelihood: POSSIBLE
#   headwear_likelihood: VERY_UNLIKELY
# }

# %% [markdown]
# ### Image Properties

# %%
response = client.image_properties(image=image)
response
# Out:
# image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 90.0
#         green: 84.0
#         blue: 57.0
#       }
#       score: 0.1658262
#       pixel_fraction: 0.0960472
#     }
#     colors {
#       color {
#         red: 157.0
#         green: 150.0
#         blue: 126.0
#       }
#       score: 0.15258466
#       pixel_fraction: 0.1879646
#     }
#     colors {
#       color {
#         red: 193.0
#         green: 191.0
#         blue: 179.0
#       }
#       score: 0.071288146
#       pixel_fraction: 0.20306785
#     }
#     colors {
#       color {
#         red: 166.0
#         green: 108.0
#         blue: 63.0
#       }
#       score: 0.050707348
#       pixel_fraction: 0.0068436577
#     }
#     colors {
#       color {
#         red: 126.0
#         green: 120.0
#         blue: 93.0
#       }
#       score: 0.14381455
#       pixel_fraction: 0.1059587
#     }
#     colors {
#       color {
#         red: 61.0
#         green: 56.0
#         blue: 31.0
#       }
#       score: 0.1095238
#       pixel_fraction: 0.061297935
#     }
#     colors {
#       color {
#         red: 198.0
#         green: 140.0
#         blue: 94.0
#       }
#       score: 0.041776016
#       pixel_fraction: 0.0066076694
#     }
#     colors {
#       color {
#         red: 194.0
#         green: 188.0
#         blue: 166.0
#       }
#       score: 0.03585536
#       pixel_fraction: 0.02938053
#     }
#     colors {
#       color {
#         red: 77.0
#         green: 89.0
#         blue: 57.0
#       }
#       score: 0.0275175
#       pixel_fraction: 0.014277286
#     }
#     colors {
#       color {
#         red: 133.0
#         green: 80.0
#         blue: 37.0
#       }
#       score: 0.02192222
#       pixel_fraction: 0.00359882
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#         x: 680
#       }
#       vertices {
#         x: 1496
#       }
#       vertices {
#         x: 1496
#         y: 1457
#       }
#       vertices {
#         x: 680
#         y: 1457
#       }
#     }
#     confidence: 0.46875
#     importance_fraction: 0.58464855
#   }
# }

# %% [markdown]
# ### Label Detection

# %%
response = client.label_detection(image=image)
response
# Out:
# label_annotations {
#   mid: "/m/079bkr"
#   description: "Mode of transport"
#   score: 0.96869874
#   topicality: 0.96869874
# }
# label_annotations {
#   mid: "/m/018p4k"
#   description: "Cart"
#   score: 0.90895
#   topicality: 0.90895
# }
# label_annotations {
#   mid: "/m/07yv9"
#   description: "Vehicle"
#   score: 0.90143174
#   topicality: 0.90143174
# }
# label_annotations {
#   mid: "/m/01hffk"
#   description: "Carriage"
#   score: 0.89694226
#   topicality: 0.89694226
# }
# label_annotations {
#   mid: "/m/07bsy"
#   description: "Transport"
#   score: 0.86291295
#   topicality: 0.86291295
# }
# label_annotations {
#   mid: "/m/07_gml"
#   description: "Working animal"
#   score: 0.736109
#   topicality: 0.736109
# }
# label_annotations {
#   mid: "/m/02j091"
#   description: "Horse and buggy"
#   score: 0.71871597
#   topicality: 0.71871597
# }
# label_annotations {
#   mid: "/m/0464z4"
#   description: "Pack animal"
#   score: 0.70788527
#   topicality: 0.70788527
# }
# label_annotations {
#   mid: "/m/0242gd"
#   description: "Wagon"
#   score: 0.6617713
#   topicality: 0.6617713
# }
# label_annotations {
#   mid: "/m/03k3r"
#   description: "Horse"
#   score: 0.6272487
#   topicality: 0.6272487
# }

# %% [markdown]
# ### Landmark Detection

# %%
response = client.landmark_detection(image=image)
response

# %% [markdown]
# ### Logo Detection

# %%
response = client.logo_detection(image=image)
response
# Out:
# logo_annotations {
#   mid: "/m/03mb5kj"
#   description: "Browne Jacobson"
#   score: 0.6108932
#   bounding_poly {
#     vertices {
#       x: 1155
#       y: 535
#     }
#     vertices {
#       x: 1642
#       y: 535
#     }
#     vertices {
#       x: 1642
#       y: 621
#     }
#     vertices {
#       x: 1155
#       y: 621
#     }
#   }
# }

# %% [markdown]
# ### Object Detection

# %%
response = client.object_localization(image=image)
response
# Out:
# localized_object_annotations {
#   mid: "/m/083wq"
#   name: "Wheel"
#   score: 0.9269065
#   bounding_poly {
#     normalized_vertices {
#       x: 0.51806146
#       y: 0.5668511
#     }
#     normalized_vertices {
#       x: 0.61581224
#       y: 0.5668511
#     }
#     normalized_vertices {
#       x: 0.61581224
#       y: 0.71255636
#     }
#     normalized_vertices {
#       x: 0.51806146
#       y: 0.71255636
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/083wq"
#   name: "Wheel"
#   score: 0.91704434
#   bounding_poly {
#     normalized_vertices {
#       x: 0.4728733
#       y: 0.55629605
#     }
#     normalized_vertices {
#       x: 0.56723005
#       y: 0.55629605
#     }
#     normalized_vertices {
#       x: 0.56723005
#       y: 0.68358594
#     }
#     normalized_vertices {
#       x: 0.4728733
#       y: 0.68358594
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.91213554
#   bounding_poly {
#     normalized_vertices {
#       x: 0.6835687
#       y: 0.5708439
#     }
#     normalized_vertices {
#       x: 0.7492478
#       y: 0.5708439
#     }
#     normalized_vertices {
#       x: 0.7492478
#       y: 0.79503417
#     }
#     normalized_vertices {
#       x: 0.6835687
#       y: 0.79503417
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.90596837
#   bounding_poly {
#     normalized_vertices {
#       x: 0.058958557
#       y: 0.5172151
#     }
#     normalized_vertices {
#       x: 0.11600954
#       y: 0.5172151
#     }
#     normalized_vertices {
#       x: 0.11600954
#       y: 0.7466211
#     }
#     normalized_vertices {
#       x: 0.058958557
#       y: 0.7466211
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.89921266
#   bounding_poly {
#     normalized_vertices {
#       x: 0.7503992
#       y: 0.5531373
#     }
#     normalized_vertices {
#       x: 0.8143771
#       y: 0.5531373
#     }
#     normalized_vertices {
#       x: 0.8143771
#       y: 0.76852936
#     }
#     normalized_vertices {
#       x: 0.7503992
#       y: 0.76852936
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.89702296
#   bounding_poly {
#     normalized_vertices {
#       x: 0.6081823
#       y: 0.5821188
#     }
#     normalized_vertices {
#       x: 0.6802936
#       y: 0.5821188
#     }
#     normalized_vertices {
#       x: 0.6802936
#       y: 0.77460486
#     }
#     normalized_vertices {
#       x: 0.6081823
#       y: 0.77460486
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/03k3r"
#   name: "Horse"
#   score: 0.88190407
#   bounding_poly {
#     normalized_vertices {
#       x: 0.2720629
#       y: 0.4858913
#     }
#     normalized_vertices {
#       x: 0.47163764
#       y: 0.4858913
#     }
#     normalized_vertices {
#       x: 0.47163764
#       y: 0.70160955
#     }
#     normalized_vertices {
#       x: 0.2720629
#       y: 0.70160955
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/018p4k"
#   name: "Cart"
#   score: 0.86740184
#   bounding_poly {
#     normalized_vertices {
#       x: 0.2967279
#       y: 0.45067278
#     }
#     normalized_vertices {
#       x: 0.6583302
#       y: 0.45067278
#     }
#     normalized_vertices {
#       x: 0.6583302
#       y: 0.7092617
#     }
#     normalized_vertices {
#       x: 0.2967279
#       y: 0.7092617
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/01g317"
#   name: "Person"
#   score: 0.7488103
#   bounding_poly {
#     normalized_vertices {
#       x: 0.52607185
#       y: 0.47454342
#     }
#     normalized_vertices {
#       x: 0.6090762
#       y: 0.47454342
#     }
#     normalized_vertices {
#       x: 0.6090762
#       y: 0.6645767
#     }
#     normalized_vertices {
#       x: 0.52607185
#       y: 0.6645767
#     }
#   }
# }
# localized_object_annotations {
#   mid: "/m/0h9mv"
#   name: "Tire"
#   score: 0.6164076
#   bounding_poly {
#     normalized_vertices {
#       x: 0.51571643
#       y: 0.56225735
#     }
#     normalized_vertices {
#       x: 0.61457133
#       y: 0.56225735
#     }
#     normalized_vertices {
#       x: 0.61457133
#       y: 0.71344924
#     }
#     normalized_vertices {
#       x: 0.51571643
#       y: 0.71344924
#     }
#   }
# }

# %% [markdown]
# ### Web Detection

# %%
response = client.web_detection(image=image)
response
# Out:
# web_detection {
#   web_entities {
#     entity_id: "/m/03k3r"
#     score: 0.8551619
#     description: "Horse"
#   }
#   web_entities {
#     entity_id: "/m/02j091"
#     score: 0.61098564
#     description: "Horse and buggy"
#   }
#   web_entities {
#     entity_id: "/m/02z6033"
#     score: 0.5659005
#     description: "Horse harness"
#   }
#   web_entities {
#     entity_id: "/m/07bsy"
#     score: 0.53916574
#     description: "Transport"
#   }
#   web_entities {
#     entity_id: "/m/0464z4"
#     score: 0.5269144
#     description: "Pack animal"
#   }
#   web_entities {
#     entity_id: "/m/01c8br"
#     score: 0.41458538
#     description: "Street"
#   }
#   web_entities {
#     entity_id: "/m/07j7r"
#     score: 0.33523893
#     description: "Tree"
#   }
#   web_entities {
#     entity_id: "/m/01540"
#     description: "Biology"
#   }
#   web_entities {
#     entity_id: "/m/06mq7"
#     description: "Science"
#   }
#   visually_similar_images {
#     url: "https://images1.apartments.com/i2/W_AoNVPe9iQvXkYTvLLB9zAC6hzLM4P6OOAoq2yk0h0/117/carriage-homes-at-villebois-wilsonville-or.jpg"
#   }
#   visually_similar_images {
#     url: "https://c8.alamy.com/comp/D206EM/man-and-woman-walk-past-a-bare-deciduous-tree-with-balls-of-evergreen-D206EM.jpg"
#   }
#   visually_similar_images {
#     url: "https://c8.alamy.com/comp/C334R5/horse-drawn-carriage-park-off-of-rue-dauteuil-in-quebec-city-canada-C334R5.jpg"
#   }
#   visually_similar_images {
#     url: "https://c8.alamy.com/comp/2BF77XJ/bude-castle-heritage-centre-once-the-home-of-sir-goldsworthy-gurney-the-inventor-of-the-steam-carriage-on-the-south-west-coast-path-north-cornwall-2BF77XJ.jpg"
#   }
#   visually_similar_images {
#     url: "https://ssl.cdn-redfin.com/photo/229/mbphoto/227/genMid.1918227_39_3.jpg"
#   }
#   visually_similar_images {
#     url: "https://images1.apartments.com/i2/HaEEXW2CuaEHlmQrKidyRjw6kQy_x2kX5s_jNgpVODE/117/pinetree-plaza-chula-vista-ca-building-photo.jpg"
#   }
#   visually_similar_images {
#     url: "https://c8.alamy.com/comp/KE1M5J/december-9-2015-tombstone-arizona-usa-christmas-tree-set-up-on-the-KE1M5J.jpg"
#   }
#   visually_similar_images {
#     url: "https://travelinspiredliving.com/wp-content/uploads/2018/08/Carriage-Ride-in-Frankenmuth.jpg"
#   }
#   visually_similar_images {
#     url: "https://bloximages.newyork1.vip.townnews.com/nrtoday.com/content/tncms/assets/v3/editorial/f/41/f41cbd4b-8ce4-51b1-81df-7b87ae2921a7/5dd59045a7323.image.jpg?resize=1200%2C865"
#   }
#   visually_similar_images {
#     url: "https://thumbs.dreamstime.com/b/cenic-view-gomes-teixeira-square-fountain-lions-surrounded-palm-tree-porto-portugal-december-scenic-famous-touristic-141985901.jpg"
#   }
#   best_guess_labels {
#     label: "horse and buggy"
#   }
# }
